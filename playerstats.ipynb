# %% [markdown]
# # BATTERS

# %%
import requests
import pandas as pd
from datetime import datetime
from collections import defaultdict
from concurrent.futures import ThreadPoolExecutor, as_completed
import os

# --- CONFIG ---
current_year = datetime.now().year
years = list(range(2021, current_year + 1))
schedule_cache = {}
os.makedirs("batters", exist_ok=True)

# --- Load batter IDs ---
batter_df = pd.read_csv("batter_ids.csv")

# --- Helper: fetch schedule for a given team & season ---
def get_schedule(team_id, season):
    key = (team_id, season)
    if key in schedule_cache:
        return schedule_cache[key]

    url = "https://statsapi.mlb.com/api/v1/schedule"
    params = {"teamId": team_id, "season": season, "sportId": 1}
    res = requests.get(url, params=params).json()
    sched = {}
    for date in res['dates']:
        for g in date['games']:
            gid = int(g['gamePk'])
            away = g['teams']['away']['team']['id']
            home = g['teams']['home']['team']['id']
            opp = home if away == team_id else away
            sched[gid] = {'Team': team_id, 'Opp': opp, 'away_id': away, 'home_id': home}
    schedule_cache[key] = sched
    return sched

# --- Helper: fetch full log per player ---
def fetch_player_log(player_id):
    all_rows = []

    for season in years:
        url = f"https://statsapi.mlb.com/api/v1/people/{player_id}/stats"
        params = {"stats": "gameLog", "group": "hitting", "season": season}
        res = requests.get(url, params=params).json()

        if not res['stats'] or not res['stats'][0]['splits']:
            continue

        rows = []
        team_ids_used = set()

        for game in res['stats'][0]['splits']:
            row = game['stat']
            game_id = int(game['game']['gamePk'])
            game_date = game['date']
            team_id = game['team']['id']
            row['game_id'] = game_id
            row['game_date'] = game_date
            row['team_id'] = team_id
            team_ids_used.add(team_id)
            row['season'] = season
            rows.append(row)

        df = pd.DataFrame(rows)
        df['game_id'] = df['game_id'].astype(int)

        column_map = {
            'game_date': 'game_date',
            'game_id': 'game_id',
            'atBats': 'AB', 'hits': 'H', 'runs': 'R', 'doubles': '2B', 'triples': '3B',
            'homeRuns': 'HR', 'rbi': 'RBI', 'baseOnBalls': 'BB', 'strikeOuts': 'SO',
            'stolenBases': 'SB', 'caughtStealing': 'CS', 'hitByPitch': 'HBP',
            'sacBunts': 'SH', 'sacFlies': 'SF', 'intentionalWalks': 'IBB',
            'totalBases': 'TB', 'avg': 'BA', 'obp': 'OBP', 'slg': 'SLG', 'ops': 'OPS',
            'plateAppearances': 'PA'
        }
        df = df.rename(columns=column_map)

        df['Team'] = None
        df['Opp'] = None
        df['away_id'] = None
        df['home_id'] = None

        for tid in team_ids_used:
            schedule = get_schedule(tid, season)
            for gid, game_row in df[df['team_id'] == tid].iterrows():
                info = schedule.get(game_row['game_id'], {})
                df.at[gid, 'Team'] = info.get('Team')
                df.at[gid, 'Opp'] = info.get('Opp')
                df.at[gid, 'away_id'] = info.get('away_id')
                df.at[gid, 'home_id'] = info.get('home_id')

        df['game_date'] = pd.to_datetime(df['game_date'])
        df = df.sort_values(['game_date', 'game_id'])
        dbl_counts = df.groupby('game_date').cumcount() + 1
        dbl_flags = df.groupby('game_date')['game_id'].transform('count')
        df['dbl'] = dbl_flags.where(dbl_flags > 1, None)
        df.loc[df['dbl'].notnull(), 'dbl'] = dbl_counts[df['dbl'].notnull()].astype(float)

        all_rows.append(df)

    if all_rows:
        final_df = pd.concat(all_rows)
        ordered = [
            'game_date', 'game_id', 'Team', 'Opp', 'away_id', 'home_id',
            'PA', 'AB', 'H', 'R', '2B', '3B', 'HR', 'RBI',
            'BB', 'SO', 'SB', 'CS', 'HBP', 'SH', 'SF', 'IBB', 'TB',
            'BA', 'OBP', 'SLG', 'OPS', 'dbl'
        ]
        final_df = final_df[ordered]
        return final_df
    return None

# --- Threaded Worker ---
def process_batter(row):
    player_id = int(row['mlbID'])
    bbref_id = row['key_bbref']
    try:
        df = fetch_player_log(player_id)
        if df is not None:
            filename = f"batters/{bbref_id}_batting.csv"
            df.to_csv(filename, index=False)
            return f"Saved {filename}"
        else:
            return f"No data for {bbref_id}"
    except Exception as e:
        return f"Error processing {bbref_id}: {e}"

# --- Run Thread Pool ---
max_threads = 4
with ThreadPoolExecutor(max_workers=max_threads) as executor:
    futures = [executor.submit(process_batter, row) for _, row in batter_df.iterrows()]
    for future in as_completed(futures):
        print(future.result())

print(f"Processed {len(batter_df)} batters")
# Out:
# Saved batters/acunajo01_batting.csv
# Saved batters/adamsma01_batting.csv
# Saved batters/adamsjo03_batting.csv
# Saved batters/abreuwi02_batting.csv
# Saved batters/adriaeh01_batting.csv
# Saved batters/abramcj01_batting.csv
# Saved batters/acunaro01_batting.csv
# Saved batters/abreujo02_batting.csv
# Saved batters/adamsri03_batting.csv
# Saved batters/adamewi01_batting.csv
# Saved batters/adelljo01_batting.csv
# Saved batters/aguilry01_batting.csv
# Saved batters/akiyash01_batting.csv
# Saved batters/aguilje01_batting.csv
# Saved batters/alcanke01_batting.csv
# Saved batters/albieoz01_batting.csv
# Saved batters/alcanse01_batting.csv
# Saved batters/alberha01_batting.csv
# Saved batters/alexabl01_batting.csv
# Saved batters/alexacj01_batting.csv
# Saved batters/alfarjo01_batting.csv
# Saved batters/ahmedni01_batting.csv
# Saved batters/allenau01_batting.csv
# Saved batters/alforan01_batting.csv
# Saved batters/allenni02_batting.csv
# Saved batters/almonab01_batting.csv
# Saved batters/allengr01_batting.csv
# Saved batters/almoral01_batting.csv
# Saved batters/aluja01_batting.csv
# Saved batters/alonspe01_batting.csv
# Saved batters/alvarar01_batting.csv
# Saved batters/alvared01_batting.csv
# Saved batters/alvarna01_batting.csv
# Saved batters/alvarfr01_batting.csv
# Saved batters/altuvjo01_batting.csv
# Saved batters/alvaryo01_batting.csv
# Saved batters/amadoad01_batting.csv
# Saved batters/amburtr01_batting.csv
# Saved batters/anderbr06_batting.csv
# Saved batters/amayami01_batting.csv
# Saved batters/amayaja01_batting.csv
# Saved batters/anderti01_batting.csv
# Saved batters/andruel01_batting.csv
# Saved batters/andrejo03_batting.csv
# Saved batters/aquinar01_batting.csv
# Saved batters/arauzjo01_batting.csv
# Saved batters/arciaor01_batting.csv
# Saved batters/andujmi01_batting.csv
# Saved batters/arandjo01_batting.csv
# Saved batters/arozara01_batting.csv
# Saved batters/arroych01_batting.csv
# Saved batters/arteahu01_batting.csv
# Saved batters/astudwi01_batting.csv
# Saved batters/ariasga01_batting.csv
# Saved batters/arraelu01_batting.csv
# Saved batters/arenano01_batting.csv
# Saved batters/avilaal01_batting.csv
# Saved batters/azocajo01_batting.csv
# Saved batters/baderha01_batting.csv
# Saved batters/bakerda02_batting.csv
# Saved batters/bakerlu01_batting.csv
# Saved batters/baeji01_batting.csv
# Saved batters/bailepa01_batting.csv
# Saved batters/baldwbr01_batting.csv
# Saved batters/baddoak01_batting.csv
# Saved batters/baldwdr01_batting.csv
# Saved batters/baezja01_batting.csv
# Saved batters/bannory01_batting.csv
# Saved batters/banueda01_batting.csv
# Saved batters/bargead01_batting.csv
# Saved batters/barrelu01_batting.csv
# Saved batters/barnhtu01_batting.csv
# Saved batters/barrojo01_batting.csv
# Saved batters/barretr01_batting.csv
# Saved batters/battema01_batting.csv
# Saved batters/barneau01_batting.csv
# Saved batters/basabos01_batting.csv
# Saved batters/batybr01_batting.csv
# Saved batters/beckhti01_batting.csv
# Saved batters/bartjo01_batting.csv
# Saved batters/beatyma01_batting.csv
# Saved batters/beerse01_batting.csv
# Saved batters/bauerja01_batting.csv
# Saved batters/beckjo01_batting.csv
# Saved batters/belljo02_batting.csv
# Saved batters/bellico01_batting.csv
# Saved batters/bemboan01_batting.csv
# Saved batters/beltbr01_batting.csv
# Saved batters/berrost01_batting.csv
# Saved batters/beninan01_batting.csv
# Saved batters/bensowi01_batting.csv
# Saved batters/bernawy01_batting.csv
# Saved batters/bethach01_batting.csv
# Saved batters/bertijo01_batting.csv
# Saved batters/bettsmo01_batting.csv
# Saved batters/bishobr01_batting.csv
# Saved batters/blackch02_batting.csv
# Saved batters/blackty01_batting.csv
# Saved batters/bichebo01_batting.csv
# Saved batters/blancda02_batting.csv
# Saved batters/biggica01_batting.csv
# Saved batters/blanktr01_batting.csv
# Saved batters/bledajj01_batting.csv
# Saved batters/blissry01_batting.csv
# Saved batters/boltsk01_batting.csv
# Saved batters/bogaexa01_batting.csv
# Saved batters/bradlbo01_batting.csv
# Saved batters/bonifjo01_batting.csv
# Saved batters/bouchse01_batting.csv
# Saved batters/boteda01_batting.csv
# Saved batters/bradlja02_batting.csv
# Saved batters/brantmi02_batting.csv
# Saved batters/brantro01_batting.csv
# Saved batters/bregmal01_batting.csv
# Saved batters/brennwi02_batting.csv
# Saved batters/bohmal01_batting.csv
# Saved batters/brinsle01_batting.csv
# Saved batters/brooktr01_batting.csv
# Saved batters/bridejo01_batting.csv
# Saved batters/brossmi01_batting.csv
# Saved batters/brownse01_batting.csv
# Saved batters/bruceja01_batting.csv
# Saved batters/brujavi01_batting.csv
# Saved batters/burdipe01_batting.csv
# Saved batters/bryankr01_batting.csv
# Saved batters/burleal01_batting.csv
# Saved batters/burnsan01_batting.csv
# Saved batters/burgeja01_batting.csv
# Saved batters/buterdr01_batting.csv
# Saved batters/buschmi02_batting.csv
# Saved batters/butlela01_batting.csv
# Saved batters/cabbatr01_batting.csv
# Saved batters/cabaljo01_batting.csv
# Saved batters/cabreas01_batting.csv
# Saved batters/cabremi01_batting.csv
# Saved batters/cabreos01_batting.csv
# Saved batters/buxtoby01_batting.csv
# Saved batters/cainlo01_batting.csv
# Saved batters/camarja01_batting.csv
# Saved batters/callal02_batting.csv
# Saved batters/calhoko01_batting.csv
# Saved batters/calhowi01_batting.csv
# Saved batters/camarjo01_batting.csv
# Saved batters/campber01_batting.csv
# Saved batters/camerda01_batting.csv
# Saved batters/caminju01_batting.csv
# Saved batters/campbkr01_batting.csv
# Saved batters/campegu01_batting.csv
# Saved batters/canaral01_batting.csv
# Saved batters/campulu01_batting.csv
# Saved batters/canhama01_batting.csv
# Saved batters/canoro01_batting.csv
# Saved batters/canzodo01_batting.csv
# Saved batters/candeje01_batting.csv
# Saved batters/capelco01_batting.csv
# Saved batters/capravi01_batting.csv
# Saved batters/caratvi01_batting.csv
# Saved batters/carlsdy01_batting.csv
# Saved batters/carpeke01_batting.csv
# Saved batters/carpema01_batting.csv
# Saved batters/carroco02_batting.csv
# Saved batters/casalcu01_batting.csv
# Saved batters/carteev01_batting.csv
# Saved batters/casastr01_batting.csv
# Saved batters/castidi02_batting.csv
# Saved batters/casteni01_batting.csv
# Saved batters/castier01_batting.csv
# Saved batters/castiiv01_batting.csv
# Saved batters/castrha01_batting.csv
# Saved batters/castrja01_batting.csv
# Saved batters/castrro01_batting.csv
# Saved batters/castrst01_batting.csv
# Saved batters/caveja01_batting.csv
# Saved batters/castrwi01_batting.csv
# Saved batters/celesgi01_batting.csv
# Saved batters/changyu01_batting.csv
# Saved batters/chapaan01_batting.csv
# Saved batters/chapmma01_batting.csv
# Saved batters/choiji01_batting.csv
# Saved batters/chiriro01_batting.csv
# Saved batters/chavimi01_batting.csv
# Saved batters/chourja01_batting.csv
# Saved batters/chishja01_batting.csv
# Saved batters/clasejo01_batting.csv
# Saved batters/ciuffni01_batting.csv
# Saved batters/colliis01_batting.csv
# Saved batters/clemeer01_batting.csv
# Saved batters/colasos01_batting.csv
# Saved batters/clemeko01_batting.csv
# Saved batters/colliza01_batting.csv
# Saved batters/confomi01_batting.csv
# Saved batters/contrma01_batting.csv
# Saved batters/coningr01_batting.csv
# Saved batters/cookbi01_batting.csv
# Saved batters/coopega03_batting.csv
# Saved batters/cordefr02_batting.csv
# Saved batters/contrwi01_batting.csv
# Saved batters/contrwi02_batting.csv
# Saved batters/correca01_batting.csv
# Saved batters/craigwi01_batting.csv
# Saved batters/cowseco01_batting.csv
# Saved batters/crawfbr01_batting.csv
# Saved batters/crewsdy01_batting.csv
# Saved batters/crawfjp01_batting.csv
# Saved batters/croncj01_batting.csv
# Saved batters/croneja01_batting.csv
# Saved batters/croplty01_batting.csv
# Saved batters/crookna01_batting.csv
# Saved batters/crowape01_batting.csv
# Saved batters/culbech01_batting.csv
# Saved batters/cruzon01_batting.csv
# Saved batters/cruzne02_batting.csv
# Saved batters/davidma02_batting.csv
# Saved batters/dalbebo01_batting.csv
# Saved batters/dahlda01_batting.csv
# Saved batters/darnatr01_batting.csv
# Saved batters/davisbr04_batting.csv
# Saved batters/davishe01_batting.csv
# Saved batters/davisja03_batting.csv
# Saved batters/davista01_batting.csv
# Saved batters/davisjd01_batting.csv
# Saved batters/dawsoro01_batting.csv
# Saved batters/davisjo05_batting.csv
# Saved batters/daviskh01_batting.csv
# Saved batters/dazayo01_batting.csv
# Saved batters/degotal01_batting.csv
# Saved batters/deanau01_batting.csv
# Saved batters/deichgr01_batting.csv
# Saved batters/delacel01_batting.csv
# Saved batters/delacbr01_batting.csv
# Saved batters/dejonpa01_batting.csv
# Saved batters/delayja01_batting.csv
# Saved batters/delcaad01_batting.csv
# Saved batters/deloaza01_batting.csv
# Saved batters/deloslu03_batting.csv
# Saved batters/delucjo01_batting.csv
# Saved batters/deshide02_batting.csv
# Saved batters/demertr01_batting.csv
# Saved batters/deluzbe01_batting.csv
# Saved batters/deverjo01_batting.csv
# Saved batters/deverra01_batting.csv
# Saved batters/dezenza01_batting.csv
# Saved batters/diazal02_batting.csv
# Saved batters/diazjo03_batting.csv
# Saved batters/diazel01_batting.csv
# Saved batters/diazis01_batting.csv
# Saved batters/diazle01_batting.csv
# Saved batters/diazya01_batting.csv
# Saved batters/diazyu01_batting.csv
# Saved batters/dickeal01_batting.csv
# Saved batters/diazya02_batting.csv
# Saved batters/difowi01_batting.csv
# Saved batters/dickeco01_batting.csv
# Saved batters/dingldi01_batting.csv
# Saved batters/dixonbr01_batting.csv
# Saved batters/dominja01_batting.csv
# Saved batters/donaljo02_batting.csv
# Saved batters/dorowry01_batting.csv
# Saved batters/donovbr01_batting.csv
# Saved batters/drisclo01_batting.csv
# Saved batters/downsje01_batting.csv
# Saved batters/doziehu01_batting.csv
# Saved batters/doylebr02_batting.csv
# Saved batters/drurybr01_batting.csv
# Saved batters/dubonma01_batting.csv
# Saved batters/duggast01_batting.csv
# Saved batters/duffyma01_batting.csv
# Saved batters/dunanjo01_batting.csv
# Saved batters/dunnbl01_batting.csv
# Saved batters/dunnol01_batting.csv
# Saved batters/duranez01_batting.csv
# Saved batters/duranja01_batting.csv
# Saved batters/dysonja01_batting.csv
# Saved batters/eatonad02_batting.csv
# Saved batters/eatonna01_batting.csv
# Saved batters/duvalad01_batting.csv
# Saved batters/edenca01_batting.csv
# Saved batters/edwarxa01_batting.csv
# Saved batters/edmanto01_batting.csv
# Saved batters/ellisdu01_batting.csv
# Saved batters/ellisdr01_batting.csv
# Saved batters/encarch01_batting.csv
# Saved batters/encarje01_batting.csv
# Saved batters/escobal02_batting.csv
# Saved batters/engelad01_batting.csv
# Saved batters/escobed01_batting.csv
# Saved batters/espinsa01_batting.csv
# Saved batters/estrath01_batting.csv
# Saved batters/fabiasa01_batting.csv
# Saved batters/evansph01_batting.csv
# Saved batters/faircst01_batting.csv
# Saved batters/fargajo01_batting.csv
# Saved batters/farmeky01_batting.csv
# Saved batters/feduchu01_batting.csv
# Saved batters/felicma01_batting.csv
# Saved batters/fermijo01_batting.csv
# Saved batters/fishede01_batting.csv
# Saved batters/fermifr01_batting.csv
# Saved batters/fitzgty01_batting.csv
# Saved batters/fletcdo01_batting.csv
# Saved batters/fletcda02_batting.csv
# Saved batters/flories01_batting.csv
# Saved batters/florewi01_batting.csv
# Saved batters/foscuju01_batting.csv
# Saved batters/fordmi01_batting.csv
# Saved batters/fowlede01_batting.csv
# Saved batters/forteni01_batting.csv
# Saved batters/fowledu01_batting.csv
# Saved batters/foxlu01_batting.csv
# Saved batters/francma02_batting.csv
# Saved batters/fraleja01_batting.csv
# Saved batters/frazito01_batting.csv
# Saved batters/francty01_batting.csv
# Saved batters/frazicl01_batting.csv
# Saved batters/francwa01_batting.csv
# Saved batters/fraziad01_batting.csv
# Saved batters/freemfr01_batting.csv
# Saved batters/freemmi01_batting.csv
# Saved batters/freemty01_batting.csv
# Saved batters/frelisa01_batting.csv
# Saved batters/fryda01_batting.csv
# Saved batters/friedtj01_batting.csv
# Saved batters/fuentjo01_batting.csv
# Saved batters/gallaca01_batting.csv
# Saved batters/gallojo01_batting.csv
# Saved batters/galvifr01_batting.csv
# Saved batters/gamelbe01_batting.csv
# Saved batters/garciar01_batting.csv
# Saved batters/garcide02_batting.csv
# Saved batters/garciad02_batting.csv
# Saved batters/garciav01_batting.csv
# Saved batters/garcijo02_batting.csv
# Saved batters/garcile02_batting.csv
# Saved batters/garcilu04_batting.csv
# Saved batters/garcima01_batting.csv
# Saved batters/gardnbr01_batting.csv
# Saved batters/garciro02_batting.csv
# Saved batters/garliky01_batting.csv
# Saved batters/garnedu01_batting.csv
# Saved batters/garrest01_batting.csv
# Saved batters/gaspemi01_batting.csv
# Saved batters/garvemi01_batting.csv
# Saved batters/gelofza01_batting.csv
# Saved batters/gentrty01_batting.csv
# Saved batters/giambtr01_batting.csv
# Saved batters/gittech01_batting.csv
# Saved batters/godoyjo01_batting.csv
# Saved batters/gimenan01_batting.csv
# Saved batters/goldspa01_batting.csv
# Saved batters/gomesya01_batting.csv
# Saved batters/gonzaer01_batting.csv
# Saved batters/gonzama01_batting.csv
# Saved batters/gonzalu03_batting.csv
# Saved batters/gonzani01_batting.csv
# Saved batters/gonzaos01_batting.csv
# Saved batters/gonzaro01_batting.csv
# Saved batters/goodrni01_batting.csv
# Saved batters/goodwbr01_batting.csv
# Saved batters/goodmhu01_batting.csv
# Saved batters/gordode01_batting.csv
# Saved batters/gorete01_batting.csv
# Saved batters/gordoni01_batting.csv
# Saved batters/gormano01_batting.csv
# Saved batters/gosseph01_batting.csv
# Saved batters/graytr01_batting.csv
# Saved batters/grandya01_batting.csv
# Saved batters/gourryu01_batting.csv
# Saved batters/gregodi01_batting.csv
# Saved batters/greenri03_batting.csv
# Saved batters/greingr01_batting.csv
# Saved batters/grichra01_batting.csv
# Saved batters/grishtr01_batting.csv
# Saved batters/grissva01_batting.csv
# Saved batters/groshjo01_batting.csv
# Saved batters/grossro01_batting.csv
# Saved batters/guerrvl02_batting.csv
# Saved batters/guilllu01_batting.csv
# Saved batters/gurrilo01_batting.csv
# Saved batters/gushuta01_batting.csv
# Saved batters/guthrda01_batting.csv
# Saved batters/gutieke01_batting.csv
# Saved batters/haaseer01_batting.csv
# Saved batters/hagerja01_batting.csv
# Saved batters/haggesa01_batting.csv
# Saved batters/hallda02_batting.csv
# Saved batters/hamilbi02_batting.csv
# Saved batters/hamilca01_batting.csv
# Saved batters/hamilda03_batting.csv
# Saved batters/hampsga01_batting.csv
# Saved batters/hanigmi01_batting.csv
# Saved batters/happia01_batting.csv
# Saved batters/harribr02_batting.csv
# Saved batters/harpebr03_batting.csv
# Saved batters/harridu01_batting.csv
# Saved batters/harrijo05_batting.csv
# Saved batters/harrimo01_batting.csv
# Saved batters/harrimi04_batting.csv
# Saved batters/haselad01_batting.csv
# Saved batters/hayeske01_batting.csv
# Saved batters/heathni01_batting.csv
# Saved batters/hedgeau01_batting.csv
# Saved batters/haysau01_batting.csv
# Saved batters/heimjo01_batting.csv
# Saved batters/heinesc01_batting.csv
# Saved batters/helmami01_batting.csv
# Saved batters/heinety01_batting.csv
# Saved batters/henrypa01_batting.csv
# Saved batters/hendegu01_batting.csv
# Saved batters/heredgu01_batting.csv
# Saved batters/hermomi01_batting.csv
# Saved batters/henslda01_batting.csv
# Saved batters/hernada04_batting.csv
# Saved batters/hernace02_batting.csv
# Saved batters/hernael02_batting.csv
# Saved batters/hernaen02_batting.csv
# Saved batters/hernate01_batting.csv
# Saved batters/hernayo02_batting.csv
# Saved batters/hernaya01_batting.csv
# Saved batters/herreiv01_batting.csv
# Saved batters/herrejo04_batting.csv
# Saved batters/herreod01_batting.csv
# Saved batters/heywaja01_batting.csv
# Saved batters/hicklbr01_batting.csv
# Saved batters/hicksaa01_batting.csv
# Saved batters/hicksli01_batting.csv
# Saved batters/hicksjo02_batting.csv
# Saved batters/higasky01_batting.csv
# Saved batters/higgipj01_batting.csv
# Saved batters/hillde01_batting.csv
# Saved batters/hillisa01_batting.csv
# Saved batters/hindsre01_batting.csv
# Saved batters/hoernni01_batting.csv
# Saved batters/holtbr01_batting.csv
# Saved batters/hopkitj01_batting.csv
# Saved batters/horwisp01_batting.csv
# Saved batters/holadbr01_batting.csv
# Saved batters/hiurake01_batting.csv
# Saved batters/hollija01_batting.csv
# Saved batters/hoskirh01_batting.csv
# Saved batters/hosmeer01_batting.csv
# Saved batters/hoyinja01_batting.csv
# Saved batters/hudsojo03_batting.csv
# Saved batters/huffsa01_batting.csv
# Saved batters/hurstsc01_batting.csv
# Saved batters/hummeco01_batting.csv
# Saved batters/hurtuja01_batting.csv
# Saved batters/ibanean01_batting.csv
# Saved batters/iglesjo01_batting.csv
# Saved batters/inciaen01_batting.csv
# Saved batters/indiajo01_batting.csv
# Saved batters/jacksal02_batting.csv
# Saved batters/jacksdr01_batting.csv
# Saved batters/isbelky01_batting.csv
# Saved batters/jankotr01_batting.csv
# Saved batters/janseda01_batting.csv
# Saved batters/jayjo02_batting.csv
# Saved batters/jimenle01_batting.csv
# Saved batters/jeffery01_batting.csv
# Saved batters/jimenel02_batting.csv
# Saved batters/johnsbr03_batting.csv
# Saved batters/joeco01_batting.csv
# Saved batters/johnsda07_batting.csv
# Saved batters/jonesgr02_batting.csv
# Saved batters/jonesja07_batting.csv
# Saved batters/jonesja08_batting.csv
# Saved batters/jonesno01_batting.csv
# Saved batters/jonesta01_batting.csv
# Saved batters/joycema01_batting.csv
# Saved batters/jordale01_batting.csv
# Saved batters/judgeaa01_batting.csv
# Saved batters/julksco01_batting.csv
# Saved batters/julieed01_batting.csv
# Saved batters/jungja01_batting.csv
# Saved batters/kaiseco01_batting.csv
# Saved batters/jungjo01_batting.csv
# Saved batters/katohgo01_batting.csv
# Saved batters/kavadni01_batting.csv
# Saved batters/kazmase01_batting.csv
# Saved batters/keirsda01_batting.csv
# Saved batters/keithco01_batting.csv
# Saved batters/kelenja01_batting.csv
# Saved batters/kennebu01_batting.csv
# Saved batters/kempto01_batting.csv
# Saved batters/kellyca02_batting.csv
# Saved batters/keplema01_batting.csv
# Saved batters/kessigr01_batting.csv
# Saved batters/kieboca01_batting.csv
# Saved batters/kiermke01_batting.csv
# Saved batters/kingesc01_batting.csv
# Saved batters/kimha01_batting.csv
# Saved batters/kineris01_batting.csv
# Saved batters/kirilal01_batting.csv
# Saved batters/kivlepa01_batting.csv
# Saved batters/kirkal01_batting.csv
# Saved batters/kjershe01_batting.csv
# Saved batters/knappan01_batting.csv
# Saved batters/kochgr01_batting.csv
# Saved batters/kohlwta01_batting.csv
# Saved batters/kniznan01_batting.csv
# Saved batters/kolozma01_batting.csv
# Saved batters/kozmape01_batting.csv
# Saved batters/kreidry01_batting.csv
# Saved batters/krizaja01_batting.csv
# Saved batters/krugeja01_batting.csv
# Saved batters/ladenty01_batting.csv
# Saved batters/lagarju01_batting.csv
# Saved batters/kwanst01_batting.csv
# Saved batters/lamarry01_batting.csv
# Saved batters/lambja01_batting.csv
# Saved batters/langesh01_batting.csv
# Saved batters/larseja01_batting.csv
# Saved batters/larnatr01_batting.csv
# Saved batters/langfwy01_batting.csv
# Saved batters/lasteto01_batting.csv
# Saved batters/lavarry01_batting.csv
# Saved batters/laurera01_batting.csv
# Saved batters/lavasbr01_batting.csv
# Saved batters/lawlajo01_batting.csv
# Saved batters/leebr02_batting.csv
# Saved batters/leblach01_batting.csv
# Saved batters/leeju01_batting.csv
# Saved batters/leekh01_batting.csv
# Saved batters/lemahdj01_batting.csv
# Saved batters/leeko01_batting.csv
# Saved batters/leonpe01_batting.csv
# Saved batters/leonsa01_batting.csv
# Saved batters/lestejo02_batting.csv
# Saved batters/lewisky01_batting.csv
# Saved batters/lewisro02_batting.csv
# Saved batters/leybado01_batting.csv
# Saved batters/liberlu01_batting.csv
# Saved batters/lintz02_batting.csv
# Saved batters/lindofr01_batting.csv
# Saved batters/lipcian01_batting.csv
# Saved batters/lipsctr01_batting.csv
# Saved batters/lobatjo01_batting.csv
# Saved batters/locklty01_batting.csv
# Saved batters/locasti01_batting.csv
# Saved batters/lockrbr01_batting.csv
# Saved batters/loftini01_batting.csv
# Saved batters/longoev01_batting.csv
# Saved batters/longsh01_batting.csv
# Saved batters/lopesch01_batting.csv
# Saved batters/loperjo01_batting.csv
# Saved batters/lopesti01_batting.csv
# Saved batters/lopezal03_batting.csv
# Saved batters/lopezir01_batting.csv
# Saved batters/lopezja03_batting.csv
# Saved batters/lopezot01_batting.csv
# Saved batters/lopezni01_batting.csv
# Saved batters/lowebr01_batting.csv
# Saved batters/lowejo01_batting.csv
# Saved batters/lowrije01_batting.csv
# Saved batters/luciama01_batting.csv
# Saved batters/lowena01_batting.csv
# Saved batters/lucrojo01_batting.csv
# Saved batters/lukesna01_batting.csv
# Saved batters/luplojo01_batting.csv
# Saved batters/luxga01_batting.csv
# Saved batters/machivi01_batting.csv
# Saved batters/machadi01_batting.csv
# Saved batters/machama01_batting.csv
# Saved batters/mackida01_batting.csv
# Saved batters/madribl01_batting.csv
# Saved batters/maggidr01_batting.csv
# Saved batters/madrini01_batting.csv
# Saved batters/malloju02_batting.csv
# Saved batters/mailelu01_batting.csv
# Saved batters/maldoma01_batting.csv
# Saved batters/manzaky01_batting.csv
# Saved batters/mancitr01_batting.csv
# Saved batters/marcatu01_batting.csv
# Saved batters/marchra01_batting.csv
# Saved batters/margoma01_batting.csv
# Saved batters/marloca01_batting.csv
# Saved batters/marisja01_batting.csv
# Saved batters/marmojo01_batting.csv
# Saved batters/marrede01_batting.csv
# Saved batters/marshbr02_batting.csv
# Saved batters/martelu02_batting.csv
# Saved batters/marteke01_batting.csv
# Saved batters/marteno01_batting.csv
# Saved batters/martian02_batting.csv
# Saved batters/martiau01_batting.csv
# Saved batters/martest01_batting.csv
# Saved batters/martija03_batting.csv
# Saved batters/martijp01_batting.csv
# Saved batters/martijd02_batting.csv
# Saved batters/martini02_batting.csv
# Saved batters/martior01_batting.csv
# Saved batters/martiri01_batting.csv
# Saved batters/mastrmi01_batting.csv
# Saved batters/mateojo01_batting.csv
# Saved batters/massemi02_batting.csv
# Saved batters/mathije01_batting.csv
# Saved batters/mathima01_batting.csv
# Saved batters/mathiwy01_batting.csv
# Saved batters/matijjj01_batting.csv
# Saved batters/matonni01_batting.csv
# Saved batters/mauriro01_batting.csv
# Saved batters/maybica01_batting.csv
# Saved batters/matoslu02_batting.csv
# Saved batters/mayoco01_batting.csv
# Saved batters/mayfija01_batting.csv
# Saved batters/mazeipa01_batting.csv
# Saved batters/mazarno01_batting.csv
# Saved batters/mcbrory01_batting.csv
# Saved batters/mccanky01_batting.csv
# Saved batters/mccanja02_batting.csv
# Saved batters/mccoyma01_batting.csv
# Saved batters/mccorch01_batting.csv
# Saved batters/mccarja02_batting.csv
# Saved batters/mccragr01_batting.csv
# Saved batters/mccutan01_batting.csv
# Saved batters/mcdonmi01_batting.csv
# Saved batters/mcguire01_batting.csv
# Saved batters/mclaima01_batting.csv
# Saved batters/mckinbi01_batting.csv
# Saved batters/mckenry01_batting.csv
# Saved batters/mckinza01_batting.csv
# Saved batters/mcmahry01_batting.csv
# Saved batters/meadcu01_batting.csv
# Saved batters/mcneije01_batting.csv
# Saved batters/meadopa01_batting.csv
# Saved batters/meadoau01_batting.csv
# Saved batters/mecklwa01_batting.csv
# Saved batters/melenmj01_batting.csv
# Saved batters/mejiafr01_batting.csv
# Saved batters/mendida01_batting.csv
# Saved batters/menesjo01_batting.csv
# Saved batters/mercaos01_batting.csv
# Saved batters/mercejo03_batting.csv
# Saved batters/merceye01_batting.csv
# Saved batters/mervima01_batting.csv
# Saved batters/merriwh01_batting.csv
# Saved batters/merrija01_batting.csv
# Saved batters/meyerja02_batting.csv
# Saved batters/milladr01_batting.csv
# Saved batters/millebr03_batting.csv
# Saved batters/millebr02_batting.csv
# Saved batters/misneka01_batting.csv
# Saved batters/milleow01_batting.csv
# Saved batters/mitchca01_batting.csv
# Saved batters/miranjo01_batting.csv
# Saved batters/mitchga01_batting.csv
# Saved batters/molinya01_batting.csv
# Saved batters/monasan01_batting.csv
# Saved batters/moncayo01_batting.csv
# Saved batters/mondera02_batting.csv
# Saved batters/monteco01_batting.csv
# Saved batters/mondona01_batting.csv
# Saved batters/moniami01_batting.csv
# Saved batters/mooredy01_batting.csv
# Saved batters/moranco01_batting.csv
# Saved batters/morelmi01_batting.csv
# Saved batters/morelch01_batting.csv
# Saved batters/morofma01_batting.csv
# Saved batters/motteta01_batting.csv
# Saved batters/morenga01_batting.csv
# Saved batters/monteel01_batting.csv
# Saved batters/moustmi01_batting.csv
# Saved batters/mountry01_batting.csv
# Saved batters/mullice01_batting.csv
# Saved batters/munozya01_batting.csv
# Saved batters/muncyma02_batting.csv
# Saved batters/muncyma01_batting.csv
# Saved batters/murphto04_batting.csv
# Saved batters/murphse01_batting.csv
# Saved batters/muzzisi01_batting.csv
# Saved batters/narvaca01_batting.csv
# Saved batters/myersda01_batting.csv
# Saved batters/myerswi01_batting.csv
# Saved batters/narvaom01_batting.csv
# Saved batters/naylobo01_batting.csv
# Saved batters/naylojo01_batting.csv
# Saved batters/netoza01_batting.csv
# Saved batters/neusesh01_batting.csv
# Saved batters/newmake01_batting.csv
# Saved batters/noeljh01_batting.csv
# Saved batters/nevinty01_batting.csv
# Saved batters/nidoto01_batting.csv
# Saved batters/nodary01_batting.csv
# Saved batters/nimmobr01_batting.csv
# Saved batters/nogowjo01_batting.csv
# Saved batters/nolaau01_batting.csv
# Saved batters/nunezna01_batting.csv
# Saved batters/norbyco01_batting.csv
# Saved batters/nootbla01_batting.csv
# Saved batters/nunezre01_batting.csv
# Saved batters/nottija01_batting.csv
# Saved batters/nunezdo01_batting.csv
# Saved batters/odomjo01_batting.csv
# Saved batters/odorro01_batting.csv
# Saved batters/ogradbr01_batting.csv
# Saved batters/ohopplo01_batting.csv
# Saved batters/okeefbr01_batting.csv
# Saved batters/okeych01_batting.csv
# Saved batters/ohtansh01_batting.csv
# Saved batters/ohearry01_batting.csv
# Saved batters/olivaed02_batting.csv
# Saved batters/olivaja01_batting.csv
# Saved batters/orneljo01_batting.csv
# Saved batters/oneilty01_batting.csv
# Saved batters/olsonma02_batting.csv
# Saved batters/outmaja01_batting.csv
# Saved batters/ortegra01_batting.csv
# Saved batters/ortizjo06_batting.csv
# Saved batters/owingch01_batting.csv
# Saved batters/owenhu01_batting.csv
# Saved batters/pachecr01_batting.csv
# Saved batters/pagesan01_batting.csv
# Saved batters/palacje01_batting.csv
# Saved batters/ozunama01_batting.csv
# Saved batters/padloke01_batting.csv
# Saved batters/pagespe02_batting.csv
# Saved batters/palacjo01_batting.csv
# Saved batters/palacri01_batting.csv
# Saved batters/panikjo01_batting.csv
# Saved batters/parisky01_batting.csv
# Saved batters/papiemi01_batting.csv
# Saved batters/parkho01_batting.csv
# Saved batters/parrage01_batting.csv
# Saved batters/paredis01_batting.csv
# Saved batters/pasquvi01_batting.csv
# Saved batters/paulegr01_batting.csv
# Saved batters/paynety01_batting.csv
# Saved batters/paytoma01_batting.csv
# Saved batters/pederjo01_batting.csv
# Saved batters/pegueli01_batting.csv
# Saved batters/penaje02_batting.csv
# Saved batters/peralda01_batting.csv
# Saved batters/perazjo01_batting.csv
# Saved batters/perazos02_batting.csv
# Saved batters/peredjh01_batting.csv
# Saved batters/pereiev01_batting.csv
# Saved batters/perdoge01_batting.csv
# Saved batters/perezhe01_batting.csv
# Saved batters/perezca02_batting.csv
# Saved batters/perezca03_batting.csv
# Saved batters/perezjo02_batting.csv
# Saved batters/perezmi03_batting.csv
# Saved batters/perezro02_batting.csv
# Saved batters/perezsa02_batting.csv
# Saved batters/perezwe01_batting.csv
# Saved batters/perkibl01_batting.csv
# Saved batters/peterja01_batting.csv
# Saved batters/phamth01_batting.csv
# Saved batters/pillake01_batting.csv
# Saved batters/pinama01_batting.csv
# Saved batters/pindech01_batting.csv
# Saved batters/pinedis01_batting.csv
# Saved batters/pintore02_batting.csv
# Saved batters/plaweke01_batting.csv
# Saved batters/piscost01_batting.csv
# Saved batters/polangr01_batting.csv
# Saved batters/plummni01_batting.csv
# Saved batters/polanjo01_batting.csv
# Saved batters/portelo01_batting.csv
# Saved batters/polloaj01_batting.csv
# Saved batters/poseybu01_batting.csv
# Saved batters/pozoyo01_batting.csv
# Saved batters/proctfo01_batting.csv
# Saved batters/prattni01_batting.csv
# Saved batters/profaju01_batting.csv
# Saved batters/quereju01_batting.csv
# Saved batters/pujolal01_batting.csv
# Saved batters/quinnro01_batting.csv
# Saved batters/quiroes01_batting.csv
# Saved batters/rafaece01_batting.csv
# Saved batters/raleylu01_batting.csv
# Saved batters/raleica01_batting.csv
# Saved batters/ramirha02_batting.csv
# Saved batters/ramosbr01_batting.csv
# Saved batters/ramirjo01_batting.csv
# Saved batters/ramoshe02_batting.csv
# Saved batters/ramoshe01_batting.csv
# Saved batters/ramoswi01_batting.csv
# Saved batters/rayco01_batting.csv
# Saved batters/reddijo01_batting.csv
# Saved batters/realmjt01_batting.csv
# Saved batters/reetzja01_batting.csv
# Saved batters/remilza01_batting.csv
# Saved batters/reksza01_batting.csv
# Saved batters/refsnro01_batting.csv
# Saved batters/rendoan01_batting.csv
# Saved batters/renfrhu01_batting.csv
# Saved batters/reyesfr01_batting.csv
# Saved batters/rengilu01_batting.csv
# Saved batters/reyespa01_batting.csv
# Saved batters/reyesvi01_batting.csv
# Saved batters/reynoma03_batting.csv
# Saved batters/reynobr01_batting.csv
# Saved batters/ricebe01_batting.csv
# Saved batters/riddljt01_batting.csv
# Saved batters/riosed01_batting.csv
# Saved batters/rivasle01_batting.csv
# Saved batters/rileyau01_batting.csv
# Saved batters/rivasal01_batting.csv
# Saved batters/rivaswe01_batting.csv
# Saved batters/riverre01_batting.csv
# Saved batters/riverem01_batting.csv
# Saved batters/riverse01_batting.csv
# Saved batters/roberkr01_batting.csv
# Saved batters/roberda10_batting.csv
# Saved batters/rizzoan01_batting.csv
# Saved batters/roberlu01_batting.csv
# Saved batters/robinch04_batting.csv
# Saved batters/roblevi01_batting.csv
# Saved batters/robsoja01_batting.csv
# Saved batters/rocchbr01_batting.csv
# Saved batters/rodenal01_batting.csv
# Saved batters/rodrien01_batting.csv
# Saved batters/rodgebr02_batting.csv
# Saved batters/rodrijo09_batting.csv
# Saved batters/rodrijo10_batting.csv
# Saved batters/rodriju01_batting.csv
# Saved batters/rogerja03_batting.csv
# Saved batters/rojasjo01_batting.csv
# Saved batters/rojasjo02_batting.csv
# Saved batters/rojasjo03_batting.csv
# Saved batters/rojasmi02_batting.csv
# Saved batters/rollech01_batting.csv
# Saved batters/rominan01_batting.csv
# Saved batters/rominau01_batting.csv
# Saved batters/romodr01_batting.csv
# Saved batters/rondojo02_batting.csv
# Saved batters/rookebr01_batting.csv
# Saved batters/rortvbe01_batting.csv
# Saved batters/rosaram01_batting.csv
# Saved batters/rosareg01_batting.csv
# Saved batters/rosared01_batting.csv
# Saved batters/ruizes01_batting.csv
# Saved batters/rufda01_batting.csv
# Saved batters/ruizke01_batting.csv
# Saved batters/ruizri01_batting.csv
# Saved batters/ruthebl01_batting.csv
# Saved batters/rutscad01_batting.csv
# Saved batters/sabolbl01_batting.csv
# Saved batters/saggeth01_batting.csv
# Saved batters/salazce01_batting.csv
# Saved batters/sanchad01_batting.csv
# Saved batters/sanchal04_batting.csv
# Saved batters/sanchca01_batting.csv
# Saved batters/sanchga02_batting.csv
# Saved batters/sanchje02_batting.csv
# Saved batters/sandsdo01_batting.csv
# Saved batters/sandopa01_batting.csv
# Saved batters/sanojja01_batting.csv
# Saved batters/sanomi01_batting.csv
# Saved batters/santaan02_batting.csv
# Saved batters/santaca01_batting.csv
# Saved batters/santada01_batting.csv
# Saved batters/schebsc01_batting.csv
# Saved batters/schanno01_batting.csv
# Saved batters/schmica01_batting.csv
# Saved batters/schneda03_batting.csv
# Saved batters/schneda04_batting.csv
# Saved batters/schoojo01_batting.csv
# Saved batters/schroma01_batting.csv
# Saved batters/schuema01_batting.csv
# Saved batters/schunaa01_batting.csv
# Saved batters/schwifr01_batting.csv
# Saved batters/schwaky01_batting.csv
# Saved batters/scottvi01_batting.csv
# Saved batters/seageco01_batting.csv
# Saved batters/seageky01_batting.csv
# Saved batters/seaglch01_batting.csv
# Saved batters/segurje01_batting.csv
# Saved batters/sengeha01_batting.csv
# Saved batters/semiema01_batting.csv
# Saved batters/senzeni01_batting.csv
# Saved batters/servebr01_batting.csv
# Saved batters/shawma01_batting.csv
# Saved batters/severpe01_batting.csv
# Saved batters/shawtr01_batting.csv
# Saved batters/shentau01_batting.csv
# Saved batters/sheetga01_batting.csv
# Saved batters/shewmbr01_batting.csv
# Saved batters/sianimi01_batting.csv
# Saved batters/shortza01_batting.csv
# Saved batters/sierrma01_batting.csv
# Saved batters/simmoan01_batting.csv
# Saved batters/singljo02_batting.csv
# Saved batters/sirijo01_batting.csv
# Saved batters/siscoch01_batting.csv
# Saved batters/slateau01_batting.csv
# Saved batters/smithca07_batting.csv
# Saved batters/smithca05_batting.csv
# Saved batters/smithdo02_batting.csv
# Saved batters/smithjo11_batting.csv
# Saved batters/smithke04_batting.csv
# Saved batters/smithke05_batting.csv
# Saved batters/smithpa04_batting.csv
# Saved batters/soderty01_batting.csv
# Saved batters/smithwi05_batting.csv
# Saved batters/sogarer01_batting.csv
# Saved batters/sogarni01_batting.csv
# Saved batters/solakni01_batting.csv
# Saved batters/solando01_batting.csv
# Saved batters/solerjo01_batting.csv
# Saved batters/sosale01_batting.csv
# Saved batters/sotoli01_batting.csv
# Saved batters/sosaed01_batting.csv
# Saved batters/souzast01_batting.csv
# Saved batters/sotoju01_batting.csv
# Saved batters/spangco01_batting.csv
# Saved batters/springe01_batting.csv
# Saved batters/stallja01_batting.csv
# Saved batters/stassma01_batting.csv
# Saved batters/stefami01_batting.csv
# Saved batters/stephty01_batting.csv
# Saved batters/steersp01_batting.csv
# Saved batters/stevean01_batting.csv
# Saved batters/stantmi03_batting.csv
# Saved batters/steveca01_batting.csv
# Saved batters/stoketr01_batting.csv
# Saved batters/storytr01_batting.csv
# Saved batters/stoweky01_batting.csv
# Saved batters/stewadj01_batting.csv
# Saved batters/stubbga01_batting.csv
# Saved batters/strawmy01_batting.csv
# Saved batters/stottbr01_batting.csv
# Saved batters/sullibr01_batting.csv
# Saved batters/suareeu01_batting.csv
# Saved batters/swaggtr01_batting.csv
# Saved batters/suzukku01_batting.csv
# Saved batters/sweentr01_batting.csv
# Saved batters/suwinja01_batting.csv
# Saved batters/suzukse01_batting.csv
# Saved batters/swansda01_batting.csv
# Saved batters/tapiara01_batting.csv
# Saved batters/tatisfe02_batting.csv
# Saved batters/tauchmi01_batting.csv
# Saved batters/taverle01_batting.csv
# Saved batters/taylosa04_batting.csv
# Saved batters/tayloch03_batting.csv
# Saved batters/taylomi02_batting.csv
# Saved batters/tayloty01_batting.csv
# Saved batters/tejedan01_batting.csv
# Saved batters/terrycu01_batting.csv
# Saved batters/tenajo01_batting.csv
# Saved batters/tellero01_batting.csv
# Saved batters/teodobr01_batting.csv
# Saved batters/thomaal01_batting.csv
# Saved batters/thaisma01_batting.csv
# Saved batters/thomaco01_batting.csv
# Saved batters/thomadi01_batting.csv
# Saved batters/thompbu01_batting.csv
# Saved batters/thomptr01_batting.csv
# Saved batters/tomka01_batting.csv
# Saved batters/toglimi01_batting.csv
# Saved batters/thomala02_batting.csv
# Saved batters/torkesp01_batting.csv
# Saved batters/toroab01_batting.csv
# Saved batters/torregl01_batting.csv
# Saved batters/torrero01_batting.csv
# Saved batters/tovarwi01_batting.csv
# Saved batters/torrelu01_batting.csv
# Saved batters/tovarez01_batting.csv
# Saved batters/trammta01_batting.csv
# Saved batters/trejoal01_batting.csv
# Saved batters/trevijo01_batting.csv
# Saved batters/trompch01_batting.csv
# Saved batters/triolja01_batting.csv
# Saved batters/tuckeco01_batting.csv
# Saved batters/tsutsyo01_batting.csv
# Saved batters/troutmi01_batting.csv
# Saved batters/tuckeky01_batting.csv
# Saved batters/turanbr02_batting.csv
# Saved batters/turneju01_batting.csv
# Saved batters/uptonju01_batting.csv
# Saved batters/uriaslu01_batting.csv
# Saved batters/turnetr01_batting.csv
# Saved batters/uriasra01_batting.csv
# Saved batters/valaipa01_batting.csv
# Saved batters/urshegi01_batting.csv
# Saved batters/valdeen01_batting.csv
# Saved batters/valerbr01_batting.csv
# Saved batters/vanmejo01_batting.csv
# Saved batters/vargail01_batting.csv
# Saved batters/vargami01_batting.csv
# Saved batters/vaughan01_batting.csv
# Saved batters/varshda01_batting.csv
# Saved batters/vavrate01_batting.csv
# Saved batters/vazquch01_batting.csv
# Saved batters/vazqulu01_batting.csv
# Saved batters/velazan01_batting.csv
# Saved batters/velazne01_batting.csv
# Saved batters/verdual01_batting.csv
# Saved batters/viladry01_batting.csv
# Saved batters/vierlma01_batting.csv
# Saved batters/vientma01_batting.csv
# Saved batters/villada01_batting.csv
# Saved batters/villajo01_batting.csv
# Saved batters/vilorme01_batting.csv
# Saved batters/vogelda01_batting.csv
# Saved batters/vogtst01_batting.csv
# Saved batters/voitlu01_batting.csv
# Saved batters/volpean01_batting.csv
# Saved batters/vosleja01_batting.csv
# Saved batters/vottojo01_batting.csv
# Saved batters/wadety01_batting.csv
# Saved batters/wadela01_batting.csv
# Saved batters/wagamer01_batting.csv
# Saved batters/wagnewi01_batting.csv
# Saved batters/walkejo02_batting.csv
# Saved batters/walkest01_batting.csv
# Saved batters/walkech02_batting.csv
# Saved batters/wallach01_batting.csv
# Saved batters/wallfo01_batting.csv
# Saved batters/wallnma01_batting.csv
# Saved batters/walshja01_batting.csv
# Saved batters/wallsta01_batting.csv
# Saved batters/waltodo01_batting.csv
# Saved batters/waterdr01_batting.csv
# Saved batters/welkeco01_batting.csv
# Saved batters/wardta01_batting.csv
# Saved batters/wellsau01_batting.csv
# Saved batters/wendljo01_batting.csv
# Saved batters/westbja02_batting.csv
# Saved batters/wendzda01_batting.csv
# Saved batters/whitcsh01_batting.csv
# Saved batters/westbjo01_batting.csv
# Saved batters/whiteaa01_batting.csv
# Saved batters/whiteev01_batting.csv
# Saved batters/whiteel04_batting.csv
# Saved batters/wiemejo01_batting.csv
# Saved batters/wilkest01_batting.csv
# Saved batters/willial04_batting.csv
# Saved batters/williju02_batting.csv
# Saved batters/willima10_batting.csv
# Saved batters/willilu01_batting.csv
# Saved batters/willini01_batting.csv
# Saved batters/wilsoco01_batting.csv
# Saved batters/wilsoja04_batting.csv
# Saved batters/wilsoja05_batting.csv
# Saved batters/wilsoma02_batting.csv
# Saved batters/wilsowe01_batting.csv
# Saved batters/winnma01_batting.csv
# Saved batters/wiselbr01_batting.csv
# Saved batters/winkeje01_batting.csv
# Saved batters/wisdopa01_batting.csv
# Saved batters/wolteto01_batting.csv
# Saved batters/wittbo02_batting.csv
# Saved batters/wongco01_batting.csv
# Saved batters/wongke01_batting.csv
# Saved batters/yanger01_batting.csv
# Saved batters/woodja03_batting.csv
# Saved batters/wongko01_batting.csv
# Saved batters/wynnsau01_batting.csv
# Saved batters/yastrmi01_batting.csv
# Saved batters/yelicch01_batting.csv
# Saved batters/yepezju01_batting.csv
# Saved batters/yorkeni01_batting.csv
# Saved batters/youngan02_batting.csv
# Saved batters/yoshima02_batting.csv
# Saved batters/youngja02_batting.csv
# Saved batters/youngja03_batting.csv
# Saved batters/zimmery01_batting.csv
# Saved batters/zavalse01_batting.csv
# Saved batters/zimmebr01_batting.csv
# Saved batters/nan_batting.csv
# Saved batters/nan_batting.csv
# No data for nan
# Saved batters/zuninmi01_batting.csv
# Saved batters/nan_batting.csv
# Processed 1066 batters

# %% [markdown]
# # PITCHERS

# %%
import requests
import pandas as pd
from datetime import datetime
import os

# --- CONFIG ---
player_id = 663158
bbref_id = 'suarero01'
current_year = datetime.now().year
years = list(range(2021, current_year + 1))
schedule_cache = {}
os.makedirs("pitchers", exist_ok=True)

# --- Field Translation ---
translation_map = {
    'inningsPitched': 'IP',
    'hits': 'H',
    'runs': 'R',
    'earnedRuns': 'ER',
    'baseOnBalls': 'BB',
    'strikeOuts': 'SO',
    'homeRuns': 'HR',
    'hitByPitch': 'HBP',
    'era': 'ERA',
    'fip': 'FIP',
    'battersFaced': 'BF',
    'pitchesThrown': 'Pit',
    'strikes': 'Str',
    'strikesLooking': 'StL',
    'strikesSwinging': 'StS',
    'groundOuts': 'GB',
    'flyOuts': 'FB',
    'inheritedRunners': 'IR',
    'inheritedRunnersScored': 'IS',
    'stolenBases': 'SB',
    'caughtStealing': 'CS',
    'pickoffs': 'PO',
    'atBats': 'AB',
    'doubles': '2B',
    'triples': '3B',
    'intentionalWalks': 'IBB',
    'groundIntoDoublePlay': 'GDP',
    'sacFlies': 'SF',
    'reachedOnError': 'ROE',
}

meta_columns = ['game_date', 'game_id', 'Team', 'Opp', 'away_id', 'home_id']
stat_columns = list(translation_map.values())
final_columns = meta_columns + stat_columns + ['dbl']

# --- Fetch schedule for mapping team + opponent + home/away ---
def get_schedule(team_id, season):
    key = (team_id, season)
    if key in schedule_cache:
        return schedule_cache[key]

    url = "https://statsapi.mlb.com/api/v1/schedule"
    params = {"teamId": team_id, "season": season, "sportId": 1}
    res = requests.get(url, params=params).json()
    sched = {}
    for date in res['dates']:
        for g in date['games']:
            gid = int(g['gamePk'])
            away = g['teams']['away']['team']['id']
            home = g['teams']['home']['team']['id']
            opp = home if away == team_id else away
            sched[gid] = {'Team': team_id, 'Opp': opp, 'away_id': away, 'home_id': home}
    schedule_cache[key] = sched
    return sched

# --- Fetch game logs for one pitcher ---
def fetch_pitcher_log(player_id):
    all_rows = []

    for season in years:
        url = f"https://statsapi.mlb.com/api/v1/people/{player_id}/stats"
        params = {"stats": "gameLog", "group": "pitching", "season": season}
        res = requests.get(url, params=params).json()

        if not res['stats'] or not res['stats'][0]['splits']:
            continue

        rows = []
        team_ids_used = set()

        for game in res['stats'][0]['splits']:
            raw = game['stat']
            row = {translation_map[k]: v for k, v in raw.items() if k in translation_map}
            row['game_id'] = game['game']['gamePk']
            row['game_date'] = game['date']
            team_id = game['team']['id']
            row['team_id'] = team_id
            team_ids_used.add(team_id)
            row['opp_id'] = game['opponent']['id']
            row['season'] = season
            rows.append(row)

        df = pd.DataFrame(rows)
        df['game_id'] = df['game_id'].astype(int)

        df['Team'] = None
        df['Opp'] = None
        df['away_id'] = None
        df['home_id'] = None

        for tid in team_ids_used:
            schedule = get_schedule(tid, season)
            for gid, game_row in df[df['team_id'] == tid].iterrows():
                info = schedule.get(game_row['game_id'], {})
                df.at[gid, 'Team'] = info.get('Team')
                df.at[gid, 'Opp'] = info.get('Opp')
                df.at[gid, 'away_id'] = info.get('away_id')
                df.at[gid, 'home_id'] = info.get('home_id')

        df['game_date'] = pd.to_datetime(df['game_date'])
        df = df.sort_values(['game_date', 'game_id'])
        dbl_counts = df.groupby('game_date').cumcount() + 1
        dbl_flags = df.groupby('game_date')['game_id'].transform('count')
        df['dbl'] = dbl_flags.where(dbl_flags > 1, None)
        df.loc[df['dbl'].notnull(), 'dbl'] = dbl_counts[df['dbl'].notnull()].astype(float)

        all_rows.append(df)

    if all_rows:
        final_df = pd.concat(all_rows)
        for col in final_columns:
            if col not in final_df.columns:
                final_df[col] = None
        final_df = final_df[final_columns]
        return final_df
    return None

# --- Run and save ---
df = fetch_pitcher_log(player_id)
if df is not None:
    filename = f"pitchers/{bbref_id}_pitching.csv"
    df.to_csv(filename, index=False)
    print(f"Saved {filename} with {len(df)} rows and {len(df.columns)} columns")
else:
    print("No data found")
# Out:
# Saved pitchers/suarero01_pitching.csv with 139 rows and 36 columns
