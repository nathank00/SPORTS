# %%
import os
import pandas as pd

def get_player_stats(bbref_id, player_type, game_id):
    """
    Get the player's stats for the specific game_id. If not available, return the most recent stats.
    """
    stats_dir = 'batters' if player_type == 'batting' else 'pitchers'
    stats_file = os.path.join(stats_dir, f'{bbref_id}_stats_{player_type}.csv')
    
    if not os.path.exists(stats_file):
        print(f"Stats file for {bbref_id} not found ({player_type}).")
        return None
    
    stats_df = pd.read_csv(stats_file)
    game_stats = stats_df[stats_df['game_id'] == game_id]
    
    if not game_stats.empty:
        return game_stats.iloc[0]
    else:
        return stats_df.iloc[-1]

def process_game(game_id):
    # Read the gamelog file
    game_file = f'gamelogs/game_{game_id}.csv'
    if not os.path.exists(game_file):
        print(f"Gamelog file for game {game_id} not found.")
        return
    
    game_df = pd.read_csv(game_file)
    game_data = game_df.iloc[0].to_dict()
    
    # Define relevant columns for batters and pitchers
    batter_columns = ['AVG_20', 'OBP_20', 'SLG_20', 'OPS_20', 'SB_20', 'CS_20', 'XB_20', 'TB_20', 'SO_20',
                      'AVG_5', 'OBP_5', 'SLG_5', 'OPS_5', 'SB_5', 'CS_5', 'XB_5', 'TB_5', 'SO_5']
    pitcher_columns = ['IP_real_20', 'ERA', 'H_20', 'BF_20', 'HR_20', 'R_20', 'ER_20', 'BB_20', 'SO_20', 'XB_against_20',
                       'TB_against_20', 'ERA_20', 'WHIP_20', 'IP_real_5', 'H_5', 'BF_5', 'HR_5', 'R_5', 'ER_5', 'BB_5',
                       'SO_5', 'XB_against_5', 'TB_against_5', 'ERA_5', 'WHIP_5']
    
    # Fetch stats for each batter
    for i in range(1, 10):
        for team in ['Away', 'Home']:
            bbref_id = game_data.get(f'{team}_Batter{i}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'batting', game_id)
                if stats is not None:
                    for col in batter_columns:
                        game_data[f'{team}_Batter{i}_{col}'] = stats.get(col, '')
            else:
                print(f'missing bbrefID for game {game_id}')

    # Fetch stats for each pitcher
    for team in ['Away', 'Home']:
        for i in range(1, 11):
            role = 'SP' if i == 1 else f'P_{i}'
            bbref_id = game_data.get(f'{team}_{role}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'pitching', game_id)
                if stats is not None:
                    for col in pitcher_columns:
                        game_data[f'{team}_{role}_{col}'] = stats.get(col, '')

    # Fetch stats for each bullpen pitcher
    for team in ['Away', 'Home']:
        for i in range(1, 15):  # Adjust the range according to your maximum expected number of bullpen pitchers
            role = f'bullpen_{i}'
            bbref_id = game_data.get(f'{team}_{role}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'pitching', game_id)
                if stats is not None:
                    for col in pitcher_columns:
                        game_data[f'{team}_{role}_{col}'] = stats.get(col, '')
    
    # Create a DataFrame from the updated game data
    updated_game_df = pd.DataFrame([game_data])
    
    # Save the updated game data to a new CSV file
    output_file = f'gamelogs/gamestats_{game_id}.csv'
    updated_game_df.to_csv(output_file, index=False)
    print(f"Processed and saved game stats for game {game_id} to {output_file}")

def process_recent_games(num_recent_games):
    game_pks_file = 'game_pks.csv'
    if not os.path.exists(game_pks_file):
        print(f"{game_pks_file} not found.")
        return

    game_pks_df = pd.read_csv(game_pks_file)
    recent_game_pks = game_pks_df.tail(num_recent_games)['game_id'].tolist()
    
    for game_id in recent_game_pks:
        process_game(game_id)

# Input the number of most recent games to process
num_recent_games = 50
process_recent_games(num_recent_games)
# Out:
# Processed and saved game stats for game 746122 to gamelogs/gamestats_746122.csv
# Stats file for hornba01 not found (pitching).
# Processed and saved game stats for game 745723 to gamelogs/gamestats_745723.csv
# Processed and saved game stats for game 745480 to gamelogs/gamestats_745480.csv
# Processed and saved game stats for game 744833 to gamelogs/gamestats_744833.csv
# Processed and saved game stats for game 746455 to gamelogs/gamestats_746455.csv
# Processed and saved game stats for game 746692 to gamelogs/gamestats_746692.csv
# Processed and saved game stats for game 746771 to gamelogs/gamestats_746771.csv
# Processed and saved game stats for game 746208 to gamelogs/gamestats_746208.csv
# Processed and saved game stats for game 747181 to gamelogs/gamestats_747181.csv
# Processed and saved game stats for game 747014 to gamelogs/gamestats_747014.csv
# Processed and saved game stats for game 746451 to gamelogs/gamestats_746451.csv
# Processed and saved game stats for game 745557 to gamelogs/gamestats_745557.csv
# Processed and saved game stats for game 745074 to gamelogs/gamestats_745074.csv
# Processed and saved game stats for game 746690 to gamelogs/gamestats_746690.csv
# Processed and saved game stats for game 745803 to gamelogs/gamestats_745803.csv
# Stats file for hornba01 not found (pitching).
# Processed and saved game stats for game 746937 to gamelogs/gamestats_746937.csv
# Processed and saved game stats for game 746368 to gamelogs/gamestats_746368.csv
# Processed and saved game stats for game 745968 to gamelogs/gamestats_745968.csv
# Processed and saved game stats for game 746206 to gamelogs/gamestats_746206.csv
# Processed and saved game stats for game 745393 to gamelogs/gamestats_745393.csv
# Processed and saved game stats for game 747180 to gamelogs/gamestats_747180.csv
# Processed and saved game stats for game 745316 to gamelogs/gamestats_745316.csv
# Stats file for penniwa01 not found (pitching).
# Processed and saved game stats for game 745155 to gamelogs/gamestats_745155.csv
# Processed and saved game stats for game 746773 to gamelogs/gamestats_746773.csv
# Stats file for penniwa01 not found (pitching).
# Processed and saved game stats for game 745155 to gamelogs/gamestats_745155.csv
# Stats file for penniwa01 not found (pitching).
# Processed and saved game stats for game 745156 to gamelogs/gamestats_745156.csv
# Processed and saved game stats for game 746207 to gamelogs/gamestats_746207.csv
# Processed and saved game stats for game 747175 to gamelogs/gamestats_747175.csv
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 745390 to gamelogs/gamestats_745390.csv
# Processed and saved game stats for game 745312 to gamelogs/gamestats_745312.csv
# Processed and saved game stats for game 746447 to gamelogs/gamestats_746447.csv
# Processed and saved game stats for game 746766 to gamelogs/gamestats_746766.csv
# Processed and saved game stats for game 745152 to gamelogs/gamestats_745152.csv
# Processed and saved game stats for game 745175 to gamelogs/gamestats_745175.csv
# Processed and saved game stats for game 745549 to gamelogs/gamestats_745549.csv
# Processed and saved game stats for game 747013 to gamelogs/gamestats_747013.csv
# Stats file for hornba01 not found (pitching).
# Processed and saved game stats for game 746930 to gamelogs/gamestats_746930.csv
# Processed and saved game stats for game 745798 to gamelogs/gamestats_745798.csv
# Processed and saved game stats for game 745067 to gamelogs/gamestats_745067.csv
# Processed and saved game stats for game 746369 to gamelogs/gamestats_746369.csv
# Processed and saved game stats for game 746687 to gamelogs/gamestats_746687.csv
# Processed and saved game stats for game 745963 to gamelogs/gamestats_745963.csv
# Processed and saved game stats for game 745311 to gamelogs/gamestats_745311.csv
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 745392 to gamelogs/gamestats_745392.csv
# Processed and saved game stats for game 746202 to gamelogs/gamestats_746202.csv
# Processed and saved game stats for game 747177 to gamelogs/gamestats_747177.csv
# Processed and saved game stats for game 747009 to gamelogs/gamestats_747009.csv
# Stats file for hornba01 not found (pitching).
# Processed and saved game stats for game 746932 to gamelogs/gamestats_746932.csv
# Processed and saved game stats for game 745551 to gamelogs/gamestats_745551.csv
# Processed and saved game stats for game 746449 to gamelogs/gamestats_746449.csv
# Processed and saved game stats for game 745797 to gamelogs/gamestats_745797.csv
# Processed and saved game stats for game 745066 to gamelogs/gamestats_745066.csv
# Processed and saved game stats for game 746686 to gamelogs/gamestats_746686.csv
# Processed and saved game stats for game 746370 to gamelogs/gamestats_746370.csv
# Processed and saved game stats for game 746769 to gamelogs/gamestats_746769.csv
# Processed and saved game stats for game 745962 to gamelogs/gamestats_745962.csv
# Processed and saved game stats for game 745151 to gamelogs/gamestats_745151.csv
# Processed and saved game stats for game 745314 to gamelogs/gamestats_745314.csv
# Processed and saved game stats for game 746201 to gamelogs/gamestats_746201.csv
# Stats file for eiserbr01 not found (pitching).
# Processed and saved game stats for game 747176 to gamelogs/gamestats_747176.csv
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 745385 to gamelogs/gamestats_745385.csv
# Processed and saved game stats for game 747298 to gamelogs/gamestats_747298.csv
