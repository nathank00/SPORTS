# %%
import os
import pandas as pd

def get_player_stats(bbref_id, player_type, game_id):
    """
    Get the player's stats for the specific game_id. If not available, return the most recent stats.
    """
    stats_dir = 'batters' if player_type == 'batting' else 'pitchers'
    stats_file = os.path.join(stats_dir, f'{bbref_id}_stats_{player_type}.csv')
    
    if not os.path.exists(stats_file):
        print(f"Stats file for {bbref_id} not found ({player_type}).")
        return None
    
    stats_df = pd.read_csv(stats_file)
    game_stats = stats_df[stats_df['game_id'] == game_id]
    
    if not game_stats.empty:
        return game_stats.iloc[0]
    else:
        return stats_df.iloc[-1]

def process_game(game_id):
    # Read the gamelog file
    game_file = f'gamelogs/game_{game_id}.csv'
    if not os.path.exists(game_file):
        print(f"Gamelog file for game {game_id} not found.")
        return
    
    game_df = pd.read_csv(game_file)
    game_data = game_df.iloc[0].to_dict()
    
    # Define relevant columns for batters and pitchers
    batter_columns = ['AVG_20', 'OBP_20', 'SLG_20', 'OPS_20', 'SB_20', 'CS_20', 'XB_20', 'TB_20', 'SO_20',
                      'AVG_5', 'OBP_5', 'SLG_5', 'OPS_5', 'SB_5', 'CS_5', 'XB_5', 'TB_5', 'SO_5']
    pitcher_columns = ['IP_real_20', 'ERA', 'H_20', 'BF_20', 'HR_20', 'R_20', 'ER_20', 'BB_20', 'SO_20', 'XB_against_20',
                       'TB_against_20', 'ERA_20', 'WHIP_20', 'IP_real_5', 'H_5', 'BF_5', 'HR_5', 'R_5', 'ER_5', 'BB_5',
                       'SO_5', 'XB_against_5', 'TB_against_5', 'ERA_5', 'WHIP_5']
    
    # Fetch stats for each batter
    for i in range(1, 10):
        for team in ['Away', 'Home']:
            bbref_id = game_data.get(f'{team}_Batter{i}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'batting', game_id)
                if stats is not None:
                    for col in batter_columns:
                        game_data[f'{team}_Batter{i}_{col}'] = stats.get(col, '')
            else:
                print(f'missing bbrefID for game {game_id}')

    # Fetch stats for each pitcher
    for team in ['Away', 'Home']:
        for i in range(1, 11):
            role = 'SP' if i == 1 else f'P_{i}'
            bbref_id = game_data.get(f'{team}_{role}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'pitching', game_id)
                if stats is not None:
                    for col in pitcher_columns:
                        game_data[f'{team}_{role}_{col}'] = stats.get(col, '')

    # Fetch stats for each bullpen pitcher
    for team in ['Away', 'Home']:
        for i in range(1, 15):  # Adjust the range according to your maximum expected number of bullpen pitchers
            role = f'bullpen_{i}'
            bbref_id = game_data.get(f'{team}_{role}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'pitching', game_id)
                if stats is not None:
                    for col in pitcher_columns:
                        game_data[f'{team}_{role}_{col}'] = stats.get(col, '')
    
    # Create a DataFrame from the updated game data
    updated_game_df = pd.DataFrame([game_data])
    
    # Save the updated game data to a new CSV file
    output_file = f'gamelogs/gamestats_{game_id}.csv'
    updated_game_df.to_csv(output_file, index=False)
    print(f"Processed and saved game stats for game {game_id} to {output_file}")

def process_recent_games(num_recent_games):
    game_pks_file = 'game_pks.csv'
    if not os.path.exists(game_pks_file):
        print(f"{game_pks_file} not found.")
        return

    game_pks_df = pd.read_csv(game_pks_file)
    recent_game_pks = game_pks_df.tail(num_recent_games)['game_id'].tolist()
    
    for game_id in recent_game_pks:
        process_game(game_id)

# Input the number of most recent games to process
num_recent_games = 50
process_recent_games(num_recent_games)
# Out:
# Processed and saved game stats for game 745563 to gamelogs/gamestats_745563.csv
# Processed and saved game stats for game 744843 to gamelogs/gamestats_744843.csv
# Stats file for unknown not found (batting).
# Processed and saved game stats for game 745733 to gamelogs/gamestats_745733.csv
# Processed and saved game stats for game 744917 to gamelogs/gamestats_744917.csv
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 747107 to gamelogs/gamestats_747107.csv
# Processed and saved game stats for game 745893 to gamelogs/gamestats_745893.csv
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746867 to gamelogs/gamestats_746867.csv
# Processed and saved game stats for game 745004 to gamelogs/gamestats_745004.csv
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746783 to gamelogs/gamestats_746783.csv
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746542 to gamelogs/gamestats_746542.csv
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746217 to gamelogs/gamestats_746217.csv
# Processed and saved game stats for game 745650 to gamelogs/gamestats_745650.csv
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 747106 to gamelogs/gamestats_747106.csv
# Processed and saved game stats for game 745489 to gamelogs/gamestats_745489.csv
# Processed and saved game stats for game 746050 to gamelogs/gamestats_746050.csv
# Processed and saved game stats for game 745561 to gamelogs/gamestats_745561.csv
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746864 to gamelogs/gamestats_746864.csv
# Processed and saved game stats for game 744842 to gamelogs/gamestats_744842.csv
# Processed and saved game stats for game 746625 to gamelogs/gamestats_746625.csv
# Stats file for unknown not found (batting).
# Processed and saved game stats for game 745732 to gamelogs/gamestats_745732.csv
# Processed and saved game stats for game 744920 to gamelogs/gamestats_744920.csv
# Processed and saved game stats for game 745887 to gamelogs/gamestats_745887.csv
# Processed and saved game stats for game 745002 to gamelogs/gamestats_745002.csv
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746781 to gamelogs/gamestats_746781.csv
# Stats file for unknown not found (batting).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746538 to gamelogs/gamestats_746538.csv
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746219 to gamelogs/gamestats_746219.csv
# Processed and saved game stats for game 745646 to gamelogs/gamestats_745646.csv
# Processed and saved game stats for game 744841 to gamelogs/gamestats_744841.csv
# Stats file for unknown not found (batting).
# Processed and saved game stats for game 746626 to gamelogs/gamestats_746626.csv
# Processed and saved game stats for game 745889 to gamelogs/gamestats_745889.csv
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746782 to gamelogs/gamestats_746782.csv
# Stats file for unknown not found (batting).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746539 to gamelogs/gamestats_746539.csv
# Processed and saved game stats for game 745645 to gamelogs/gamestats_745645.csv
# Processed and saved game stats for game 745734 to gamelogs/gamestats_745734.csv
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 745164 to gamelogs/gamestats_745164.csv
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 745401 to gamelogs/gamestats_745401.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746861 to gamelogs/gamestats_746861.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 745483 to gamelogs/gamestats_745483.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 745562 to gamelogs/gamestats_745562.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746460 to gamelogs/gamestats_746460.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 745729 to gamelogs/gamestats_745729.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746698 to gamelogs/gamestats_746698.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746624 to gamelogs/gamestats_746624.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746052 to gamelogs/gamestats_746052.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 745006 to gamelogs/gamestats_745006.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746375 to gamelogs/gamestats_746375.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746540 to gamelogs/gamestats_746540.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 745649 to gamelogs/gamestats_745649.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for unknown not found (pitching).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 745403 to gamelogs/gamestats_745403.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746131 to gamelogs/gamestats_746131.csv
