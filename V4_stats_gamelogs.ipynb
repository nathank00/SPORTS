# %%
import os
import pandas as pd

def get_player_stats(bbref_id, player_type, game_id):
    """
    Get the player's stats for the specific game_id. If not available, return the most recent stats.
    """
    stats_dir = 'batters' if player_type == 'batting' else 'pitchers'
    stats_file = os.path.join(stats_dir, f'{bbref_id}_stats_{player_type}.csv')
    
    if not os.path.exists(stats_file):
        print(f"Stats file for {bbref_id} not found ({player_type}).")
        return None
    
    stats_df = pd.read_csv(stats_file)
    game_stats = stats_df[stats_df['game_id'] == game_id]
    
    if not game_stats.empty:
        return game_stats.iloc[0]
    else:
        return stats_df.iloc[-1]

def process_game(game_id):
    # Read the gamelog file
    game_file = f'gamelogs/game_{game_id}.csv'
    if not os.path.exists(game_file):
        print(f"Gamelog file for game {game_id} not found.")
        return
    
    game_df = pd.read_csv(game_file)
    game_data = game_df.iloc[0].to_dict()
    
    # Define relevant columns for batters and pitchers
    batter_columns = ['AVG_20', 'OBP_20', 'SLG_20', 'OPS_20', 'SB_20', 'CS_20', 'XB_20', 'TB_20', 'SO_20',
                      'AVG_5', 'OBP_5', 'SLG_5', 'OPS_5', 'SB_5', 'CS_5', 'XB_5', 'TB_5', 'SO_5']
    pitcher_columns = ['IP_real_20', 'ERA', 'H_20', 'BF_20', 'HR_20', 'R_20', 'ER_20', 'BB_20', 'SO_20', 'XB_against_20',
                       'TB_against_20', 'ERA_20', 'WHIP_20', 'IP_real_5', 'H_5', 'BF_5', 'HR_5', 'R_5', 'ER_5', 'BB_5',
                       'SO_5', 'XB_against_5', 'TB_against_5', 'ERA_5', 'WHIP_5']
    
    # Fetch stats for each batter
    for i in range(1, 10):
        for team in ['Away', 'Home']:
            bbref_id = game_data.get(f'{team}_Batter{i}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'batting', game_id)
                if stats is not None:
                    for col in batter_columns:
                        game_data[f'{team}_Batter{i}_{col}'] = stats.get(col, '')
            else:
                print(f'missing bbrefID for game {game_id}')

    # Fetch stats for each pitcher
    for team in ['Away', 'Home']:
        for i in range(1, 11):
            role = 'SP' if i == 1 else f'P_{i}'
            bbref_id = game_data.get(f'{team}_{role}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'pitching', game_id)
                if stats is not None:
                    for col in pitcher_columns:
                        game_data[f'{team}_{role}_{col}'] = stats.get(col, '')

    # Fetch stats for each bullpen pitcher
    for team in ['Away', 'Home']:
        for i in range(1, 15):  # Adjust the range according to your maximum expected number of bullpen pitchers
            role = f'bullpen_{i}'
            bbref_id = game_data.get(f'{team}_{role}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'pitching', game_id)
                if stats is not None:
                    for col in pitcher_columns:
                        game_data[f'{team}_{role}_{col}'] = stats.get(col, '')
    
    # Create a DataFrame from the updated game data
    updated_game_df = pd.DataFrame([game_data])
    
    # Save the updated game data to a new CSV file
    output_file = f'gamelogs/gamestats_{game_id}.csv'
    updated_game_df.to_csv(output_file, index=False)
    print(f"Processed and saved game stats for game {game_id} to {output_file}")

def process_recent_games(num_recent_games):
    game_pks_file = 'game_pks.csv'
    if not os.path.exists(game_pks_file):
        print(f"{game_pks_file} not found.")
        return

    game_pks_df = pd.read_csv(game_pks_file)
    recent_game_pks = game_pks_df.tail(num_recent_games)['game_id'].tolist()
    
    for game_id in recent_game_pks:
        process_game(game_id)

# Input the number of most recent games to process
num_recent_games = 50
process_recent_games(num_recent_games)
# Out:
# Processed and saved game stats for game 746282 to gamelogs/gamestats_746282.csv
# Processed and saved game stats for game 746537 to gamelogs/gamestats_746537.csv
# Processed and saved game stats for game 745647 to gamelogs/gamestats_745647.csv
# Processed and saved game stats for game 745240 to gamelogs/gamestats_745240.csv
# Processed and saved game stats for game 746133 to gamelogs/gamestats_746133.csv
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 745487 to gamelogs/gamestats_745487.csv
# Processed and saved game stats for game 746617 to gamelogs/gamestats_746617.csv
# Stats file for nan not found (pitching).
# Processed and saved game stats for game 746045 to gamelogs/gamestats_746045.csv
# Stats file for unknown not found (batting).
# Processed and saved game stats for game 744837 to gamelogs/gamestats_744837.csv
# Processed and saved game stats for game 745728 to gamelogs/gamestats_745728.csv
# Processed and saved game stats for game 744915 to gamelogs/gamestats_744915.csv
# Processed and saved game stats for game 747100 to gamelogs/gamestats_747100.csv
# Processed and saved game stats for game 744998 to gamelogs/gamestats_744998.csv
# Processed and saved game stats for game 746858 to gamelogs/gamestats_746858.csv
# Processed and saved game stats for game 746283 to gamelogs/gamestats_746283.csv
# Stats file for unknown not found (batting).
# Processed and saved game stats for game 745888 to gamelogs/gamestats_745888.csv
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746534 to gamelogs/gamestats_746534.csv
# Processed and saved game stats for game 745643 to gamelogs/gamestats_745643.csv
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 746128 to gamelogs/gamestats_746128.csv
# Processed and saved game stats for game 745234 to gamelogs/gamestats_745234.csv
# Stats file for unknown not found (batting).
# Processed and saved game stats for game 744834 to gamelogs/gamestats_744834.csv
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 745484 to gamelogs/gamestats_745484.csv
# Processed and saved game stats for game 745726 to gamelogs/gamestats_745726.csv
# Stats file for unknown not found (batting).
# Processed and saved game stats for game 744912 to gamelogs/gamestats_744912.csv
# Stats file for unknown not found (batting).
# Processed and saved game stats for game 745890 to gamelogs/gamestats_745890.csv
# Processed and saved game stats for game 746619 to gamelogs/gamestats_746619.csv
# Stats file for nan not found (pitching).
# Processed and saved game stats for game 746043 to gamelogs/gamestats_746043.csv
# Processed and saved game stats for game 746857 to gamelogs/gamestats_746857.csv
# Processed and saved game stats for game 744996 to gamelogs/gamestats_744996.csv
# Processed and saved game stats for game 745641 to gamelogs/gamestats_745641.csv
# Processed and saved game stats for game 745236 to gamelogs/gamestats_745236.csv
# Processed and saved game stats for game 747103 to gamelogs/gamestats_747103.csv
# Processed and saved game stats for game 746285 to gamelogs/gamestats_746285.csv
# Processed and saved game stats for game 746532 to gamelogs/gamestats_746532.csv
# Processed and saved game stats for game 746126 to gamelogs/gamestats_746126.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746859 to gamelogs/gamestats_746859.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 745479 to gamelogs/gamestats_745479.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 744836 to gamelogs/gamestats_744836.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (pitching).
# Processed and saved game stats for game 745725 to gamelogs/gamestats_745725.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746693 to gamelogs/gamestats_746693.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746620 to gamelogs/gamestats_746620.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746046 to gamelogs/gamestats_746046.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 747097 to gamelogs/gamestats_747097.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 744992 to gamelogs/gamestats_744992.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746533 to gamelogs/gamestats_746533.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 745884 to gamelogs/gamestats_745884.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 745639 to gamelogs/gamestats_745639.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 745398 to gamelogs/gamestats_745398.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 745237 to gamelogs/gamestats_745237.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746127 to gamelogs/gamestats_746127.csv
