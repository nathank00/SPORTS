# %%
import os
import pandas as pd

def get_player_stats(bbref_id, player_type, game_id):
    """
    Get the player's stats for the specific game_id. If not available, return the most recent stats.
    """
    stats_dir = 'batters' if player_type == 'batting' else 'pitchers'
    stats_file = os.path.join(stats_dir, f'{bbref_id}_stats_{player_type}.csv')
    
    if not os.path.exists(stats_file):
        print(f"Stats file for {bbref_id} not found ({player_type}).")
        return None
    
    stats_df = pd.read_csv(stats_file)
    game_stats = stats_df[stats_df['game_id'] == game_id]
    
    if not game_stats.empty:
        return game_stats.iloc[0]
    else:
        return stats_df.iloc[-1]

def process_game(game_id):
    # Read the gamelog file
    game_file = f'gamelogs/game_{game_id}.csv'
    if not os.path.exists(game_file):
        print(f"Gamelog file for game {game_id} not found.")
        return
    
    game_df = pd.read_csv(game_file)
    game_data = game_df.iloc[0].to_dict()
    
    # Define relevant columns for batters and pitchers
    batter_columns = ['AVG_20', 'OBP_20', 'SLG_20', 'OPS_20', 'SB_20', 'CS_20', 'XB_20', 'TB_20', 'SO_20',
                      'AVG_5', 'OBP_5', 'SLG_5', 'OPS_5', 'SB_5', 'CS_5', 'XB_5', 'TB_5', 'SO_5']
    pitcher_columns = ['IP_real_20', 'ERA', 'H_20', 'BF_20', 'HR_20', 'R_20', 'ER_20', 'BB_20', 'SO_20', 'XB_against_20',
                       'TB_against_20', 'ERA_20', 'WHIP_20', 'IP_real_5', 'H_5', 'BF_5', 'HR_5', 'R_5', 'ER_5', 'BB_5',
                       'SO_5', 'XB_against_5', 'TB_against_5', 'ERA_5', 'WHIP_5']
    
    # Fetch stats for each batter
    for i in range(1, 10):
        for team in ['Away', 'Home']:
            bbref_id = game_data.get(f'{team}_Batter{i}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'batting', game_id)
                if stats is not None:
                    for col in batter_columns:
                        game_data[f'{team}_Batter{i}_{col}'] = stats.get(col, '')
            else:
                print(f'missing bbrefID for game {game_id}')

    # Fetch stats for each pitcher
    for team in ['Away', 'Home']:
        for i in range(1, 11):
            role = 'SP' if i == 1 else f'P_{i}'
            bbref_id = game_data.get(f'{team}_{role}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'pitching', game_id)
                if stats is not None:
                    for col in pitcher_columns:
                        game_data[f'{team}_{role}_{col}'] = stats.get(col, '')

    # Fetch stats for each bullpen pitcher
    for team in ['Away', 'Home']:
        for i in range(1, 15):  # Adjust the range according to your maximum expected number of bullpen pitchers
            role = f'bullpen_{i}'
            bbref_id = game_data.get(f'{team}_{role}_bbrefID')
            if bbref_id:
                stats = get_player_stats(bbref_id, 'pitching', game_id)
                if stats is not None:
                    for col in pitcher_columns:
                        game_data[f'{team}_{role}_{col}'] = stats.get(col, '')
    
    # Create a DataFrame from the updated game data
    updated_game_df = pd.DataFrame([game_data])
    
    # Save the updated game data to a new CSV file
    output_file = f'gamelogs/gamestats_{game_id}.csv'
    updated_game_df.to_csv(output_file, index=False)
    print(f"Processed and saved game stats for game {game_id} to {output_file}")

def process_recent_games(num_recent_games):
    game_pks_file = 'game_pks.csv'
    if not os.path.exists(game_pks_file):
        print(f"{game_pks_file} not found.")
        return

    game_pks_df = pd.read_csv(game_pks_file)
    recent_game_pks = game_pks_df.tail(num_recent_games)['game_id'].tolist()
    
    for game_id in recent_game_pks:
        process_game(game_id)

# Input the number of most recent games to process
num_recent_games = 50
process_recent_games(num_recent_games)
# Out:
# Processed and saved game stats for game 746288 to gamelogs/gamestats_746288.csv
# Processed and saved game stats for game 746210 to gamelogs/gamestats_746210.csv
# Processed and saved game stats for game 745560 to gamelogs/gamestats_745560.csv
# Processed and saved game stats for game 745070 to gamelogs/gamestats_745070.csv
# Processed and saved game stats for game 747017 to gamelogs/gamestats_747017.csv
# Processed and saved game stats for game 744922 to gamelogs/gamestats_744922.csv
# Processed and saved game stats for game 745804 to gamelogs/gamestats_745804.csv
# Stats file for nan not found (pitching).
# Processed and saved game stats for game 746939 to gamelogs/gamestats_746939.csv
# Processed and saved game stats for game 746776 to gamelogs/gamestats_746776.csv
# Processed and saved game stats for game 747105 to gamelogs/gamestats_747105.csv
# Processed and saved game stats for game 746292 to gamelogs/gamestats_746292.csv
# Processed and saved game stats for game 745970 to gamelogs/gamestats_745970.csv
# Stats file for nan not found (pitching).
# Processed and saved game stats for game 745161 to gamelogs/gamestats_745161.csv
# Processed and saved game stats for game 746214 to gamelogs/gamestats_746214.csv
# Processed and saved game stats for game 747183 to gamelogs/gamestats_747183.csv
# Processed and saved game stats for game 745238 to gamelogs/gamestats_745238.csv
# Processed and saved game stats for game 745319 to gamelogs/gamestats_745319.csv
# Processed and saved game stats for game 746778 to gamelogs/gamestats_746778.csv
# Stats file for nan not found (pitching).
# Stats file for nan not found (pitching).
# Processed and saved game stats for game 745159 to gamelogs/gamestats_745159.csv
# Processed and saved game stats for game 744921 to gamelogs/gamestats_744921.csv
# Processed and saved game stats for game 745559 to gamelogs/gamestats_745559.csv
# Processed and saved game stats for game 746289 to gamelogs/gamestats_746289.csv
# Processed and saved game stats for game 745801 to gamelogs/gamestats_745801.csv
# Processed and saved game stats for game 747186 to gamelogs/gamestats_747186.csv
# Stats file for nan not found (pitching).
# Stats file for nan not found (pitching).
# Processed and saved game stats for game 746940 to gamelogs/gamestats_746940.csv
# Processed and saved game stats for game 745071 to gamelogs/gamestats_745071.csv
# Processed and saved game stats for game 747104 to gamelogs/gamestats_747104.csv
# Processed and saved game stats for game 745972 to gamelogs/gamestats_745972.csv
# Processed and saved game stats for game 745317 to gamelogs/gamestats_745317.csv
# Processed and saved game stats for game 747018 to gamelogs/gamestats_747018.csv
# Processed and saved game stats for game 746211 to gamelogs/gamestats_746211.csv
# Processed and saved game stats for game 745239 to gamelogs/gamestats_745239.csv
# Processed and saved game stats for game 747101 to gamelogs/gamestats_747101.csv
# Stats file for nan not found (pitching).
# Processed and saved game stats for game 746938 to gamelogs/gamestats_746938.csv
# Processed and saved game stats for game 745555 to gamelogs/gamestats_745555.csv
# Processed and saved game stats for game 744916 to gamelogs/gamestats_744916.csv
# Processed and saved game stats for game 745802 to gamelogs/gamestats_745802.csv
# Processed and saved game stats for game 745072 to gamelogs/gamestats_745072.csv
# Processed and saved game stats for game 746290 to gamelogs/gamestats_746290.csv
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746779 to gamelogs/gamestats_746779.csv
# Processed and saved game stats for game 745971 to gamelogs/gamestats_745971.csv
# Stats file for unknown not found (pitching).
# Processed and saved game stats for game 745154 to gamelogs/gamestats_745154.csv
# Processed and saved game stats for game 745320 to gamelogs/gamestats_745320.csv
# Processed and saved game stats for game 746209 to gamelogs/gamestats_746209.csv
# Processed and saved game stats for game 747182 to gamelogs/gamestats_747182.csv
# Processed and saved game stats for game 745243 to gamelogs/gamestats_745243.csv
# Processed and saved game stats for game 747016 to gamelogs/gamestats_747016.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 744914 to gamelogs/gamestats_744914.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 744840 to gamelogs/gamestats_744840.csv
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Stats file for nan not found (batting).
# Processed and saved game stats for game 746535 to gamelogs/gamestats_746535.csv
