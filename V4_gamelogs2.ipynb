# %%
import requests
import pandas as pd
from datetime import datetime
from pybaseball import playerid_reverse_lookup

# Load game_pks.csv to get team names and IDs
game_pks_df = pd.read_csv('game_pks.csv')

# Mapping of team 3-digit IDs to oddshark 5-digit IDs 
team_to_oddshark_id = {
    120: 27017, 146: 27022, 139: 27003, 144: 27009, 140: 27002, 117: 27023,
    135: 26996, 143: 26995, 110: 27008, 136: 27011, 121: 27014, 109: 27007,
    108: 26998, 133: 27016, 141: 27010, 114: 27014, 138: 27019, 142: 27005,
    116: 26999, 147: 27001, 137: 26997, 118: 27006, 145: 27018, 115: 27004,
    111: 27021, 119: 27015, 112: 27020, 158: 27012, 113: 27000, 134: 27013
}

errors = []

def get_game_data(gamepk):
    url = f"https://statsapi.mlb.com/api/v1.1/game/{gamepk}/feed/live"
    response = requests.get(url)
    return response.json()

def get_bbref_id(mlbam_id):
    try:
        lookup_df = playerid_reverse_lookup([mlbam_id], key_type='mlbam')
        bbref_id = lookup_df.loc[lookup_df['key_mlbam'] == mlbam_id, 'key_bbref'].values[0]
        return bbref_id
    except IndexError:
        return 'unknown'

def extract_starting_lineup(game_data, team_side):
    lineup = {}
    team = game_data['liveData']['boxscore']['teams'][team_side]['players']
    
    for player_id, player_info in team.items():
        try:
            if 'battingOrder' in player_info and int(player_info['battingOrder']) % 100 == 0:
                order = int(player_info['battingOrder']) // 100
                mlbam_id = player_info['person']['id']
                bbref_id = get_bbref_id(mlbam_id)
                lineup[order] = {
                    'name': player_info['person']['fullName'],
                    'mlbam_id': mlbam_id,
                    'bbref_id': bbref_id
                }
        except Exception as e:
            errors.append((gamepk, f"Error processing player {player_id} in {team_side} lineup: {str(e)}"))
    
    # Ensure lineup is filled and sorted by batting order
    return [lineup.get(i, {'name': '', 'mlbam_id': '', 'bbref_id': ''}) for i in range(1, 9)]

def get_pitchers(game_data, team_side):
    team = game_data['liveData']['boxscore']['teams'][team_side]
    pitchers = []
    for idx, pitcher_id in enumerate(team['pitchers']):
        try:
            pitcher = team['players'][f'ID{pitcher_id}']
            mlbam_id = pitcher['person']['id']
            bbref_id = get_bbref_id(mlbam_id)
            pitchers.append({
                'name': pitcher['person']['fullName'],
                'mlbam_id': mlbam_id,
                'bbref_id': bbref_id,
                'order': idx + 1
            })
        except Exception as e:
            errors.append((gamepk, f"Error processing pitcher {pitcher_id} in {team_side} team: {str(e)}"))
    return pitchers

def create_game_dataframe(gamepk):
    game_data = get_game_data(gamepk)
    
    try:
        home_lineup = extract_starting_lineup(game_data, 'home')
        away_lineup = extract_starting_lineup(game_data, 'away')
    except Exception as e:
        errors.append((gamepk, f"Error extracting lineups: {str(e)}"))
        return pd.DataFrame()
    
    try:
        home_pitchers = get_pitchers(game_data, 'home')
        away_pitchers = get_pitchers(game_data, 'away')
    except Exception as e:
        errors.append((gamepk, f"Error extracting pitchers: {str(e)}"))
        return pd.DataFrame()
    
    # Get additional game information
    game_info = game_pks_df[game_pks_df['game_id'] == gamepk].iloc[0]
    
    try:
        game_date = game_info['game_date']
    except KeyError:
        game_date = 'unknown'
        errors.append((gamepk, "Error getting game date"))
    
    try:
        runs_home = game_data['liveData']['linescore']['teams']['home']['runs']
    except KeyError:
        runs_home = 0
        errors.append((gamepk, "Error getting home runs"))
    
    try:
        runs_away = game_data['liveData']['linescore']['teams']['away']['runs']
    except KeyError:
        runs_away = 0
        errors.append((gamepk, "Error getting away runs"))
    
    runs_total = runs_home + runs_away
    
    # Get team information from game_pks.csv
    home_id = game_info['home_id']
    away_id = game_info['away_id']
    home_name = game_info['home_name']
    away_name = game_info['away_name']
    
    # Check for invalid team IDs
    if home_id not in team_to_oddshark_id or away_id not in team_to_oddshark_id:
        print(f"Invalid team IDs - {home_name} {home_id} vs {away_name} {away_id}")
    
    home_oddshark_id = team_to_oddshark_id.get(home_id, 'unknown')
    away_oddshark_id = team_to_oddshark_id.get(away_id, 'unknown')
    
    game_record = {
        'game_id': gamepk, 'game_date': game_date, 'runs_home': runs_home, 'runs_away': runs_away, 'runs_total': runs_total,
        'home_id': home_id, 'home_name': home_name, 'away_id': away_id, 'away_name': away_name,
        'home_oddshark_id': home_oddshark_id, 'away_oddshark_id': away_oddshark_id
    }

    for i, player in enumerate(away_lineup, start=1):
        game_record[f'Away_Batter{i}_Name'] = player['name']
        game_record[f'Away_Batter{i}_ID'] = player['mlbam_id']
        game_record[f'Away_Batter{i}_bbrefID'] = player['bbref_id']
        
    for i, player in enumerate(home_lineup, start=1):
        game_record[f'Home_Batter{i}_Name'] = player['name']
        game_record[f'Home_Batter{i}_ID'] = player['mlbam_id']
        game_record[f'Home_Batter{i}_bbrefID'] = player['bbref_id']
    
    # Add starting pitchers
    if home_pitchers:
        game_record['Home_SP_Name'] = home_pitchers[0]['name']
        game_record['Home_SP_ID'] = home_pitchers[0]['mlbam_id']
        game_record['Home_SP_bbrefID'] = home_pitchers[0]['bbref_id']
    
    if away_pitchers:
        game_record['Away_SP_Name'] = away_pitchers[0]['name']
        game_record['Away_SP_ID'] = away_pitchers[0]['mlbam_id']
        game_record['Away_SP_bbrefID'] = away_pitchers[0]['bbref_id']
    
    # Add remaining pitchers
    for i, pitcher in enumerate(home_pitchers[1:], start=2):
        game_record[f'Home_P_{i}_Name'] = pitcher['name']
        game_record[f'Home_P_{i}_ID'] = pitcher['mlbam_id']
        game_record[f'Home_P_{i}_bbrefID'] = pitcher['bbref_id']
    
    for i, pitcher in enumerate(away_pitchers[1:], start=2):
        game_record[f'Away_P_{i}_Name'] = pitcher['name']
        game_record[f'Away_P_{i}_ID'] = pitcher['mlbam_id']
        game_record[f'Away_P_{i}_bbrefID'] = pitcher['bbref_id']
    
    return pd.DataFrame([game_record])

def save_game_to_csv(gamepk):
    game_df = create_game_dataframe(gamepk)
    if not game_df.empty:
        file_name = f'gamelogs/game_{gamepk}.csv'
        game_df.to_csv(file_name, index=False)
        #print(f"Data exported to {file_name}")
    else:
        print(f"No data exported for game {gamepk}")

all_games = pd.read_csv('game_pks.csv').game_id
# Example usage
gamepks = all_games.tail(50)
count = 0
for gamepk in gamepks:
    save_game_to_csv(gamepk)
    count += 1
    if count % 10 == 0:
        print(count)

# Print collected errors
if errors:
    print("Errors encountered:")
    for error in errors:
        print(error)
else:
    print("No errors encountered.")
# Out:
# Invalid team IDs - National League All-Stars 160 vs American League All-Stars 159
# 1830
# 1840
# 1850
# 1860
# 1870
# 1880
# 1890
# 1900
# 1910
# 1920
# 1930
# 1940
# 1950
# 1960
# 1970
# 1980
# 1990
# 2000
# 2010
# 2020
# 2030
# 2040
# 2050
# 2060
# 2070
# 2080
# 2090
# 2100
# 2110
# 2120
# 2130
# 2140
# 2150
# 2160
# 2170
# 2180
# 2190
# 2200
# 2210
# 2220
# 2230
# 2240
# 2250
# 2260
# 2270
# 2280
# 2290
# 2300
# 2310
# 2320
# 2330
# 2340
# 2350
# 2360
# 2370
# 2380
# 2390
# 2400
# 2410
# 2420
# 2430
# 2440
# 2450
# 2460
# 2470
# 2480
# 2490
# 2500
# 2510
# 2520
# 2530
# 2540
# 2550
# 2560
# 2570
# 2580
# 2590
# 2600
# 2610
# 2620
# 2630
# 2640
# 2650
# 2660
# 2670
# 2680
# 2690
# 2700
# 2710
# 2720
# 2730
# 2740
# 2750
# 2760
# 2770
# 2780
# 2790
# 2800
# 2810
# 2820
# 2830
# 2840
# 2850
# 2860
# 2870
# 2880
# 2890
# 2900
# 2910
# 2920
# 2930
# 2940
# 2950
# 2960
# 2970
# 2980
# 2990
# 3000
# 3010
# 3020
# 3030
# 3040
# 3050
# 3060
# 3070
# 3080
# 3090
# 3100
# 3110
# 3120
# 3130
# 3140
# 3150
# 3160
# 3170
# 3180
# 3190
# 3200
# 3210
# 3220
# 3230
# 3240
# 3250
# 3260
# 3270
# 3280
# 3290
# 3300
# 3310
# 3320
# 3330
# 3340
# 3350
# 3360
# 3370
# 3380
# 3390
# 3400
# 3410
# 3420
# 3430
# 3440
# 3450
# 3460
# 3470
# 3480
# 3490
# 3500
# 3510
# 3520
# 3530
# 3540
# 3550
# 3560
# 3570
# 3580
# 3590
# 3600
# 3610
# 3620
# 3630
# 3640
# 3650
# 3660
# 3670
# 3680
# 3690
# 3700
# 3710
# 3720
# 3730
# 3740
# 3750
# 3760
# 3770
# 3780
# 3790
# 3800
# 3810
# 3820
# 3830
# 3840
# 3850
# 3860
# 3870
# 3880
# 3890
# 3900
# 3910
# 3920
# 3930
# 3940
# 3950
# 3960
# 3970
# 3980
# 3990
# 4000
# 4010
# 4020
# 4030
# 4040
# 4050
# 4060
# 4070
# 4080
# 4090
# 4100
# 4110
# 4120
# 4130
# 4140
# 4150
# 4160
# 4170
# 4180
# 4190
# 4200
# 4210
# 4220
# 4230
# 4240
# 4250
# 4260
# 4270
# 4280
# 4290
# 4300
# 4310
# 4320
# 4330
# 4340
# 4350
# 4360
# 4370
# 4380
# 4390
# 4400
# 4410
# 4420
# 4430
# 4440
# 4450
# 4460
# 4470
# 4480
# 4490
# 4500
# 4510
# 4520
# 4530
# 4540
# 4550
# 4560
# 4570
# 4580
# 4590
# 4600
# 4610
# 4620
# 4630
# 4640
# 4650
# 4660
# 4670
# Invalid team IDs - National League All-Stars 160 vs American League All-Stars 159
# 4680
# 4690
# 4700
# 4710
# 4720
# 4730
# 4740
# 4750
# 4760
# 4770
# 4780
# 4790
# 4800
# 4810
# 4820
# 4830
# 4840
# 4850
# 4860
# 4870
# 4880
# 4890
# 4900
# 4910
# 4920
# 4930
# 4940
# 4950
# 4960
# 4970
# 4980
# 4990
# 5000
# 5010
# 5020
# 5030
# 5040
# 5050
# 5060
# 5070
# 5080
# 5090
# 5100
# 5110
# 5120
# 5130
# 5140
# 5150
# 5160
# 5170
# 5180
# 5190
# 5200
# 5210
# 5220
# 5230
# 5240
# 5250
# 5260
# 5270
# 5280
# 5290
# 5300
# 5310
# 5320
# 5330
# 5340
# 5350
# 5360
# 5370
# 5380
# 5390
# 5400
# 5410
# 5420
# 5430
# 5440
# 5450
# 5460
# 5470
# 5480
# 5490
# 5500
# 5510
# 5520
# 5530
# 5540
# 5550
# 5560
# 5570
# 5580
# 5590
# 5600
# 5610
# 5620
# 5630
# 5640
# 5650
# 5660
# 5670
# 5680
# 5690
# 5700
# 5710
# 5720
# 5730
# 5740
# 5750
# 5760
# 5770
# Invalid team IDs - Boston Red Sox 111 vs Northeastern Huskies 343
# 5780
# 5790
# 5800
# 5810
# 5820
# Invalid team IDs - Arizona Diamondbacks 109 vs West Virginia Mountaineers 5327
# 5830
# 5840
# 5850
# 5860
# 5870
# 5880
# 5890
# 5900
# 5910
# 5920
# 5930
# 5940
# Invalid team IDs - Atlanta Braves 144 vs Dominican Republic 805
# Invalid team IDs - Chicago Cubs 112 vs Canada 784
# 5950
# Invalid team IDs - Oakland Athletics 133 vs Colombia 792
# Invalid team IDs - Cleveland Guardians 114 vs Mexico 867
# Invalid team IDs - Milwaukee Brewers 158 vs Great Britain 821
# Invalid team IDs - Boston Red Sox 111 vs Puerto Rico 897
# Invalid team IDs - Houston Astros 117 vs Venezuela 944
# Invalid team IDs - New York Mets 121 vs Nicaragua 881
# Invalid team IDs - Miami Marlins 146 vs Israel 840
# 5960
# Invalid team IDs - San Francisco Giants 137 vs United States 940
# Invalid team IDs - Minnesota Twins 142 vs Dominican Republic 805
# Invalid team IDs - St. Louis Cardinals 138 vs Nicaragua 881
# Invalid team IDs - Atlanta Braves 144 vs Puerto Rico 897
# 5970
# Invalid team IDs - New York Mets 121 vs Venezuela 944
# Invalid team IDs - Chicago White Sox 145 vs Colombia 792
# Invalid team IDs - Kansas City Royals 118 vs Great Britain 821
# Invalid team IDs - Seattle Mariners 136 vs Canada 784
# Invalid team IDs - Colorado Rockies 115 vs Mexico 867
# 5980
# Invalid team IDs - Los Angeles Angels 108 vs United States 940
# Invalid team IDs - Washington Nationals 120 vs Israel 840
# 5990
# 6000
# 6010
# 6020
# 6030
# 6040
# 6050
# 6060
# 6070
# 6080
# 6090
# 6100
# 6110
# 6120
# 6130
# 6140
# 6150
# 6160
# 6170
# 6180
# 6190
# 6200
# 6210
# 6220
# 6230
# 6240
# 6250
# Invalid team IDs - Sugar Land Space Cowboys 5434 vs Houston Astros 117
# 6260
# Invalid team IDs - Houston Astros 117 vs Sugar Land Space Cowboys 5434
# 6270
# 6280
# 6290
# 6300
# 6310
# 6320
# 6330
# 6340
# 6350
# 6360
# 6370
# 6380
# 6390
# 6400
# 6410
# 6420
# 6430
# 6440
# 6450
# 6460
# 6470
# 6480
# 6490
# 6500
# 6510
# 6520
# 6530
# 6540
# 6550
# 6560
# 6570
# 6580
# 6590
# 6600
# 6610
# 6620
# 6630
# 6640
# 6650
# 6660
# 6670
# 6680
# 6690
# 6700
# 6710
# 6720
# 6730
# 6740
# 6750
# 6760
# 6770
# 6780
# 6790
# 6800
# 6810
# 6820
# 6830
# 6840
# 6850
# 6860
# 6870
# 6880
# 6890
# 6900
# 6910
# 6920
# 6930
# 6940
# 6950
# 6960
# 6970
# 6980
# 6990
# 7000
# 7010
# 7020
# 7030
# 7040
# 7050
# 7060
# 7070
# 7080
# 7090
# 7100
# 7110
# 7120
# 7130
# 7140
# 7150
# 7160
# 7170
# 7180
# 7190
# 7200
# 7210
# 7220
# 7230
# 7240
# 7250
# 7260
# 7270
# 7280
# 7290
# 7300
# 7310
# 7320
# 7330
# 7340
# 7350
# 7360
# 7370
# 7380
# 7390
# 7400
# 7410
# 7420
# 7430
# 7440
# 7450
# 7460
# 7470
# 7480
# 7490
# 7500
# 7510
# 7520
# 7530
# 7540
# 7550
# 7560
# 7570
# 7580
# 7590
# 7600
# 7610
# 7620
# 7630
# 7640
# Invalid team IDs - American League All-Stars 159 vs National League All-Stars 160
# 7650
# 7660
# 7670
# 7680
# 7690
# 7700
# 7710
# 7720
# 7730
# 7740
# 7750
# 7760
# 7770
# 7780
# 7790
# 7800
# 7810
# 7820
# 7830
# 7840
# 7850
# 7860
# 7870
# 7880
# 7890
# 7900
# 7910
# 7920
# 7930
# 7940
# 7950
# 7960
# 7970
# 7980
# 7990
# 8000
# 8010
# 8020
# 8030
# 8040
# 8050
# 8060
# 8070
# 8080
# 8090
# 8100
# 8110
# 8120
# 8130
# 8140
# 8150
# 8160
# 8170
# 8180
# 8190
# 8200
# 8210
# 8220
# 8230
# 8240
# 8250
# 8260
# 8270
# 8280
# 8290
# 8300
# 8310
# 8320
# 8330
# 8340
# 8350
# 8360
# 8370
# 8380
# 8390
# 8400
# 8410
# 8420
# 8430
# 8440
# 8450
# 8460
# 8470
# 8480
# 8490
# 8500
# 8510
# 8520
# 8530
# 8540
# 8550
# 8560
# 8570
# 8580
# 8590
# 8600
# 8610
# 8620
# 8630
# 8640
# 8650
# 8660
# 8670
# 8680
# 8690
# 8700
# 8710
# 8720
# 8730
# 8740
# 8750
# 8760
# 8770
# 8780
# Invalid team IDs - Boston Red Sox 111 vs Northeastern Huskies 343
# Invalid team IDs - Minnesota Twins 142 vs Minnesota Golden Gophers 4864
# 8790
# 8800
# 8810
# 8820
# 8830
# 8840
# 8850
# 8860
# 8870
# 8880
# 8890
# 8900
# 8910
# 8920
# 8930
# 8940
# 8950
# 8960
# 8970
# 8980
# 8990
# 9000
# 9010
# 9020
# 9030
# 9040
# 9050
# 9060
# 9070
# 9080
# 9090
# 9100
# 9110
# 9120
# Invalid team IDs - Kiwoom Heroes 2916 vs Los Angeles Dodgers 119
# Invalid team IDs - San Diego Padres 135 vs Korea 1171
# 9130
# 9140
# Invalid team IDs - LG Twins 2913 vs San Diego Padres 135
# Invalid team IDs - Los Angeles Dodgers 119 vs Korea 1171
# 9150
# 9160
# 9170
# 9180
# 9190
# 9200
# 9210
# 9220
# 9230
# Invalid team IDs - Diablos Rojos del Mexico 532 vs New York Yankees 147
# 9240
# Invalid team IDs - San Francisco Giants 137 vs Sacramento River Cats 105
# Invalid team IDs - Northwest Arkansas Naturals 1350 vs Kansas City Royals 118
# 9250
# Invalid team IDs - Diablos Rojos del Mexico 532 vs New York Yankees 147
# Invalid team IDs - Houston Astros 117 vs Sugar Land Space Cowboys 5434
# Invalid team IDs - Washington Nationals 120 vs Washington Nationals Prospects 370
# 9260
# Invalid team IDs - Houston Astros 117 vs Sugar Land Space Cowboys 5434
# 9270
# 9280
# 9290
# 9300
# 9310
# 9320
# 9330
# 9340
# 9350
# 9360
# 9370
# 9380
# 9390
# 9400
# 9410
# 9420
# 9430
# 9440
# 9450
# 9460
# 9470
# 9480
# 9490
# 9500
# 9510
# 9520
# 9530
# 9540
# 9550
# 9560
# 9570
# 9580
# 9590
# 9600
# 9610
# 9620
# 9630
# 9640
# 9650
# 9660
# 9670
# 9680
# 9690
# 9700
# 9710
# 9720
# 9730
# 9740
# 9750
# 9760
# 9770
# 9780
# 9790
# 9800
# 9810
# 9820
# 9830
# 9840
# 9850
# 9860
# 9870
# 9880
# 9890
# 9900
# 9910
# 9920
# 9930
# 9940
# 9950
# 9960
# 9970
# 9980
# 9990
# 10000
# 10010
# 10020
# 10030
# 10040
# 10050
# 10060
# 10070
# 10080
# 10090
# 10100
# 10110
# 10120
# 10130
# 10140
# 10150
# 10160
# 10170
# 10180
# 10190
# 10200
# 10210
# 10220
# Errors encountered:
# (632457, 'Error getting home runs')
# (632457, 'Error getting away runs')
# (663809, 'Error getting home runs')
# (663809, 'Error getting away runs')
# (663808, 'Error getting home runs')
# (663808, 'Error getting away runs')
# (663784, 'Error getting home runs')
# (663784, 'Error getting away runs')
# (663779, 'Error getting home runs')
# (663779, 'Error getting away runs')
# (663778, 'Error getting home runs')
# (663778, 'Error getting away runs')
# (663802, 'Error getting home runs')
# (663802, 'Error getting away runs')
# (663799, 'Error getting home runs')
# (663799, 'Error getting away runs')
# (663777, 'Error getting home runs')
# (663777, 'Error getting away runs')
# (663791, 'Error getting home runs')
# (663791, 'Error getting away runs')
# (706798, 'Error getting home runs')
# (706798, 'Error getting away runs')
# (706953, 'Error getting home runs')
# (706953, 'Error getting away runs')
# (706920, 'Error getting home runs')
# (706920, 'Error getting away runs')
# (707079, 'Error getting home runs')
# (707079, 'Error getting away runs')
# (719112, 'Error getting home runs')
# (719112, 'Error getting away runs')
# (719110, 'Error getting home runs')
# (719110, 'Error getting away runs')
# (719103, 'Error getting home runs')
# (719103, 'Error getting away runs')
# (719108, 'Error getting home runs')
# (719108, 'Error getting away runs')
# (719105, 'Error getting home runs')
# (719105, 'Error getting away runs')
# (719106, 'Error getting home runs')
# (719106, 'Error getting away runs')
# (719104, 'Error getting home runs')
# (719104, 'Error getting away runs')
# (719107, 'Error getting home runs')
# (719107, 'Error getting away runs')
# (748070, 'Error getting home runs')
# (748070, 'Error getting away runs')
# (747858, 'Error getting home runs')
# (747858, 'Error getting away runs')
# (747859, 'Error getting home runs')
# (747859, 'Error getting away runs')
# (747862, 'Error getting home runs')
# (747862, 'Error getting away runs')
# (747861, 'Error getting home runs')
# (747861, 'Error getting away runs')
# (746816, 'Error getting home runs')
# (746816, 'Error getting away runs')
# (745927, 'Error getting home runs')
# (745927, 'Error getting away runs')
# (746730, 'Error getting home runs')
# (746730, 'Error getting away runs')
# (745184, 'Error getting home runs')
# (745184, 'Error getting away runs')
# (747039, 'Error getting home runs')
# (747039, 'Error getting away runs')
# (745175, 'Error getting home runs')
# (745175, 'Error getting away runs')
# (746628, 'Error getting home runs')
# (746628, 'Error getting away runs')
# (745408, 'Error getting home runs')
# (745408, 'Error getting away runs')
