# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pprint
import re 
from dateutil import parser
import time
from datetime import date, datetime, timedelta
from pybaseball import playerid_reverse_lookup
import statsapi
import os
import httpx
import cloudscraper
from curl_cffi import requests as curl_requests

# %%
from curl_cffi import requests as curl_requests  # new import
...

def fetch_b_game_log(player_id, year):
    # Construct the URL for the batter's game log for the given year
    url = f'https://www.baseball-reference.com/players/gl.fcgi?id={player_id}&t=b&year={year}'

    response = curl_requests.get(url, impersonate="chrome101")

    time.sleep(2)

    # Check if the request was successful
    if response.status_code != 200:
        print(f" BAD - Failed to fetch data for batter {player_id} in {year}")
        return None

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find the table containing the game logs
    table = soup.find('table', {'id': 'batting_gamelogs'})

    # Check if the table is found
    if table is None:
        print(f"No data found for batter {player_id} in {year} - OK")
        return None

    # Read the table into a pandas DataFrame
    df = pd.read_html(str(table))[0]

    # Remove rows where 'Rk' is not a number (header rows that repeat in the table)
    df = df[pd.to_numeric(df['Rk'], errors='coerce').notnull()]

    # Add the year to the 'Date' column if the year is not already present
    df['Date'] = df['Date'].apply(lambda x: f"{x}, {year}" if '(' not in x else x)

    # Extract the value from parentheses (if present) and assign it to a new column 'dbl'
    df['dbl'] = df['Date'].str.extract(r'\((\d+)\)').astype(float)

    # Add the year to the 'Date' column for doubleheader dates
    df.loc[df['dbl'].notnull(), 'Date'] = df['Date'] + ', ' + str(year)

    # Format 'Date' to 'game_date' in YYYY-MM-DD format
    df['game_date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

    return df

def fetch_p_game_log(player_id, year):
    # Construct the URL for the pitcher's game log for the given year
    url = f'https://www.baseball-reference.com/players/gl.fcgi?id={player_id}&t=p&year={year}'
    response = curl_requests.get(url, impersonate="chrome101")

    # Check if the request was successful
    if response.status_code != 200:
        print(f" BAD - Failed to fetch data for pitcher {player_id} in {year}")
        return None

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find the table containing the game logs
    table = soup.find('table', {'id': 'pitching_gamelogs'})

    # Check if the table is found
    if table is None:
        print(f"No data found for pitcher {player_id} in {year} - OK")
        return None

    # Read the table into a pandas DataFrame
    df = pd.read_html(str(table))[0]

    # Remove rows where 'Rk' is not a number (header rows that repeat in the table)
    df = df[pd.to_numeric(df['Rk'], errors='coerce').notnull()]

    # Add the year to the 'Date' column if the year is not already present
    df['Date'] = df['Date'].apply(lambda x: f"{x}, {year}" if '(' not in x else x)

    # Extract the value from parentheses (if present) and assign it to a new column 'dbl'
    df['dbl'] = df['Date'].str.extract(r'\((\d+)\)').astype(float)

    # Add the year to the 'Date' column for doubleheader dates
    df.loc[df['dbl'].notnull(), 'Date'] = df['Date'] + ', ' + str(year)

    # Format 'Date' to 'game_date' in YYYY-MM-DD format
    df['game_date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

    return df

# %%
# Function to clean and parse dates
def clean_date(date_str, year):
    try:
        # Replace invisible characters like U+00A0 with a space
        date_str = date_str.replace('\xa0', ' ')
        # Remove any null characters and non-printable characters
        date_str = re.sub(r'[\x00-\x1f\x7f-\x9f]', '', date_str)
        # Remove unwanted characters and extra text like "(1)" or "susp"
        date_str = re.sub(r'\(.*?\)', '', date_str)  # Remove text inside parentheses
        date_str = ''.join(char for char in date_str if char.isalnum() or char.isspace() or char == ',')
        # Remove specific unwanted words like "susp"
        date_str = date_str.replace('susp', '').strip()
        # Parse the cleaned string to a date object
        parsed_date = parser.parse(date_str)
        # Force the year to be 2021
        parsed_date = parsed_date.replace(year=year)
        # Format the date to 'YYYY-MM-DD'
        #print(parsed_date)
        return parsed_date.strftime('%Y-%m-%d')
    except Exception as e:
        # Print the error for debugging purposes
        print(f"Error parsing date '{date_str}': {e}")
        # Handle any parsing errors by returning None
        return None

# Get today's date
today = date.today()

# Define end date
end_date = today.strftime('%Y-%m-%d')

def get_active_player_ids(game_data):
    active_batters = set()  # Use a set to avoid duplicates
    active_pitchers = set()  # Use a set to avoid duplicates
    
    for game in game_data:
        game_id = game['game_id']
        boxscore = statsapi.boxscore_data(game_id)
        
        for team_key in ['away', 'home']:
            if team_key in boxscore:
                team_data = boxscore[team_key]
                if 'batters' in team_data:
                    active_batters.update(team_data['batters'])
                if 'pitchers' in team_data:
                    active_pitchers.update(team_data['pitchers'])
                    
    return list(active_batters), list(active_pitchers)

# Get recent games
recent_games = statsapi.schedule(start_date=(today - timedelta(days=3)).strftime('%Y-%m-%d'), end_date=end_date) ##################################################### CHANGE THIS #################

# Get active batters and pitchers
active_batter_ids, active_pitcher_ids = get_active_player_ids(recent_games)

# Use playerid_reverse_lookup to get bbref_id
def get_bbref_ids(player_ids):
    player_data = playerid_reverse_lookup(player_ids, key_type='mlbam')
    return player_data[['key_mlbam', 'key_bbref']]

# Get bbref IDs for active batters and pitchers
active_batter_data = get_bbref_ids(active_batter_ids)
active_pitcher_data = get_bbref_ids(active_pitcher_ids)

# Save to CSV
active_batter_data.to_csv('active_batter_ids.csv', index=False)
active_pitcher_data.to_csv('active_pitcher_ids.csv', index=False)

# Load active player IDs
active_batter_ids = pd.read_csv('active_batter_ids.csv')['key_bbref']
active_pitcher_ids = pd.read_csv('active_pitcher_ids.csv')['key_bbref']

# Load game Pks
game_pks = pd.read_csv('game_pks.csv')

# Define the mapping from abbreviated team names to full team names
team_id_mapping = {
    'WSN': 120, 'MIA': 146, 'TBR': 139, 'ATL': 144, 'TEX': 140, 'HOU': 117,
    'SD': 135, 'SDP': 135, 'PHI': 143, 'BAL': 110, 'SEA': 136, 'NYM': 121,
    'ARI': 109, 'LAA': 108, 'OAK': 133, 'TOR': 141, 'CLE': 114, 'STL': 138,
    'MIN': 142, 'DET': 116, 'NYY': 147, 'SFG': 137, 'KCR': 118, 'CWS': 145,
    'CHW': 145, 'COL': 115, 'BOS': 111, 'LAD': 119, 'CHC': 112, 'MIL': 158,
    'CIN': 113, 'PIT': 134
}

# Define the current year
current_year = 2025

# Function to process and save player data
def process_player_data(player_ids, player_type='batter'):
    fetch_game_log = fetch_b_game_log if player_type == 'batter' else fetch_p_game_log
    
    for id in player_ids:
        if not id or pd.isna(id):
            continue

         # Load the existing player data if it exists
        player_file_path = f'{player_type}s/{id}_{player_type}ing.csv'
        if player_type == 'batter':
            player_file_path = f'batters/{id}_batting.csv'
        elif player_type == 'pitcher':
            player_file_path = f'pitchers/{id}_pitching.csv'
            
        if os.path.exists(player_file_path):
            player_df = pd.read_csv(player_file_path)
        else:
            player_df = pd.DataFrame()

        # Fetch data for the current year
        new_data_df = fetch_game_log(id, current_year)
        time.sleep(0.2)

        # Check if the fetched dataframe is None or empty
        if new_data_df is None or new_data_df.empty:
            continue  # Skip if no data available

        # Apply the function to the date_column and create a new column
        new_data_df['game_date'] = new_data_df['Date'].apply(lambda date: clean_date(date, current_year))
        new_data_df['Date'] = new_data_df['game_date']

        # Ensure the 'Date' column in new_data_df and 'game_date' column in game_pks are in datetime format
        new_data_df['Date'] = pd.to_datetime(new_data_df['Date'])
        game_pks['game_date'] = pd.to_datetime(game_pks['game_date'])

        # Map the team abbreviations to full team names
        new_data_df['team_id'] = new_data_df['Tm'].map(team_id_mapping)
        new_data_df['opp_id'] = new_data_df['Opp'].map(team_id_mapping)

        # Initialize a new column in new_data_df for game_id
        new_data_df['game_id'] = None

        # Iterate over the rows in new_data_df to find the corresponding game_id in game_pks
        for index, row in new_data_df.iterrows():
            # Filter the game_pks for the matching date and teams
            game_day_matches = game_pks[
                (game_pks['game_date'] == row['Date']) &
                (
                    ((game_pks['home_id'] == row['team_id']) & (game_pks['away_id'] == row['opp_id'])) |
                    ((game_pks['home_id'] == row['opp_id']) & (game_pks['away_id'] == row['team_id']))
                )
            ]

            # Check the 'dbl' column to assign the correct game_id
            if not game_day_matches.empty:
                if row['dbl'] == 1:
                    # For the first game of a double-header
                    game_id = game_day_matches.iloc[0]['game_id']
                elif row['dbl'] == 2:
                    # For the second game of a double-header
                    if len(game_day_matches) > 1:
                        game_id = game_day_matches.iloc[1]['game_id']
                    else:
                        game_id = game_day_matches.iloc[0]['game_id']
                else:
                    # For days without double-headers or unmarked double-headers, take the first game
                    game_id = game_day_matches.iloc[0]['game_id']
                new_data_df.at[index, 'game_id'] = game_id
            else:
                print(f"BAD - NO GAME MATCHES FOUND for {id} on {row['Date']}")

        # Concatenate the new data with the existing data, ensuring no duplicates
        if not player_df.empty:
            combined_df = pd.concat([player_df, new_data_df]).drop_duplicates(subset=['game_id'])
        else:
            combined_df = new_data_df

        # Save the updated player data to a CSV file
        combined_df.to_csv(player_file_path, index=False)

    print(f'All {player_type} IDs processed and saved')

# Process batter and pitcher data   
process_player_data(active_batter_ids, player_type='batter')
process_player_data(active_pitcher_ids, player_type='pitcher')

print('\nPlayer stats updated - SUCCESS\n')
# Out:
# No data found for batter milleow01 in 2025 - OK
# No data found for batter edmanto01 in 2025 - OK
# No data found for batter cessalu01 in 2025 - OK
# No data found for batter zastrro01 in 2025 - OK
# No data found for batter schneda03 in 2025 - OK
# No data found for batter lowebr01 in 2025 - OK
# No data found for batter junisja01 in 2025 - OK
# No data found for batter nerishe01 in 2025 - OK
# No data found for batter chaveje01 in 2025 - OK
# No data found for batter goodmhu01 in 2025 - OK
# No data found for batter locasti01 in 2025 - OK
# No data found for batter chourja01 in 2025 - OK
# No data found for batter cabreos01 in 2025 - OK
# No data found for batter wittbo02 in 2025 - OK
# No data found for batter winkeje01 in 2025 - OK
# No data found for batter kreidry01 in 2025 - OK
# No data found for batter crochga01 in 2025 - OK
# No data found for batter estraje01 in 2025 - OK
# No data found for batter rodried05 in 2025 - OK
# No data found for batter wilsost02 in 2025 - OK
# No data found for batter lestejo02 in 2025 - OK
# No data found for batter rutscad01 in 2025 - OK
# No data found for batter holmecl01 in 2025 - OK
# No data found for batter manzaky01 in 2025 - OK
# No data found for batter judgeaa01 in 2025 - OK
# No data found for batter stallja01 in 2025 - OK
# No data found for batter burkebr01 in 2025 - OK
# No data found for batter bowdebe01 in 2025 - OK
# No data found for batter nootbla01 in 2025 - OK
# No data found for batter jacksal02 in 2025 - OK
# No data found for batter santogr01 in 2025 - OK
# No data found for batter langfwy01 in 2025 - OK
# No data found for batter polanjo01 in 2025 - OK
# No data found for batter kirkal01 in 2025 - OK
# No data found for batter refsnro01 in 2025 - OK
# No data found for batter dezenza01 in 2025 - OK
# No data found for batter mercami01 in 2025 - OK
# No data found for batter faircst01 in 2025 - OK
# No data found for batter pallaan01 in 2025 - OK
# No data found for batter westbjo01 in 2025 - OK
# No data found for batter gombeau01 in 2025 - OK
# No data found for batter sullibr01 in 2025 - OK
# No data found for batter thaisma01 in 2025 - OK
# No data found for batter gilbelo01 in 2025 - OK
# No data found for batter laurera01 in 2025 - OK
# No data found for batter nelsory01 in 2025 - OK
# No data found for batter woodfja01 in 2025 - OK
# No data found for batter soriage01 in 2025 - OK
# No data found for batter erceglu01 in 2025 - OK
# No data found for batter castrmi01 in 2025 - OK
# No data found for batter tayloch03 in 2025 - OK
# No data found for batter boydma01 in 2025 - OK
# No data found for batter lopezre01 in 2025 - OK
# No data found for batter leeko01 in 2025 - OK
# No data found for batter wallfo01 in 2025 - OK
# No data found for batter matsuyu01 in 2025 - OK
# No data found for batter herreiv01 in 2025 - OK
# No data found for batter kriskbr01 in 2025 - OK
# No data found for batter orneljo01 in 2025 - OK
# No data found for batter machivi01 in 2025 - OK
# No data found for batter pearsna01 in 2025 - OK
# No data found for batter megiltr01 in 2025 - OK
# No data found for batter arroych01 in 2025 - OK
# No data found for batter strzepe01 in 2025 - OK
# No data found for batter naylobo01 in 2025 - OK
# No data found for batter massemi02 in 2025 - OK
# No data found for batter wagamer01 in 2025 - OK
# No data found for batter carlsdy01 in 2025 - OK
# No data found for batter hollija01 in 2025 - OK
# No data found for batter rosareg01 in 2025 - OK
# No data found for batter lipcian01 in 2025 - OK
# No data found for batter garciad02 in 2025 - OK
# No data found for batter cruzon01 in 2025 - OK
# No data found for batter vesiaal01 in 2025 - OK
# No data found for batter arraelu01 in 2025 - OK
# No data found for batter martest01 in 2025 - OK
# No data found for batter ellarfr01 in 2025 - OK
# No data found for batter cannigr01 in 2025 - OK
# No data found for batter hoernni01 in 2025 - OK
# No data found for batter leeju01 in 2025 - OK
# No data found for batter lowena01 in 2025 - OK
# No data found for batter torrelu01 in 2025 - OK
# No data found for batter loperjo01 in 2025 - OK
# No data found for batter solerjo01 in 2025 - OK
# No data found for batter ortizjo06 in 2025 - OK
# No data found for batter zulueyo01 in 2025 - OK
# No data found for batter pocheco01 in 2025 - OK
# No data found for batter helmami01 in 2025 - OK
# No data found for batter ozunama01 in 2025 - OK
# No data found for batter romerjo01 in 2025 - OK
# No data found for batter vientma01 in 2025 - OK
# No data found for batter ottavad01 in 2025 - OK
# No data found for batter blackty01 in 2025 - OK
# No data found for batter machadi01 in 2025 - OK
# No data found for batter hartky01 in 2025 - OK
# No data found for batter andujmi01 in 2025 - OK
# No data found for batter shentau01 in 2025 - OK
# No data found for batter lugose01 in 2025 - OK
# No data found for batter caratvi01 in 2025 - OK
# No data found for batter canzodo01 in 2025 - OK
# No data found for batter criswco01 in 2025 - OK
# No data found for batter lorenmi01 in 2025 - OK
# No data found for batter lukesna01 in 2025 - OK
# No data found for batter contrwi01 in 2025 - OK
# No data found for batter millema03 in 2025 - OK
# No data found for batter kremede01 in 2025 - OK
# No data found for batter madribl01 in 2025 - OK
# No data found for batter alvarjo03 in 2025 - OK
# No data found for batter minteaj01 in 2025 - OK
# No data found for batter lopezpa01 in 2025 - OK
# No data found for batter webbja01 in 2025 - OK
# No data found for batter bryankr01 in 2025 - OK
# No data found for batter litteza01 in 2025 - OK
# No data found for batter castrro01 in 2025 - OK
# No data found for batter higasky01 in 2025 - OK
# No data found for batter allarko01 in 2025 - OK
# No data found for batter richatr01 in 2025 - OK
# No data found for batter skubata01 in 2025 - OK
# No data found for batter adamja01 in 2025 - OK
# No data found for batter frelisa01 in 2025 - OK
# No data found for batter bargead01 in 2025 - OK
# No data found for batter bautife01 in 2025 - OK
# No data found for batter zuniggu01 in 2025 - OK
# No data found for batter stridsp01 in 2025 - OK
# No data found for batter chafian01 in 2025 - OK
# No data found for batter moniami01 in 2025 - OK
# No data found for batter albieoz01 in 2025 - OK
# No data found for batter hamilda03 in 2025 - OK
# No data found for batter velazan01 in 2025 - OK
# No data found for batter sotoli01 in 2025 - OK
# No data found for batter soderty01 in 2025 - OK
# No data found for batter abreubr01 in 2025 - OK
# No data found for batter croneja01 in 2025 - OK
# No data found for batter kikucyu01 in 2025 - OK
# No data found for batter bickfph01 in 2025 - OK
# No data found for batter verlaju01 in 2025 - OK
# No data found for batter alcaljo01 in 2025 - OK
# No data found for batter bellova01 in 2025 - OK
# No data found for batter vasqura02 in 2025 - OK
# No data found for batter gonzani01 in 2025 - OK
# No data found for batter santaan02 in 2025 - OK
# No data found for batter seaglch01 in 2025 - OK
# No data found for batter deloaza01 in 2025 - OK
# No data found for batter sirijo01 in 2025 - OK
# No data found for batter winnke01 in 2025 - OK
# No data found for batter wallsta01 in 2025 - OK
# No data found for batter valdefr01 in 2025 - OK
# No data found for batter montgma01 in 2025 - OK
# No data found for batter mullice01 in 2025 - OK
# No data found for batter keithco01 in 2025 - OK
# No data found for batter garciro04 in 2025 - OK
# No data found for batter clevimi01 in 2025 - OK
# No data found for batter rutleja01 in 2025 - OK
# No data found for batter lynchda02 in 2025 - OK
# No data found for batter mcgousc01 in 2025 - OK
# No data found for batter whitcsh01 in 2025 - OK
# No data found for batter moorema02 in 2025 - OK
# No data found for batter pillake01 in 2025 - OK
# No data found for batter ohtansh01 in 2025 - OK
# No data found for batter langesh01 in 2025 - OK
# No data found for batter youngda02 in 2025 - OK
# No data found for batter sianimi01 in 2025 - OK
# No data found for batter jacobal01 in 2025 - OK
# No data found for batter arciaor01 in 2025 - OK
# No data found for batter sheetga01 in 2025 - OK
# No data found for batter lambja01 in 2025 - OK
# No data found for batter foscuju01 in 2025 - OK
# No data found for batter thielca01 in 2025 - OK
# No data found for batter darnatr01 in 2025 - OK
# No data found for batter schwaky01 in 2025 - OK
# No data found for batter woobr01 in 2025 - OK
# No data found for batter spierca01 in 2025 - OK
# No data found for batter freemfr01 in 2025 - OK
# No data found for batter winnma01 in 2025 - OK
# No data found for batter pintore02 in 2025 - OK
# No data found for batter henriro01 in 2025 - OK
# No data found for batter nunezdo01 in 2025 - OK
# No data found for batter amayami01 in 2025 - OK
# No data found for batter beninan01 in 2025 - OK
# No data found for batter hendrry01 in 2025 - OK
# No data found for batter malloju02 in 2025 - OK
# No data found for batter blackma01 in 2025 - OK
# No data found for batter volpean01 in 2025 - OK
# No data found for batter bandaan01 in 2025 - OK
# No data found for batter skenepa01 in 2025 - OK
# No data found for batter kolozma01 in 2025 - OK
# No data found for batter viladry01 in 2025 - OK
# No data found for batter ellisdu01 in 2025 - OK
# No data found for batter matonph01 in 2025 - OK
# No data found for batter armstsh01 in 2025 - OK
# No data found for batter foleyja01 in 2025 - OK
# No data found for batter suterbr01 in 2025 - OK
# No data found for batter schrejo01 in 2025 - OK
# No data found for batter gamelbe01 in 2025 - OK
# No data found for batter kingbr02 in 2025 - OK
# No data found for batter birdja01 in 2025 - OK
# No data found for batter rogerty01 in 2025 - OK
# No data found for batter vespini01 in 2025 - OK
# No data found for batter sogarni01 in 2025 - OK
# No data found for batter rojasmi02 in 2025 - OK
# No data found for batter mckentr01 in 2025 - OK
# No data found for batter bellico01 in 2025 - OK
# No data found for batter morenga01 in 2025 - OK
# No data found for batter correca01 in 2025 - OK
# No data found for batter fujinsh01 in 2025 - OK
# No data found for batter walkery01 in 2025 - OK
# No data found for batter longsa01 in 2025 - OK
# No data found for batter rosaram01 in 2025 - OK
# No data found for batter merrija01 in 2025 - OK
# No data found for batter ellisch01 in 2025 - OK
# No data found for batter treinbl01 in 2025 - OK
# No data found for batter andergr01 in 2025 - OK
# No data found for batter senzaan01 in 2025 - OK
# No data found for batter mcgeeea01 in 2025 - OK
# No data found for batter garciyi01 in 2025 - OK
# No data found for batter scottta02 in 2025 - OK
# No data found for batter swaggtr01 in 2025 - OK
# No data found for batter rodrima01 in 2025 - OK
# No data found for batter narvaca01 in 2025 - OK
# No data found for batter kniznan01 in 2025 - OK
# No data found for batter villada01 in 2025 - OK
# No data found for batter jimenel02 in 2025 - OK
# No data found for batter perdoan01 in 2025 - OK
# No data found for batter melenmj01 in 2025 - OK
# No data found for batter tatisfe02 in 2025 - OK
# No data found for batter burneco01 in 2025 - OK
# No data found for batter payamjo01 in 2025 - OK
# No data found for batter kolekst01 in 2025 - OK
# No data found for batter milneho01 in 2025 - OK
# No data found for batter rogerja03 in 2025 - OK
# No data found for batter speiega01 in 2025 - OK
# No data found for batter kellyca02 in 2025 - OK
# No data found for batter hayeske01 in 2025 - OK
# No data found for batter briesbe01 in 2025 - OK
# No data found for batter cruzfe01 in 2025 - OK
# No data found for batter hillti01 in 2025 - OK
# No data found for batter sandlni01 in 2025 - OK
# No data found for batter hudsobr01 in 2025 - OK
# No data found for batter mountry01 in 2025 - OK
# No data found for batter suareal01 in 2025 - OK
# No data found for batter ramosbr01 in 2025 - OK
# No data found for batter quintjo01 in 2025 - OK
# No data found for batter contrwi02 in 2025 - OK
# No data found for batter wallach01 in 2025 - OK
# No data found for batter portelo01 in 2025 - OK
# No data found for batter hernajo02 in 2025 - OK
# No data found for batter shustja01 in 2025 - OK
# No data found for batter rodriwi02 in 2025 - OK
# No data found for batter whiteel04 in 2025 - OK
# No data found for batter cortene01 in 2025 - OK
# No data found for batter rasmudr01 in 2025 - OK
# No data found for batter wentzjo01 in 2025 - OK
# No data found for batter gibauia01 in 2025 - OK
# No data found for batter estevca01 in 2025 - OK
# No data found for batter forteni01 in 2025 - OK
# No data found for batter beeksja02 in 2025 - OK
# No data found for batter kuhnejo01 in 2025 - OK
# No data found for batter renfrhu01 in 2025 - OK
# No data found for batter arenano01 in 2025 - OK
# No data found for batter peralwa01 in 2025 - OK
# No data found for batter varlalo01 in 2025 - OK
# No data found for batter hoffmje02 in 2025 - OK
# No data found for batter willial04 in 2025 - OK
# No data found for batter vargail01 in 2025 - OK
# No data found for batter barretr01 in 2025 - OK
# No data found for batter cordefr02 in 2025 - OK
# No data found for batter rodgebr02 in 2025 - OK
# No data found for batter marshbr02 in 2025 - OK
# No data found for batter cowseco01 in 2025 - OK
# No data found for batter lopezjo02 in 2025 - OK
# No data found for batter norbyco01 in 2025 - OK
# No data found for batter houckta01 in 2025 - OK
# No data found for batter alcanke01 in 2025 - OK
# No data found for batter roberni01 in 2025 - OK
# No data found for batter ingrako01 in 2025 - OK
# No data found for batter machama01 in 2025 - OK
# No data found for batter mccoyma01 in 2025 - OK
# No data found for batter yastrmi01 in 2025 - OK
# No data found for batter torregl01 in 2025 - OK
# No data found for batter rayro02 in 2025 - OK
# No data found for batter suarejo01 in 2025 - OK
# No data found for batter johnsbr03 in 2025 - OK
# No data found for batter cabaljo01 in 2025 - OK
# No data found for batter meadcu01 in 2025 - OK
# No data found for batter wallnma01 in 2025 - OK
# No data found for batter ucetaed01 in 2025 - OK
# No data found for batter thorntr01 in 2025 - OK
# No data found for batter delosye01 in 2025 - OK
# No data found for batter mclaima01 in 2025 - OK
# No data found for batter feddeer01 in 2025 - OK
# No data found for batter pomerdr01 in 2025 - OK
# No data found for batter buxtoby01 in 2025 - OK
# No data found for batter mayzati01 in 2025 - OK
# No data found for batter edwarxa01 in 2025 - OK
# No data found for batter garcilu04 in 2025 - OK
# No data found for batter mitchca01 in 2025 - OK
# No data found for batter kellyke02 in 2025 - OK
# No data found for batter tovarez01 in 2025 - OK
# No data found for batter perezca02 in 2025 - OK
# No data found for batter davishe01 in 2025 - OK
# No data found for batter leiteja01 in 2025 - OK
# No data found for batter peredjh01 in 2025 - OK
# No data found for batter curryxz01 in 2025 - OK
# No data found for batter busenal01 in 2025 - OK
# No data found for batter phillty01 in 2025 - OK
# No data found for batter freemty01 in 2025 - OK
# No data found for batter pfaadbr01 in 2025 - OK
# No data found for batter garzaju01 in 2025 - OK
# No data found for batter garcijo02 in 2025 - OK
# No data found for batter rodrich01 in 2025 - OK
# No data found for batter rodriri05 in 2025 - OK
# No data found for batter jonesno01 in 2025 - OK
# No data found for batter vestwi01 in 2025 - OK
# No data found for batter falteba01 in 2025 - OK
# No data found for batter capravi01 in 2025 - OK
# No data found for batter pilkiko01 in 2025 - OK
# No data found for batter bailepa01 in 2025 - OK
# No data found for batter rocchbr01 in 2025 - OK
# No data found for batter miranjo01 in 2025 - OK
# No data found for batter casteni01 in 2025 - OK
# No data found for batter rodriel02 in 2025 - OK
# No data found for batter rengilu01 in 2025 - OK
# No data found for batter smithjo11 in 2025 - OK
# No data found for batter millebr04 in 2025 - OK
# No data found for batter rodonca01 in 2025 - OK
# No data found for batter reyespa01 in 2025 - OK
# No data found for batter bednada01 in 2025 - OK
# No data found for batter obrieri01 in 2025 - OK
# No data found for batter castrda01 in 2025 - OK
# No data found for batter kennebu01 in 2025 - OK
# No data found for batter delucjo01 in 2025 - OK
# No data found for batter abbotan01 in 2025 - OK
# No data found for batter francty01 in 2025 - OK
# No data found for batter santito01 in 2025 - OK
# No data found for batter finneky01 in 2025 - OK
# No data found for batter gillalo01 in 2025 - OK
# No data found for batter gerbejo01 in 2025 - OK
# No data found for batter raleylu01 in 2025 - OK
# No data found for batter iglesra01 in 2025 - OK
# No data found for batter grichra01 in 2025 - OK
# No data found for batter toglimi01 in 2025 - OK
# No data found for batter uribeab01 in 2025 - OK
# No data found for batter fermifr01 in 2025 - OK
# No data found for batter monasan01 in 2025 - OK
# No data found for batter gaspemi01 in 2025 - OK
# No data found for batter brebbjo01 in 2025 - OK
# No data found for batter strathu01 in 2025 - OK
# No data found for batter guilllu01 in 2025 - OK
# No data found for batter clemeer01 in 2025 - OK
# No data found for batter helslry01 in 2025 - OK
# No data found for batter adamsri03 in 2025 - OK
# No data found for batter delosen01 in 2025 - OK
# No data found for batter harriho03 in 2025 - OK
# No data found for batter gormano01 in 2025 - OK
# No data found for batter bakerbr01 in 2025 - OK
# No data found for batter yoshima02 in 2025 - OK
# No data found for batter hernaen02 in 2025 - OK
# No data found for batter suzukse01 in 2025 - OK
# No data found for batter rogerta01 in 2025 - OK
# No data found for batter gonzaos01 in 2025 - OK
# No data found for batter encarje01 in 2025 - OK
# No data found for batter doylebr02 in 2025 - OK
# No data found for batter mcfartj01 in 2025 - OK
# No data found for batter nolaaa01 in 2025 - OK
# No data found for batter hergeji01 in 2025 - OK
# No data found for batter slateju01 in 2025 - OK
# No data found for batter diazya01 in 2025 - OK
# No data found for batter scherma01 in 2025 - OK
# No data found for batter mooredy01 in 2025 - OK
# No data found for batter abramcj01 in 2025 - OK
# No data found for batter muncyma01 in 2025 - OK
# No data found for batter williga01 in 2025 - OK
# No data found for batter elderbr01 in 2025 - OK
# No data found for batter lovelri01 in 2025 - OK
# No data found for batter rookebr01 in 2025 - OK
# No data found for batter martiju01 in 2025 - OK
# No data found for batter santaca01 in 2025 - OK
# No data found for batter wynnsau01 in 2025 - OK
# No data found for batter mcmahry01 in 2025 - OK
# No data found for batter blissry01 in 2025 - OK
# No data found for batter urenajo01 in 2025 - OK
# No data found for batter thomaal01 in 2025 - OK
# No data found for batter millesh01 in 2025 - OK
# No data found for batter jackslu01 in 2025 - OK
# No data found for batter blalobr01 in 2025 - OK
# No data found for batter boylejo01 in 2025 - OK
# No data found for batter strawmy01 in 2025 - OK
# No data found for batter wiselbr01 in 2025 - OK
# No data found for batter seaboco01 in 2025 - OK
# No data found for batter urshegi01 in 2025 - OK
# No data found for batter alvaryo01 in 2025 - OK
# No data found for batter justiev01 in 2025 - OK
# No data found for batter goldspa01 in 2025 - OK
# No data found for batter reynobr01 in 2025 - OK
# No data found for batter schanno01 in 2025 - OK
# No data found for batter legumca01 in 2025 - OK
# No data found for batter schunaa01 in 2025 - OK
# No data found for batter contrlu01 in 2025 - OK
# No data found for batter weavelu01 in 2025 - OK
# No data found for batter luxga01 in 2025 - OK
# No data found for batter diazya02 in 2025 - OK
# No data found for batter penaje02 in 2025 - OK
# No data found for batter mercaos01 in 2025 - OK
# No data found for batter carteev01 in 2025 - OK
# No data found for batter mervima01 in 2025 - OK
# No data found for batter raineta01 in 2025 - OK
# No data found for batter varlagu01 in 2025 - OK
# No data found for batter perallu01 in 2025 - OK
# No data found for batter wadety01 in 2025 - OK
# No data found for batter riosed01 in 2025 - OK
# No data found for batter phamth01 in 2025 - OK
# No data found for batter heywaja01 in 2025 - OK
# No data found for batter fauchca01 in 2025 - OK
# No data found for batter myersda01 in 2025 - OK
# No data found for batter cantijo01 in 2025 - OK
# No data found for batter smithpa04 in 2025 - OK
# No data found for batter glasnty01 in 2025 - OK
# No data found for batter marinro01 in 2025 - OK
# No data found for batter sousabe01 in 2025 - OK
# No data found for batter meyerja02 in 2025 - OK
# No data found for batter yepezju01 in 2025 - OK
# No data found for batter perezwe01 in 2025 - OK
# No data found for batter garcima01 in 2025 - OK
# No data found for batter peralfr01 in 2025 - OK
# No data found for batter ferrejo01 in 2025 - OK
# No data found for batter pepiory01 in 2025 - OK
# No data found for batter seageco01 in 2025 - OK
# No data found for batter thompry02 in 2025 - OK
# No data found for batter mcguire01 in 2025 - OK
# No data found for batter varshda01 in 2025 - OK
# No data found for batter wilsobr02 in 2025 - OK
# No data found for batter kerkeor01 in 2025 - OK
# No data found for batter haysau01 in 2025 - OK
# No data found for batter oneilty01 in 2025 - OK
# No data found for batter yelicch01 in 2025 - OK
# No data found for batter lasorjo01 in 2025 - OK
# No data found for batter herrejo04 in 2025 - OK
# No data found for batter littllu01 in 2025 - OK
# No data found for batter detmere01 in 2025 - OK
# No data found for batter fairbpe01 in 2025 - OK
# No data found for batter joycebe01 in 2025 - OK
# No data found for batter rortvbe01 in 2025 - OK
# No data found for batter herriti01 in 2025 - OK
# No data found for batter bachala01 in 2025 - OK
# No data found for batter borucry01 in 2025 - OK
# No data found for batter eflinza01 in 2025 - OK
# No data found for batter sandsco01 in 2025 - OK
# No data found for batter ohearry01 in 2025 - OK
# No data found for batter crawfjp01 in 2025 - OK
# No data found for batter turnetr01 in 2025 - OK
# No data found for batter feltnry01 in 2025 - OK
# No data found for batter basabos01 in 2025 - OK
# No data found for batter schuema01 in 2025 - OK
# No data found for batter mantijo01 in 2025 - OK
# No data found for batter hanifbr01 in 2025 - OK
# No data found for batter stratch01 in 2025 - OK
# No data found for batter pereiev01 in 2025 - OK
# No data found for batter higgipj01 in 2025 - OK
# No data found for batter taylomi02 in 2025 - OK
# No data found for batter brighje01 in 2025 - OK
# No data found for batter bummeaa01 in 2025 - OK
# No data found for batter soriajo02 in 2025 - OK
# No data found for batter mateojo01 in 2025 - OK
# No data found for batter dominja01 in 2025 - OK
# No data found for batter stassma01 in 2025 - OK
# No data found for batter gimenan01 in 2025 - OK
# No data found for batter freelky01 in 2025 - OK
# No data found for batter kingjo01 in 2025 - OK
# No data found for batter livelbe01 in 2025 - OK
# No data found for batter turanbr02 in 2025 - OK
# No data found for batter wongco01 in 2025 - OK
# No data found for batter willide03 in 2025 - OK
# No data found for batter abreuwi02 in 2025 - OK
# No data found for batter vazquch01 in 2025 - OK
# No data found for batter shewmbr01 in 2025 - OK
# No data found for batter triolja01 in 2025 - OK
# No data found for batter suarero01 in 2025 - OK
# No data found for batter greenri03 in 2025 - OK
# No data found for batter hillja01 in 2025 - OK
# No data found for batter sanojja01 in 2025 - OK
# No data found for batter bivensp01 in 2025 - OK
# No data found for batter trejoal01 in 2025 - OK
# No data found for batter brashma01 in 2025 - OK
# No data found for batter berrost01 in 2025 - OK
# No data found for batter youngja03 in 2025 - OK
# No data found for batter leclejo01 in 2025 - OK
# No data found for batter lockrbr01 in 2025 - OK
# No data found for batter megilty01 in 2025 - OK
# No data found for batter trompch01 in 2025 - OK
# No data found for batter sosaed01 in 2025 - OK
# No data found for batter iglesjo01 in 2025 - OK
# No data found for batter mcgremi01 in 2025 - OK
# No data found for batter lowejo01 in 2025 - OK
# No data found for batter ricebe01 in 2025 - OK
# No data found for batter ariasga01 in 2025 - OK
# No data found for batter pressry01 in 2025 - OK
# No data found for batter pagesan01 in 2025 - OK
# No data found for batter padilni01 in 2025 - OK
# No data found for batter anderti01 in 2025 - OK
# No data found for batter confomi01 in 2025 - OK
# No data found for batter butlela01 in 2025 - OK
# No data found for batter delacbr01 in 2025 - OK
# No data found for batter biggica01 in 2025 - OK
# No data found for batter pozoyo01 in 2025 - OK
# No data found for batter morelch01 in 2025 - OK
# No data found for batter overtco01 in 2025 - OK
# No data found for batter julksco01 in 2025 - OK
# No data found for batter castrke01 in 2025 - OK
# No data found for batter colliis01 in 2025 - OK
# No data found for batter burgora01 in 2025 - OK
# No data found for batter woodssi01 in 2025 - OK
# No data found for batter perazos02 in 2025 - OK
# No data found for batter stewadj01 in 2025 - OK
# No data found for batter hernani01 in 2025 - OK
# No data found for batter dingldi01 in 2025 - OK
# No data found for batter benjawe01 in 2025 - OK
# No data found for batter olsonre01 in 2025 - OK
# No data found for batter yateski01 in 2025 - OK
# No data found for batter vargami01 in 2025 - OK
# No data found for batter julieed01 in 2025 - OK
# No data found for batter duranjh01 in 2025 - OK
# No data found for batter duranja01 in 2025 - OK
# No data found for batter headrbr01 in 2025 - OK
# No data found for batter keirsda01 in 2025 - OK
# No data found for batter deverra01 in 2025 - OK
# No data found for batter vazqulu01 in 2025 - OK
# No data found for batter lucchjo01 in 2025 - OK
# No data found for batter guentse01 in 2025 - OK
# No data found for batter birdsha01 in 2025 - OK
# No data found for batter espinsa01 in 2025 - OK
# No data found for batter mccragr01 in 2025 - OK
# No data found for batter brooktr01 in 2025 - OK
# No data found for batter castilu02 in 2025 - OK
# No data found for batter azocajo01 in 2025 - OK
# No data found for batter sorokmi01 in 2025 - OK
# No data found for batter lawreju01 in 2025 - OK
# No data found for batter jeffery01 in 2025 - OK
# No data found for batter suwinja01 in 2025 - OK
# No data found for batter leitema02 in 2025 - OK
# No data found for batter heimjo01 in 2025 - OK
# No data found for batter colemdy01 in 2025 - OK
# No data found for batter quijajo01 in 2025 - OK
# No data found for batter realmjt01 in 2025 - OK
# No data found for batter amadoad01 in 2025 - OK
# No data found for batter dunnbl01 in 2025 - OK
# No data found for batter okertst01 in 2025 - OK
# No data found for batter hahnje01 in 2025 - OK
# No data found for batter reaco01 in 2025 - OK
# No data found for batter raganco01 in 2025 - OK
# No data found for batter bowmama01 in 2025 - OK
# No data found for batter adelljo01 in 2025 - OK
# No data found for batter rodriju01 in 2025 - OK
# No data found for batter kwanst01 in 2025 - OK
# No data found for batter quiroes01 in 2025 - OK
# No data found for batter brownse01 in 2025 - OK
# No data found for batter baderha01 in 2025 - OK
# No data found for batter bohmal01 in 2025 - OK
# No data found for batter bendean01 in 2025 - OK
# No data found for batter walkejo02 in 2025 - OK
# No data found for batter spencmi01 in 2025 - OK
# No data found for batter sauceta01 in 2025 - OK
# No data found for batter bauerja01 in 2025 - OK
# No data found for batter graytr01 in 2025 - OK
# No data found for batter bridejo01 in 2025 - OK
# No data found for batter luzarje01 in 2025 - OK
# No data found for batter henslda01 in 2025 - OK
# No data found for batter bibeeta01 in 2025 - OK
# No data found for batter alexaty01 in 2025 - OK
# No data found for batter rileyau01 in 2025 - OK
# No data found for batter walketa01 in 2025 - OK
# No data found for batter uriaslu01 in 2025 - OK
# No data found for batter woodja03 in 2025 - OK
# No data found for batter lopezal03 in 2025 - OK
# No data found for batter blewesc01 in 2025 - OK
# No data found for batter jarvibr01 in 2025 - OK
# No data found for batter mushipa01 in 2025 - OK
# No data found for batter tayloty01 in 2025 - OK
# No data found for batter zavalse01 in 2025 - OK
# No data found for batter stromma01 in 2025 - OK
# No data found for batter anderia01 in 2025 - OK
# No data found for batter rafaece01 in 2025 - OK
# No data found for batter canoye01 in 2025 - OK
# No data found for batter caminju01 in 2025 - OK
# No data found for batter rivasle01 in 2025 - OK
# No data found for batter waltodo01 in 2025 - OK
# No data found for batter santade01 in 2025 - OK
# No data found for batter canaral01 in 2025 - OK
# No data found for batter crowape01 in 2025 - OK
# No data found for batter hernada03 in 2025 - OK
# No data found for batter milleer01 in 2025 - OK
# No data found for batter acunajo01 in 2025 - OK
# No data found for batter romanjo03 in 2025 - OK
# No data found for batter koenija01 in 2025 - OK
# No data found for batter sanchga02 in 2025 - OK
# No data found for batter nunezde01 in 2025 - OK
# No data found for batter brazohu01 in 2025 - OK
# No data found for batter eovalna01 in 2025 - OK
# No data found for batter friedtj01 in 2025 - OK
# No data found for batter schwesp01 in 2025 - OK
# No data found for batter mahlety01 in 2025 - OK
# No data found for batter raleica01 in 2025 - OK
# No data found for batter garvemi01 in 2025 - OK
# No data found for batter nidoto01 in 2025 - OK
# No data found for batter guerrvl02 in 2025 - OK
# No data found for batter whitlga01 in 2025 - OK
# No data found for batter hendrky01 in 2025 - OK
# No data found for batter saggeth01 in 2025 - OK
# No data found for batter luciama01 in 2025 - OK
# No data found for batter cabrege01 in 2025 - OK
# No data found for batter johnspi01 in 2025 - OK
# No data found for batter gorema01 in 2025 - OK
# No data found for batter roycrch01 in 2025 - OK
# No data found for batter taylosa04 in 2025 - OK
# No data found for batter alexasc02 in 2025 - OK
# No data found for batter burleal01 in 2025 - OK
# No data found for batter kellyza01 in 2025 - OK
# No data found for batter hiurake01 in 2025 - OK
# No data found for batter mcmiljo01 in 2025 - OK
# No data found for batter lindofr01 in 2025 - OK
# No data found for batter kranima01 in 2025 - OK
# No data found for batter scottta01 in 2025 - OK
# No data found for batter smithaj01 in 2025 - OK
# No data found for batter navarbr01 in 2025 - OK
# No data found for batter castrha01 in 2025 - OK
# No data found for batter loftini01 in 2025 - OK
# No data found for batter okeefbr01 in 2025 - OK
# No data found for batter murfepe01 in 2025 - OK
# No data found for batter oberba01 in 2025 - OK
# No data found for batter garabge01 in 2025 - OK
# No data found for batter taillja01 in 2025 - OK
# No data found for batter jimenle01 in 2025 - OK
# No data found for batter bernabr01 in 2025 - OK
# No data found for batter gourryu01 in 2025 - OK
# No data found for batter martida03 in 2025 - OK
# No data found for batter munozan01 in 2025 - OK
# No data found for batter alcanse01 in 2025 - OK
# No data found for batter margoma01 in 2025 - OK
# No data found for batter steveca01 in 2025 - OK
# No data found for batter robinch04 in 2025 - OK
# No data found for batter mollsa01 in 2025 - OK
# No data found for batter espadjo01 in 2025 - OK
# No data found for batter ryanjo04 in 2025 - OK
# No data found for batter hodgepo01 in 2025 - OK
# No data found for batter webblo01 in 2025 - OK
# No data found for batter holtoty01 in 2025 - OK
# No data found for batter curtijo02 in 2025 - OK
# No data found for batter brennwi02 in 2025 - OK
# No data found for batter frypa01 in 2025 - OK
# No data found for batter garcilu03 in 2025 - OK
# No data found for batter churcma01 in 2025 - OK
# No data found for batter willitr01 in 2025 - OK
# No data found for batter greenhu01 in 2025 - OK
# No data found for batter montera01 in 2025 - OK
# No data found for batter gomezyo01 in 2025 - OK
# No data found for batter rouppla01 in 2025 - OK
# No data found for batter fernary01 in 2025 - OK
# No data found for batter larnatr01 in 2025 - OK
# No data found for batter fraziad01 in 2025 - OK
# No data found for batter caspabe01 in 2025 - OK
# No data found for batter becktr01 in 2025 - OK
# No data found for batter gaddihu01 in 2025 - OK
# No data found for batter grishtr01 in 2025 - OK
# No data found for batter schmica01 in 2025 - OK
# No data found for batter zerpaan01 in 2025 - OK
# No data found for batter misiean01 in 2025 - OK
# No data found for batter semiema01 in 2025 - OK
# No data found for batter rossjo01 in 2025 - OK
# No data found for batter nolaau01 in 2025 - OK
# No data found for batter perezsa02 in 2025 - OK
# No data found for batter grayso01 in 2025 - OK
# No data found for batter mccorch01 in 2025 - OK
# No data found for batter springe01 in 2025 - OK
# No data found for batter brownhu01 in 2025 - OK
# No data found for batter diazel01 in 2025 - OK
# No data found for batter neelyja01 in 2025 - OK
# No data found for batter lodolni01 in 2025 - OK
# No data found for batter mondona01 in 2025 - OK
# No data found for batter shortza01 in 2025 - OK
# No data found for batter kingmi01 in 2025 - OK
# No data found for batter maldoma01 in 2025 - OK
# No data found for batter perdoge01 in 2025 - OK
# No data found for batter mitchga01 in 2025 - OK
# No data found for batter thomala02 in 2025 - OK
# No data found for batter roblevi01 in 2025 - OK
# No data found for batter candeje01 in 2025 - OK
# No data found for batter palenda01 in 2025 - OK
# No data found for batter wilsoja05 in 2025 - OK
# No data found for batter pukaj01 in 2025 - OK
# No data found for batter vaughan01 in 2025 - OK
# No data found for batter isbelky01 in 2025 - OK
# No data found for batter matonni01 in 2025 - OK
# No data found for batter amayaja01 in 2025 - OK
# No data found for batter ohopplo01 in 2025 - OK
# No data found for batter weissgr01 in 2025 - OK
# No data found for batter merryju01 in 2025 - OK
# No data found for batter hummeco01 in 2025 - OK
# No data found for batter farmeky01 in 2025 - OK
# No data found for batter gurrilo01 in 2025 - OK
# No data found for batter lopezot01 in 2025 - OK
# No data found for batter ceasedy01 in 2025 - OK
# No data found for batter burgeja01 in 2025 - OK
# No data found for batter salech01 in 2025 - OK
# No data found for batter olivaja01 in 2025 - OK
# No data found for batter waterdr01 in 2025 - OK
# No data found for batter banksta01 in 2025 - OK
# No data found for batter kellebr01 in 2025 - OK
# No data found for batter baeji01 in 2025 - OK
# No data found for batter paredis01 in 2025 - OK
# No data found for batter brantro01 in 2025 - OK
# No data found for batter suareeu01 in 2025 - OK
# No data found for batter roberlu01 in 2025 - OK
# No data found for batter barneau01 in 2025 - OK
# No data found for batter narvaom01 in 2025 - OK
# No data found for batter perezci01 in 2025 - OK
# No data found for batter coningr01 in 2025 - OK
# No data found for batter cleavga01 in 2025 - OK
# No data found for batter searsjp01 in 2025 - OK
# No data found for batter brujavi01 in 2025 - OK
# No data found for batter jonesja08 in 2025 - OK
# No data found for batter arandjo01 in 2025 - OK
# No data found for batter rodrira02 in 2025 - OK
# No data found for batter bledajj01 in 2025 - OK
# No data found for batter swansda01 in 2025 - OK
# No data found for batter stottbr01 in 2025 - OK
# No data found for batter pegueel01 in 2025 - OK
# No data found for batter ramoshe02 in 2025 - OK
# No data found for batter karinja01 in 2025 - OK
# No data found for batter ruizjo01 in 2025 - OK
# No data found for batter harpebr03 in 2025 - OK
# No data found for batter cuasjo01 in 2025 - OK
# No data found for batter adamewi01 in 2025 - OK
# No data found for batter kahnlto01 in 2025 - OK
# No data found for batter ahmedni01 in 2025 - OK
# No data found for batter storytr01 in 2025 - OK
# No data found for batter naylojo01 in 2025 - OK
# No data found for batter couloda01 in 2025 - OK
# No data found for batter janseke01 in 2025 - OK
# No data found for batter baezja01 in 2025 - OK
# No data found for batter keplema01 in 2025 - OK
# No data found for batter singljo02 in 2025 - OK
# No data found for batter noeljh01 in 2025 - OK
# No data found for batter stefami01 in 2025 - OK
# No data found for batter harrimi04 in 2025 - OK
# No data found for batter bartjo01 in 2025 - OK
# No data found for batter canhama01 in 2025 - OK
# No data found for batter velasvi01 in 2025 - OK
# No data found for batter richaly01 in 2025 - OK
# No data found for batter blancro01 in 2025 - OK
# No data found for batter buschmi02 in 2025 - OK
# No data found for batter trivilo01 in 2025 - OK
# No data found for batter happia01 in 2025 - OK
# No data found for batter pederjo01 in 2025 - OK
# No data found for batter leahyky01 in 2025 - OK
# No data found for batter taverle01 in 2025 - OK
# No data found for batter leedy01 in 2025 - OK
# No data found for batter fermijo01 in 2025 - OK
# No data found for batter jankotr01 in 2025 - OK
# No data found for batter sweentr01 in 2025 - OK
# No data found for batter halvose01 in 2025 - OK
# No data found for batter battema01 in 2025 - OK
# No data found for batter eatonna01 in 2025 - OK
# No data found for batter parisky01 in 2025 - OK
# No data found for batter slateau01 in 2025 - OK
# No data found for batter harvehu01 in 2025 - OK
# No data found for batter garciar01 in 2025 - OK
# No data found for batter heinety01 in 2025 - OK
# No data found for batter contrro01 in 2025 - OK
# No data found for batter ferguca01 in 2025 - OK
# No data found for batter kineris01 in 2025 - OK
# No data found for batter wheelza01 in 2025 - OK
# No data found for batter huffsa01 in 2025 - OK
# No data found for batter solando01 in 2025 - OK
# No data found for batter bidoos01 in 2025 - OK
# No data found for batter hedgeau01 in 2025 - OK
# No data found for batter liberma01 in 2025 - OK
# No data found for batter okeych01 in 2025 - OK
# No data found for batter indiajo01 in 2025 - OK
# No data found for batter hillde01 in 2025 - OK
# No data found for batter matoslu02 in 2025 - OK
# No data found for batter topaju01 in 2025 - OK
# No data found for batter stripro01 in 2025 - OK
# No data found for batter davisau01 in 2025 - OK
# No data found for batter encarch01 in 2025 - OK
# No data found for batter sosale01 in 2025 - OK
# No data found for batter martich02 in 2025 - OK
# No data found for batter mckinza01 in 2025 - OK
# No data found for batter davisjd01 in 2025 - OK
# No data found for batter dovalca01 in 2025 - OK
# No data found for batter arozara01 in 2025 - OK
# No data found for batter dalbebo01 in 2025 - OK
# No data found for batter anderni01 in 2025 - OK
# No data found for batter wellsau01 in 2025 - OK
# No data found for batter toroab01 in 2025 - OK
# No data found for batter adonjo01 in 2025 - OK
# No data found for batter martini02 in 2025 - OK
# No data found for batter olsonma02 in 2025 - OK
# No data found for batter waltean01 in 2025 - OK
# No data found for batter hernate01 in 2025 - OK
# No data found for batter henrypa01 in 2025 - OK
# No data found for batter jungjo01 in 2025 - OK
# No data found for batter marteke01 in 2025 - OK
# No data found for batter ribalor01 in 2025 - OK
# No data found for batter stanery01 in 2025 - OK
# No data found for batter blanktr01 in 2025 - OK
# No data found for batter wachami01 in 2025 - OK
# No data found for batter ruizke01 in 2025 - OK
# No data found for batter wilsoju10 in 2025 - OK
# No data found for batter villach01 in 2025 - OK
# No data found for batter berrijo01 in 2025 - OK
# No data found for batter simslu01 in 2025 - OK
# No data found for batter hurtuja01 in 2025 - OK
# No data found for batter rojasjo03 in 2025 - OK
# No data found for batter breweco01 in 2025 - OK
# No data found for batter mccarja02 in 2025 - OK
# No data found for batter haggesa01 in 2025 - OK
# No data found for batter mastrmi01 in 2025 - OK
# No data found for batter marchra01 in 2025 - OK
# No data found for batter tuckeky01 in 2025 - OK
# No data found for batter dubonma01 in 2025 - OK
# No data found for batter friedma01 in 2025 - OK
# No data found for batter bogaexa01 in 2025 - OK
# No data found for batter smithbu03 in 2025 - OK
# No data found for batter smithca06 in 2025 - OK
# No data found for batter hartlge01 in 2025 - OK
# No data found for batter carpeke01 in 2025 - OK
# No data found for batter hampsga01 in 2025 - OK
# No data found for batter altavda01 in 2025 - OK
# No data found for batter clarkta01 in 2025 - OK
# No data found for batter kjershe01 in 2025 - OK
# No data found for batter fittsri01 in 2025 - OK
# No data found for batter batybr01 in 2025 - OK
# No data found for batter baldwbr01 in 2025 - OK
# No data found for batter harridu01 in 2025 - OK
# No data found for batter bakerlu01 in 2025 - OK
# No data found for batter bazared01 in 2025 - OK
# No data found for batter wiemejo01 in 2025 - OK
# No data found for batter martise01 in 2025 - OK
# No data found for batter smithwi05 in 2025 - OK
# No data found for batter sprinje01 in 2025 - OK
# No data found for batter kelenja01 in 2025 - OK
# No data found for batter brasiry01 in 2025 - OK
# No data found for batter ibanean01 in 2025 - OK
# No data found for batter quantca01 in 2025 - OK
# No data found for batter rodrien01 in 2025 - OK
# No data found for batter pagespe02 in 2025 - OK
# No data found for batter wadela01 in 2025 - OK
# No data found for batter dejonpa01 in 2025 - OK
# No data found for batter salazce01 in 2025 - OK
# No data found for batter sotoju01 in 2025 - OK
# No data found for batter belljo02 in 2025 - OK
# No data found for batter hudsojo03 in 2025 - OK
# No data found for batter ramirjo01 in 2025 - OK
# No data found for batter zeferry01 in 2025 - OK
# No data found for batter monteke01 in 2025 - OK
# No data found for batter alonspe01 in 2025 - OK
# No data found for batter vargaca01 in 2025 - OK
# No data found for batter joeco01 in 2025 - OK
# No data found for batter bassich01 in 2025 - OK
# No data found for batter mortoch02 in 2025 - OK
# No data found for batter bouchse01 in 2025 - OK
# No data found for batter tellero01 in 2025 - OK
# No data found for batter wardta01 in 2025 - OK
# No data found for batter severlu01 in 2025 - OK
# No data found for batter hicklbr01 in 2025 - OK
# No data found for batter chivian01 in 2025 - OK
# No data found for batter grullde01 in 2025 - OK
# No data found for batter hamilia01 in 2025 - OK
# No data found for batter campulu01 in 2025 - OK
# No data found for batter tengka01 in 2025 - OK
# No data found for batter monteco01 in 2025 - OK
# No data found for batter chapmar01 in 2025 - OK
# No data found for batter crewsdy01 in 2025 - OK
# No data found for batter torkesp01 in 2025 - OK
# No data found for batter bregmal01 in 2025 - OK
# No data found for batter uriasra01 in 2025 - OK
# No data found for batter hughebr01 in 2025 - OK
# No data found for batter martiau01 in 2025 - OK
# No data found for batter bichebo01 in 2025 - OK
# No data found for batter snideco01 in 2025 - OK
# No data found for batter wendzda01 in 2025 - OK
# No data found for batter tenajo01 in 2025 - OK
# No data found for batter booseca01 in 2025 - OK
# No data found for batter sternju01 in 2025 - OK
# No data found for batter salazed01 in 2025 - OK
# No data found for batter holdeco01 in 2025 - OK
# No data found for batter littlbr02 in 2025 - OK
# No data found for batter callal02 in 2025 - OK
# No data found for batter clemeko01 in 2025 - OK
# No data found for batter fordmi01 in 2025 - OK
# No data found for batter devench02 in 2025 - OK
# No data found for batter scottvi01 in 2025 - OK
# No data found for batter morejad01 in 2025 - OK
# No data found for batter flaheja01 in 2025 - OK
# No data found for batter florewi01 in 2025 - OK
# No data found for batter delacel01 in 2025 - OK
# No data found for batter allengr01 in 2025 - OK
# No data found for batter brossmi01 in 2025 - OK
# No data found for batter altuvjo01 in 2025 - OK
# No data found for batter blancda02 in 2025 - OK
# No data found for batter bertijo01 in 2025 - OK
# No data found for batter hurtebr01 in 2025 - OK
# No data found for batter alvarar01 in 2025 - OK
# No data found for batter chishja01 in 2025 - OK
# No data found for batter kaiseco01 in 2025 - OK
# No data found for batter ferguty01 in 2025 - OK
# No data found for batter troutmi01 in 2025 - OK
# No data found for batter mccutan01 in 2025 - OK
# No data found for batter hjellse01 in 2025 - OK
# No data found for batter dunnol01 in 2025 - OK
# No data found for batter westbja02 in 2025 - OK
# No data found for batter anderju01 in 2025 - OK
# No data found for batter mcclash01 in 2025 - OK
# No data found for batter chapmma01 in 2025 - OK
# No data found for batter maedake01 in 2025 - OK
# No data found for batter allenni02 in 2025 - OK
# No data found for batter wagnewi01 in 2025 - OK
# No data found for batter duranez01 in 2025 - OK
# No data found for batter fitzgty01 in 2025 - OK
# No data found for batter fraleja01 in 2025 - OK
# No data found for batter nimmobr01 in 2025 - OK
# No data found for batter pasquvi01 in 2025 - OK
# No data found for batter beckjo01 in 2025 - OK
# No data found for batter haaseer01 in 2025 - OK
# No data found for batter profaju01 in 2025 - OK
# No data found for batter nodary01 in 2025 - OK
# No data found for batter singebr01 in 2025 - OK
# No data found for batter haderjo01 in 2025 - OK
# No data found for batter arrigsp01 in 2025 - OK
# No data found for batter claseem01 in 2025 - OK
# No data found for batter kellyme01 in 2025 - OK
# No data found for batter biggehu01 in 2025 - OK
# No data found for batter sanchal04 in 2025 - OK
# No data found for batter degotal01 in 2025 - OK
# No data found for batter burkese01 in 2025 - OK
# No data found for batter schneda04 in 2025 - OK
# No data found for batter hoskirh01 in 2025 - OK
# No data found for batter casastr01 in 2025 - OK
# No data found for batter hillisa01 in 2025 - OK
# No data found for batter trevijo01 in 2025 - OK
# No data found for batter stoweky01 in 2025 - OK
# No data found for batter turneju01 in 2025 - OK
# No data found for batter sotogr01 in 2025 - OK
# No data found for batter kellemi03 in 2025 - OK
# No data found for batter newmake01 in 2025 - OK
# No data found for batter carroco02 in 2025 - OK
# No data found for batter penara02 in 2025 - OK
# No data found for batter barnhtu01 in 2025 - OK
# No data found for batter donovbr01 in 2025 - OK
# No data found for batter jaxgr01 in 2025 - OK
# No data found for batter hornba01 in 2025 - OK
# No data found for batter mecklwa01 in 2025 - OK
# No data found for batter eiserbr01 in 2025 - OK
# No data found for batter diazal03 in 2025 - OK
# No data found for batter gillico01 in 2025 - OK
# All batter IDs processed and saved
# No data found for pitcher cessalu01 in 2025 - OK
# No data found for pitcher zastrro01 in 2025 - OK
# No data found for pitcher junisja01 in 2025 - OK
# No data found for pitcher nerishe01 in 2025 - OK
# No data found for pitcher chaveje01 in 2025 - OK
# No data found for pitcher crochga01 in 2025 - OK
# No data found for pitcher estraje01 in 2025 - OK
# No data found for pitcher rodried05 in 2025 - OK
# No data found for pitcher wilsost02 in 2025 - OK
# No data found for pitcher holmecl01 in 2025 - OK
# No data found for pitcher burkebr01 in 2025 - OK
# No data found for pitcher bowdebe01 in 2025 - OK
# No data found for pitcher santogr01 in 2025 - OK
# No data found for pitcher mercami01 in 2025 - OK
# No data found for pitcher pallaan01 in 2025 - OK
# No data found for pitcher gombeau01 in 2025 - OK
# No data found for pitcher gilbelo01 in 2025 - OK
# No data found for pitcher nelsory01 in 2025 - OK
# No data found for pitcher woodfja01 in 2025 - OK
# No data found for pitcher soriage01 in 2025 - OK
# No data found for pitcher erceglu01 in 2025 - OK
# No data found for pitcher castrmi01 in 2025 - OK
# No data found for pitcher boydma01 in 2025 - OK
# No data found for pitcher lopezre01 in 2025 - OK
# No data found for pitcher matsuyu01 in 2025 - OK
# No data found for pitcher kriskbr01 in 2025 - OK
# /var/folders/5h/v8qm6jqd52q00q39r0ym2qhw0000gn/T/ipykernel_14629/102522992.py:68: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# No data found for pitcher megiltr01 in 2025 - OK
# No data found for pitcher strzepe01 in 2025 - OK
# /var/folders/5h/v8qm6jqd52q00q39r0ym2qhw0000gn/T/ipykernel_14629/102522992.py:68: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# No data found for pitcher ellarfr01 in 2025 - OK
# No data found for pitcher cannigr01 in 2025 - OK
# No data found for pitcher zulueyo01 in 2025 - OK
# No data found for pitcher pocheco01 in 2025 - OK
# No data found for pitcher romerjo01 in 2025 - OK
# No data found for pitcher ottavad01 in 2025 - OK
# No data found for pitcher hartky01 in 2025 - OK
# ...
# No data found for pitcher mayzati01 in 2025 - OK
# No data found for pitcher kellyke02 in 2025 - OK
# No data found for pitcher leiteja01 in 2025 - OK
# No data found for pitcher curryxz01 in 2025 - OK
# No data found for pitcher busenal01 in 2025 - OK
# No data found for pitcher phillty01 in 2025 - OK
# No data found for pitcher pfaadbr01 in 2025 - OK
# No data found for pitcher garzaju01 in 2025 - OK
# No data found for pitcher rodrich01 in 2025 - OK
# No data found for pitcher rodriri05 in 2025 - OK
# No data found for pitcher vestwi01 in 2025 - OK
# No data found for pitcher falteba01 in 2025 - OK
# No data found for pitcher pilkiko01 in 2025 - OK
# No data found for pitcher rodriel02 in 2025 - OK
# No data found for pitcher millebr04 in 2025 - OK
# No data found for pitcher rodonca01 in 2025 - OK
# No data found for pitcher bednada01 in 2025 - OK
# No data found for pitcher obrieri01 in 2025 - OK
# No data found for pitcher abbotan01 in 2025 - OK
# No data found for pitcher santito01 in 2025 - OK
# No data found for pitcher finneky01 in 2025 - OK
# No data found for pitcher gillalo01 in 2025 - OK
# No data found for pitcher gerbejo01 in 2025 - OK
# No data found for pitcher iglesra01 in 2025 - OK
# No data found for pitcher uribeab01 in 2025 - OK
# No data found for pitcher brebbjo01 in 2025 - OK
# No data found for pitcher strathu01 in 2025 - OK
# No data found for pitcher helslry01 in 2025 - OK
# No data found for pitcher delosen01 in 2025 - OK
# No data found for pitcher harriho03 in 2025 - OK
# No data found for pitcher bakerbr01 in 2025 - OK
# No data found for pitcher rogerta01 in 2025 - OK
# No data found for pitcher mcfartj01 in 2025 - OK
# No data found for pitcher nolaaa01 in 2025 - OK
# No data found for pitcher hergeji01 in 2025 - OK
# No data found for pitcher slateju01 in 2025 - OK
# No data found for pitcher scherma01 in 2025 - OK
# No data found for pitcher williga01 in 2025 - OK
# No data found for pitcher elderbr01 in 2025 - OK
# No data found for pitcher lovelri01 in 2025 - OK
# No data found for pitcher martiju01 in 2025 - OK
# No data found for pitcher urenajo01 in 2025 - OK
# No data found for pitcher millesh01 in 2025 - OK
# No data found for pitcher jackslu01 in 2025 - OK
# No data found for pitcher blalobr01 in 2025 - OK
# No data found for pitcher boylejo01 in 2025 - OK
# No data found for pitcher seaboco01 in 2025 - OK
# No data found for pitcher justiev01 in 2025 - OK
# No data found for pitcher legumca01 in 2025 - OK
# No data found for pitcher contrlu01 in 2025 - OK
# No data found for pitcher weavelu01 in 2025 - OK
# No data found for pitcher raineta01 in 2025 - OK
# No data found for pitcher varlagu01 in 2025 - OK
# No data found for pitcher perallu01 in 2025 - OK
# No data found for pitcher fauchca01 in 2025 - OK
# No data found for pitcher cantijo01 in 2025 - OK
# No data found for pitcher glasnty01 in 2025 - OK
# No data found for pitcher marinro01 in 2025 - OK
# No data found for pitcher sousabe01 in 2025 - OK
# No data found for pitcher peralfr01 in 2025 - OK
# No data found for pitcher ferrejo01 in 2025 - OK
# No data found for pitcher pepiory01 in 2025 - OK
# No data found for pitcher thompry02 in 2025 - OK
# No data found for pitcher wilsobr02 in 2025 - OK
# No data found for pitcher kerkeor01 in 2025 - OK
# No data found for pitcher lasorjo01 in 2025 - OK
# No data found for pitcher littllu01 in 2025 - OK
# No data found for pitcher detmere01 in 2025 - OK
# No data found for pitcher fairbpe01 in 2025 - OK
# No data found for pitcher joycebe01 in 2025 - OK
# No data found for pitcher herriti01 in 2025 - OK
# No data found for pitcher bachala01 in 2025 - OK
# No data found for pitcher borucry01 in 2025 - OK
# No data found for pitcher eflinza01 in 2025 - OK
# No data found for pitcher sandsco01 in 2025 - OK
# No data found for pitcher feltnry01 in 2025 - OK
# No data found for pitcher mantijo01 in 2025 - OK
# No data found for pitcher hanifbr01 in 2025 - OK
# No data found for pitcher stratch01 in 2025 - OK
# No data found for pitcher brighje01 in 2025 - OK
# No data found for pitcher bummeaa01 in 2025 - OK
# No data found for pitcher soriajo02 in 2025 - OK
# No data found for pitcher freelky01 in 2025 - OK
# No data found for pitcher kingjo01 in 2025 - OK
# No data found for pitcher livelbe01 in 2025 - OK
# No data found for pitcher willide03 in 2025 - OK
# No data found for pitcher suarero01 in 2025 - OK
# No data found for pitcher hillja01 in 2025 - OK
# No data found for pitcher bivensp01 in 2025 - OK
# No data found for pitcher brashma01 in 2025 - OK
# No data found for pitcher leclejo01 in 2025 - OK
# No data found for pitcher megilty01 in 2025 - OK
# No data found for pitcher mcgremi01 in 2025 - OK
# /var/folders/5h/v8qm6jqd52q00q39r0ym2qhw0000gn/T/ipykernel_14629/102522992.py:68: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# No data found for pitcher padilni01 in 2025 - OK
# No data found for pitcher overtco01 in 2025 - OK
# No data found for pitcher castrke01 in 2025 - OK
# No data found for pitcher burgora01 in 2025 - OK
# No data found for pitcher woodssi01 in 2025 - OK
# No data found for pitcher hernani01 in 2025 - OK
# No data found for pitcher benjawe01 in 2025 - OK
# No data found for pitcher olsonre01 in 2025 - OK
# /var/folders/5h/v8qm6jqd52q00q39r0ym2qhw0000gn/T/ipykernel_14629/102522992.py:68: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# No data found for pitcher duranjh01 in 2025 - OK
# No data found for pitcher headrbr01 in 2025 - OK
# No data found for pitcher lucchjo01 in 2025 - OK
# No data found for pitcher guentse01 in 2025 - OK
# No data found for pitcher birdsha01 in 2025 - OK
# No data found for pitcher castilu02 in 2025 - OK
# No data found for pitcher sorokmi01 in 2025 - OK
# No data found for pitcher lawreju01 in 2025 - OK
# No data found for pitcher leitema02 in 2025 - OK
# No data found for pitcher colemdy01 in 2025 - OK
# No data found for pitcher quijajo01 in 2025 - OK
# No data found for pitcher okertst01 in 2025 - OK
# No data found for pitcher hahnje01 in 2025 - OK
# No data found for pitcher reaco01 in 2025 - OK
# No data found for pitcher raganco01 in 2025 - OK
# No data found for pitcher bowmama01 in 2025 - OK
# No data found for pitcher bendean01 in 2025 - OK
# No data found for pitcher spencmi01 in 2025 - OK
# No data found for pitcher sauceta01 in 2025 - OK
# No data found for pitcher luzarje01 in 2025 - OK
# No data found for pitcher bibeeta01 in 2025 - OK
# No data found for pitcher alexaty01 in 2025 - OK
# No data found for pitcher walketa01 in 2025 - OK
# No data found for pitcher blewesc01 in 2025 - OK
# No data found for pitcher jarvibr01 in 2025 - OK
# No data found for pitcher mushipa01 in 2025 - OK
# No data found for pitcher stromma01 in 2025 - OK
# No data found for pitcher anderia01 in 2025 - OK
# No data found for pitcher canoye01 in 2025 - OK
# No data found for pitcher santade01 in 2025 - OK
# No data found for pitcher hernada03 in 2025 - OK
# No data found for pitcher milleer01 in 2025 - OK
# No data found for pitcher romanjo03 in 2025 - OK
# No data found for pitcher koenija01 in 2025 - OK
# No data found for pitcher nunezde01 in 2025 - OK
# No data found for pitcher brazohu01 in 2025 - OK
# No data found for pitcher eovalna01 in 2025 - OK
# No data found for pitcher schwesp01 in 2025 - OK
# No data found for pitcher mahlety01 in 2025 - OK
# No data found for pitcher whitlga01 in 2025 - OK
# No data found for pitcher hendrky01 in 2025 - OK
# No data found for pitcher cabrege01 in 2025 - OK
# No data found for pitcher johnspi01 in 2025 - OK
# No data found for pitcher gorema01 in 2025 - OK
# No data found for pitcher roycrch01 in 2025 - OK
# No data found for pitcher alexasc02 in 2025 - OK
# No data found for pitcher kellyza01 in 2025 - OK
# No data found for pitcher mcmiljo01 in 2025 - OK
# No data found for pitcher kranima01 in 2025 - OK
# /var/folders/5h/v8qm6jqd52q00q39r0ym2qhw0000gn/T/ipykernel_14629/102522992.py:68: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# No data found for pitcher smithaj01 in 2025 - OK
# No data found for pitcher murfepe01 in 2025 - OK
# No data found for pitcher oberba01 in 2025 - OK
# No data found for pitcher garabge01 in 2025 - OK
# No data found for pitcher taillja01 in 2025 - OK
# No data found for pitcher bernabr01 in 2025 - OK
# No data found for pitcher martida03 in 2025 - OK
# No data found for pitcher munozan01 in 2025 - OK
# No data found for pitcher mollsa01 in 2025 - OK
# No data found for pitcher espadjo01 in 2025 - OK
# No data found for pitcher ryanjo04 in 2025 - OK
# /var/folders/5h/v8qm6jqd52q00q39r0ym2qhw0000gn/T/ipykernel_14629/102522992.py:68: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# No data found for pitcher webblo01 in 2025 - OK
# No data found for pitcher holtoty01 in 2025 - OK
# No data found for pitcher curtijo02 in 2025 - OK
# No data found for pitcher frypa01 in 2025 - OK
# /var/folders/5h/v8qm6jqd52q00q39r0ym2qhw0000gn/T/ipykernel_14629/102522992.py:68: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# No data found for pitcher churcma01 in 2025 - OK
# No data found for pitcher willitr01 in 2025 - OK
# No data found for pitcher greenhu01 in 2025 - OK
# No data found for pitcher montera01 in 2025 - OK
# No data found for pitcher gomezyo01 in 2025 - OK
# No data found for pitcher rouppla01 in 2025 - OK
# No data found for pitcher fernary01 in 2025 - OK
# /var/folders/5h/v8qm6jqd52q00q39r0ym2qhw0000gn/T/ipykernel_14629/102522992.py:68: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# No data found for pitcher becktr01 in 2025 - OK
# No data found for pitcher gaddihu01 in 2025 - OK
# No data found for pitcher zerpaan01 in 2025 - OK
# No data found for pitcher misiean01 in 2025 - OK
# No data found for pitcher rossjo01 in 2025 - OK
# No data found for pitcher grayso01 in 2025 - OK
# No data found for pitcher brownhu01 in 2025 - OK
# No data found for pitcher neelyja01 in 2025 - OK
# No data found for pitcher lodolni01 in 2025 - OK
# No data found for pitcher kingmi01 in 2025 - OK
# No data found for pitcher palenda01 in 2025 - OK
# No data found for pitcher pukaj01 in 2025 - OK
# No data found for pitcher weissgr01 in 2025 - OK
# /var/folders/5h/v8qm6jqd52q00q39r0ym2qhw0000gn/T/ipykernel_14629/102522992.py:68: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# No data found for pitcher ceasedy01 in 2025 - OK
# No data found for pitcher salech01 in 2025 - OK
# No data found for pitcher banksta01 in 2025 - OK
# No data found for pitcher kellebr01 in 2025 - OK
# No data found for pitcher perezci01 in 2025 - OK
# No data found for pitcher cleavga01 in 2025 - OK
# No data found for pitcher searsjp01 in 2025 - OK
# No data found for pitcher rodrira02 in 2025 - OK
# No data found for pitcher pegueel01 in 2025 - OK
# No data found for pitcher karinja01 in 2025 - OK
# No data found for pitcher ruizjo01 in 2025 - OK
# No data found for pitcher cuasjo01 in 2025 - OK
# No data found for pitcher kahnlto01 in 2025 - OK
# No data found for pitcher couloda01 in 2025 - OK
# No data found for pitcher janseke01 in 2025 - OK
# No data found for pitcher velasvi01 in 2025 - OK
# No data found for pitcher richaly01 in 2025 - OK
# No data found for pitcher blancro01 in 2025 - OK
# No data found for pitcher trivilo01 in 2025 - OK
# No data found for pitcher leahyky01 in 2025 - OK
# No data found for pitcher leedy01 in 2025 - OK
# No data found for pitcher halvose01 in 2025 - OK
# No data found for pitcher harvehu01 in 2025 - OK
# No data found for pitcher contrro01 in 2025 - OK
# No data found for pitcher ferguca01 in 2025 - OK
# No data found for pitcher wheelza01 in 2025 - OK
# No data found for pitcher bidoos01 in 2025 - OK
# No data found for pitcher liberma01 in 2025 - OK
# No data found for pitcher topaju01 in 2025 - OK
# No data found for pitcher stripro01 in 2025 - OK
# No data found for pitcher davisau01 in 2025 - OK
# No data found for pitcher martich02 in 2025 - OK
# No data found for pitcher dovalca01 in 2025 - OK
# No data found for pitcher anderni01 in 2025 - OK
# No data found for pitcher adonjo01 in 2025 - OK
# No data found for pitcher waltean01 in 2025 - OK
# No data found for pitcher ribalor01 in 2025 - OK
# No data found for pitcher stanery01 in 2025 - OK
# No data found for pitcher wachami01 in 2025 - OK
# No data found for pitcher wilsoju10 in 2025 - OK
# No data found for pitcher berrijo01 in 2025 - OK
# No data found for pitcher simslu01 in 2025 - OK
# No data found for pitcher breweco01 in 2025 - OK
# No data found for pitcher friedma01 in 2025 - OK
# No data found for pitcher smithbu03 in 2025 - OK
# No data found for pitcher smithca06 in 2025 - OK
# No data found for pitcher hartlge01 in 2025 - OK
# No data found for pitcher altavda01 in 2025 - OK
# No data found for pitcher clarkta01 in 2025 - OK
# No data found for pitcher fittsri01 in 2025 - OK
# No data found for pitcher bazared01 in 2025 - OK
# No data found for pitcher martise01 in 2025 - OK
# No data found for pitcher sprinje01 in 2025 - OK
# /var/folders/5h/v8qm6jqd52q00q39r0ym2qhw0000gn/T/ipykernel_14629/102522992.py:68: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# No data found for pitcher quantca01 in 2025 - OK
# No data found for pitcher zeferry01 in 2025 - OK
# No data found for pitcher monteke01 in 2025 - OK
# No data found for pitcher vargaca01 in 2025 - OK
# No data found for pitcher bassich01 in 2025 - OK
# No data found for pitcher mortoch02 in 2025 - OK
# No data found for pitcher severlu01 in 2025 - OK
# No data found for pitcher chivian01 in 2025 - OK
# No data found for pitcher hamilia01 in 2025 - OK
# No data found for pitcher tengka01 in 2025 - OK
# No data found for pitcher chapmar01 in 2025 - OK
# No data found for pitcher hughebr01 in 2025 - OK
# No data found for pitcher snideco01 in 2025 - OK
# No data found for pitcher booseca01 in 2025 - OK
# No data found for pitcher sternju01 in 2025 - OK
# No data found for pitcher salazed01 in 2025 - OK
# No data found for pitcher holdeco01 in 2025 - OK
# No data found for pitcher littlbr02 in 2025 - OK
# No data found for pitcher devench02 in 2025 - OK
# No data found for pitcher morejad01 in 2025 - OK
# No data found for pitcher flaheja01 in 2025 - OK
# No data found for pitcher hurtebr01 in 2025 - OK
# No data found for pitcher ferguty01 in 2025 - OK
# No data found for pitcher hjellse01 in 2025 - OK
# No data found for pitcher anderju01 in 2025 - OK
# No data found for pitcher mcclash01 in 2025 - OK
# No data found for pitcher maedake01 in 2025 - OK
# No data found for pitcher singebr01 in 2025 - OK
# No data found for pitcher haderjo01 in 2025 - OK
# No data found for pitcher arrigsp01 in 2025 - OK
# No data found for pitcher claseem01 in 2025 - OK
# No data found for pitcher kellyme01 in 2025 - OK
# No data found for pitcher biggehu01 in 2025 - OK
# No data found for pitcher burkese01 in 2025 - OK
# No data found for pitcher sotogr01 in 2025 - OK
# No data found for pitcher kellemi03 in 2025 - OK
# No data found for pitcher jaxgr01 in 2025 - OK
# No data found for pitcher hornba01 in 2025 - OK
# No data found for pitcher eiserbr01 in 2025 - OK
# No data found for pitcher diazal03 in 2025 - OK
# No data found for pitcher gillico01 in 2025 - OK
# All pitcher IDs processed and saved
#
# Player stats updated - SUCCESS
