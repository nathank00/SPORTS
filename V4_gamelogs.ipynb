# %%
import os
import re
import pandas as pd
from pybaseball import statcast_batter, statcast_pitcher, playerid_lookup, pitching_stats_range, batting_stats_range, schedule_and_record, team_game_logs, pybaseball
from datetime import timedelta, datetime
import statsapi
from statsapi import boxscore_data
import pprint
import openpyxl
import mlbstatsapi

# %%
gamepk = 745415
boxscore = boxscore_data(gamePk=gamepk)

# %%
boxscore.keys()
# Out:
# dict_keys(['gameId', 'teamInfo', 'playerInfo', 'away', 'home', 'awayBatters', 'homeBatters', 'awayBattingTotals', 'homeBattingTotals', 'awayBattingNotes', 'homeBattingNotes', 'awayPitchers', 'homePitchers', 'awayPitchingTotals', 'homePitchingTotals', 'gameBoxInfo'])

# %%
pprint.pprint(boxscore)
# Out:
# {'away': {'batters': [683011,
#                       665742,
#                       592450,
#                       657077,
#                       519317,
#                       519203,
#                       650402,
#                       669224,
#                       542932,
#                       607074],
#           'battingOrder': [683011,
#                            665742,
#                            592450,
#                            657077,
#                            519317,
#                            519203,
#                            650402,
#                            669224,
#                            542932],
#           'bench': [665828, 663757, 663330, 624431],
#           'bullpen': [641482,
#                       657571,
#                       661563,
#                       672782,
#                       624647,
#                       605280,
#                       592454,
#                       642701,
#                       657376,
#                       573186,
#                       543859,
#                       596133],
#           'info': [{'fieldList': [{'label': '3B',
#                                    'value': 'Volpe (3, Darvish).'},
#                                   {'label': 'TB', 'value': 'Volpe 3.'},
#                                   {'label': 'RBI', 'value': 'Judge (36).'},
#                                   {'label': 'SF', 'value': 'Judge.'},
#                                   {'label': 'Team RISP', 'value': '0-for-1.'}],
#                     'title': 'BATTING'}],
#           'note': [],
#           'pitchers': [607074],
#           'players': {'ID519203': {'allPositions': [{'abbreviation': '1B'}],
#                                    'battingOrder': '600',
#                                    'gameStatus': {},
#                                    'jerseyNumber': '48',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Anthony Rizzo',
#                                               'id': 519203},
#                                    'position': {'abbreviation': '1B'},
#                                    'seasonStats': {'batting': {'atBats': 194,
#                                                                'avg': '.253',
#                                                                'baseOnBalls': 13,
#                                                                'doubles': 5,
#                                                                'hits': 49,
#                                                                'homeRuns': 7,
#                                                                'leftOnBase': 84,
#                                                                'obp': '.318',
#                                                                'ops': '.705',
#                                                                'rbi': 24,
#                                                                'runs': 26,
#                                                                'slg': '.387',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 39,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {'atBats': 1,
#                                                          'baseOnBalls': 0,
#                                                          'doubles': 0,
#                                                          'hits': 0,
#                                                          'homeRuns': 0,
#                                                          'leftOnBase': 0,
#                                                          'rbi': 0,
#                                                          'runs': 0,
#                                                          'stolenBases': 0,
#                                                          'strikeOuts': 0,
#                                                          'triples': 0},
#                                              'pitching': {}},
#                                    'status': {}},
#                       'ID519317': {'allPositions': [{'abbreviation': 'DH'}],
#                                    'battingOrder': '500',
#                                    'gameStatus': {},
#                                    'jerseyNumber': '27',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Giancarlo Stanton',
#                                               'id': 519317},
#                                    'position': {'abbreviation': 'DH'},
#                                    'seasonStats': {'batting': {'atBats': 168,
#                                                                'avg': '.244',
#                                                                'baseOnBalls': 12,
#                                                                'doubles': 8,
#                                                                'hits': 41,
#                                                                'homeRuns': 12,
#                                                                'leftOnBase': 78,
#                                                                'obp': '.294',
#                                                                'ops': '.800',
#                                                                'rbi': 27,
#                                                                'runs': 22,
#                                                                'slg': '.506',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 56,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {'atBats': 1,
#                                                          'baseOnBalls': 0,
#                                                          'doubles': 0,
#                                                          'hits': 0,
#                                                          'homeRuns': 0,
#                                                          'leftOnBase': 0,
#                                                          'rbi': 0,
#                                                          'runs': 0,
#                                                          'stolenBases': 0,
#                                                          'strikeOuts': 0,
#                                                          'triples': 0},
#                                              'pitching': {}},
#                                    'status': {}},
#                       'ID542932': {'allPositions': [{'abbreviation': '3B'}],
#                                    'battingOrder': '900',
#                                    'gameStatus': {},
#                                    'jerseyNumber': '19',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Jon Berti',
#                                               'id': 542932},
#                                    'position': {'abbreviation': '3B'},
#                                    'seasonStats': {'batting': {'atBats': 51,
#                                                                'avg': '.275',
#                                                                'baseOnBalls': 4,
#                                                                'doubles': 0,
#                                                                'hits': 14,
#                                                                'homeRuns': 1,
#                                                                'leftOnBase': 20,
#                                                                'obp': '.327',
#                                                                'ops': '.660',
#                                                                'rbi': 6,
#                                                                'runs': 6,
#                                                                'slg': '.333',
#                                                                'stolenBases': 3,
#                                                                'strikeOuts': 11,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {'atBats': 0,
#                                                          'baseOnBalls': 0,
#                                                          'doubles': 0,
#                                                          'hits': 0,
#                                                          'homeRuns': 0,
#                                                          'leftOnBase': 0,
#                                                          'rbi': 0,
#                                                          'runs': 0,
#                                                          'stolenBases': 0,
#                                                          'strikeOuts': 0,
#                                                          'triples': 0},
#                                              'pitching': {}},
#                                    'status': {}},
#                       'ID543859': {'gameStatus': {},
#                                    'jerseyNumber': '50',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Michael Tonkin',
#                                               'id': 543859},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 77,
#                                                                 'baseOnBalls': 9,
#                                                                 'blownSaves': 1,
#                                                                 'doubles': 3,
#                                                                 'earnedRuns': 8,
#                                                                 'era': '3.72',
#                                                                 'hits': 19,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 1,
#                                                                 'inningsPitched': '19.1',
#                                                                 'losses': 3,
#                                                                 'numberOfPitches': 399,
#                                                                 'obp': '.348',
#                                                                 'pitchesThrown': 399,
#                                                                 'rbi': 0,
#                                                                 'runs': 18,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 20,
#                                                                 'strikes': 246,
#                                                                 'triples': 0,
#                                                                 'wins': 1}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID573186': {'gameStatus': {},
#                                    'jerseyNumber': '0',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Marcus Stroman',
#                                               'id': 573186},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 208,
#                                                                 'baseOnBalls': 26,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 10,
#                                                                 'earnedRuns': 19,
#                                                                 'era': '3.05',
#                                                                 'hits': 47,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 8,
#                                                                 'inningsPitched': '56.0',
#                                                                 'losses': 2,
#                                                                 'numberOfPitches': 950,
#                                                                 'obp': '.318',
#                                                                 'pitchesThrown': 950,
#                                                                 'rbi': 0,
#                                                                 'runs': 22,
#                                                                 'stolenBases': 4,
#                                                                 'strikeOuts': 48,
#                                                                 'strikes': 570,
#                                                                 'triples': 1,
#                                                                 'wins': 3}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID592450': {'allPositions': [{'abbreviation': 'CF'}],
#                                    'battingOrder': '300',
#                                    'gameStatus': {},
#                                    'jerseyNumber': '99',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Aaron Judge',
#                                               'id': 592450},
#                                    'position': {'abbreviation': 'CF'},
#                                    'seasonStats': {'batting': {'atBats': 185,
#                                                                'avg': '.276',
#                                                                'baseOnBalls': 43,
#                                                                'doubles': 17,
#                                                                'hits': 51,
#                                                                'homeRuns': 15,
#                                                                'leftOnBase': 90,
#                                                                'obp': '.414',
#                                                                'ops': '1.025',
#                                                                'rbi': 36,
#                                                                'runs': 34,
#                                                                'slg': '.611',
#                                                                'stolenBases': 2,
#                                                                'strikeOuts': 56,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {'atBats': 0,
#                                                          'baseOnBalls': 0,
#                                                          'doubles': 0,
#                                                          'hits': 0,
#                                                          'homeRuns': 0,
#                                                          'leftOnBase': 0,
#                                                          'rbi': 1,
#                                                          'runs': 0,
#                                                          'stolenBases': 0,
#                                                          'strikeOuts': 0,
#                                                          'triples': 0},
#                                              'pitching': {}},
#                                    'status': {}},
#                       'ID592454': {'gameStatus': {},
#                                    'jerseyNumber': '41',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Tommy Kahnle',
#                                               'id': 592454},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 3,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '0.00',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '1.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 15,
#                                                                 'obp': '.000',
#                                                                 'pitchesThrown': 15,
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 9,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID596133': {'gameStatus': {},
#                                    'jerseyNumber': '30',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Luke Weaver',
#                                               'id': 596133},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 104,
#                                                                 'baseOnBalls': 5,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 4,
#                                                                 'earnedRuns': 8,
#                                                                 'era': '2.37',
#                                                                 'hits': 15,
#                                                                 'holds': 6,
#                                                                 'homeRuns': 3,
#                                                                 'inningsPitched': '30.1',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 470,
#                                                                 'obp': '.202',
#                                                                 'pitchesThrown': 470,
#                                                                 'rbi': 0,
#                                                                 'runs': 8,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 34,
#                                                                 'strikes': 313,
#                                                                 'triples': 1,
#                                                                 'wins': 3}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID605280': {'gameStatus': {},
#                                    'jerseyNumber': '35',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Clay Holmes',
#                                               'id': 605280},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 85,
#                                                                 'baseOnBalls': 6,
#                                                                 'blownSaves': 2,
#                                                                 'doubles': 1,
#                                                                 'earnedRuns': 4,
#                                                                 'era': '1.64',
#                                                                 'hits': 21,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '22.0',
#                                                                 'losses': 1,
#                                                                 'numberOfPitches': 350,
#                                                                 'obp': '.309',
#                                                                 'pitchesThrown': 350,
#                                                                 'rbi': 0,
#                                                                 'runs': 7,
#                                                                 'stolenBases': 1,
#                                                                 'strikeOuts': 25,
#                                                                 'strikes': 229,
#                                                                 'triples': 0,
#                                                                 'wins': 1}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID607074': {'allPositions': [{'abbreviation': 'P'}],
#                                    'gameStatus': {},
#                                    'jerseyNumber': '55',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Carlos Rodón',
#                                               'id': 607074},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 215,
#                                                                 'baseOnBalls': 16,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 10,
#                                                                 'earnedRuns': 20,
#                                                                 'era': '3.21',
#                                                                 'hits': 51,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 9,
#                                                                 'inningsPitched': '56.0',
#                                                                 'losses': 2,
#                                                                 'numberOfPitches': 962,
#                                                                 'obp': '.307',
#                                                                 'pitchesThrown': 962,
#                                                                 'rbi': 0,
#                                                                 'runs': 21,
#                                                                 'stolenBases': 10,
#                                                                 'strikeOuts': 56,
#                                                                 'strikes': 612,
#                                                                 'triples': 3,
#                                                                 'wins': 5}},
#                                    'stats': {'batting': {},
#                                              'pitching': {'atBats': 4,
#                                                           'baseOnBalls': 0,
#                                                           'blownSaves': 0,
#                                                           'doubles': 0,
#                                                           'earnedRuns': 0,
#                                                           'hits': 1,
#                                                           'holds': 0,
#                                                           'homeRuns': 0,
#                                                           'inningsPitched': '1.0',
#                                                           'losses': 0,
#                                                           'numberOfPitches': 24,
#                                                           'pitchesThrown': 24,
#                                                           'rbi': 0,
#                                                           'runs': 0,
#                                                           'stolenBases': 0,
#                                                           'strikeOuts': 1,
#                                                           'strikes': 12,
#                                                           'triples': 0,
#                                                           'wins': 0}},
#                                    'status': {}},
#                       'ID624431': {'gameStatus': {},
#                                    'jerseyNumber': '39',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Jose Trevino',
#                                               'id': 624431},
#                                    'position': {'abbreviation': 'C'},
#                                    'seasonStats': {'batting': {'atBats': 95,
#                                                                'avg': '.284',
#                                                                'baseOnBalls': 6,
#                                                                'doubles': 0,
#                                                                'hits': 27,
#                                                                'homeRuns': 5,
#                                                                'leftOnBase': 46,
#                                                                'obp': '.330',
#                                                                'ops': '.772',
#                                                                'rbi': 17,
#                                                                'runs': 14,
#                                                                'slg': '.442',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 12,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 5,
#                                                                 'baseOnBalls': 1,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 2,
#                                                                 'earnedRuns': 2,
#                                                                 'era': '18.00',
#                                                                 'hits': 2,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '1.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 18,
#                                                                 'obp': '.500',
#                                                                 'pitchesThrown': 18,
#                                                                 'rbi': 0,
#                                                                 'runs': 2,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 11,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID624647': {'gameStatus': {},
#                                    'jerseyNumber': '47',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Victor González',
#                                               'id': 624647},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 53,
#                                                                 'baseOnBalls': 8,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 1,
#                                                                 'earnedRuns': 4,
#                                                                 'era': '2.30',
#                                                                 'hits': 7,
#                                                                 'holds': 2,
#                                                                 'homeRuns': 2,
#                                                                 'inningsPitched': '15.2',
#                                                                 'losses': 1,
#                                                                 'numberOfPitches': 263,
#                                                                 'obp': '.258',
#                                                                 'pitchesThrown': 263,
#                                                                 'rbi': 0,
#                                                                 'runs': 5,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 6,
#                                                                 'strikes': 152,
#                                                                 'triples': 0,
#                                                                 'wins': 2}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID641482': {'gameStatus': {},
#                                    'jerseyNumber': '65',
#                                    'parentTeamId': 147,
#                                    'person': {'fullName': 'Nestor Cortes',
#                                               'id': 641482},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 247,
# ...
#                   'slg': '.409',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '1',
#                   'avg': '.335',
#                   'battingOrder': '300',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Profar, J',
#                   'namefield': '3 Profar, J  LF',
#                   'note': '',
#                   'obp': '.429',
#                   'ops': '.937',
#                   'personId': 595777,
#                   'position': 'LF',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.508',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '1',
#                   'avg': '.234',
#                   'battingOrder': '400',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '1',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Machado, M',
#                   'namefield': '4 Machado, M  DH',
#                   'note': '',
#                   'obp': '.283',
#                   'ops': '.648',
#                   'personId': 592518,
#                   'position': 'DH',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.365',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.263',
#                   'battingOrder': '500',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Cronenworth',
#                   'namefield': '5 Cronenworth  2B',
#                   'note': '',
#                   'obp': '.329',
#                   'ops': '.782',
#                   'personId': 630105,
#                   'position': '2B',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.453',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.348',
#                   'battingOrder': '600',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Solano',
#                   'namefield': '6 Solano  3B',
#                   'note': '',
#                   'obp': '.423',
#                   'ops': '.814',
#                   'personId': 456781,
#                   'position': '3B',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.391',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.257',
#                   'battingOrder': '700',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Campusano',
#                   'namefield': '7 Campusano  C',
#                   'note': '',
#                   'obp': '.298',
#                   'ops': '.699',
#                   'personId': 669134,
#                   'position': 'C',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.401',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.282',
#                   'battingOrder': '800',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Merrill',
#                   'namefield': '8 Merrill  CF',
#                   'note': '',
#                   'obp': '.326',
#                   'ops': '.700',
#                   'personId': 701538,
#                   'position': 'CF',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.374',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.216',
#                   'battingOrder': '900',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Kim, H',
#                   'namefield': '9 Kim, H  SS',
#                   'note': '',
#                   'obp': '.335',
#                   'ops': '.704',
#                   'personId': 673490,
#                   'position': 'SS',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.369',
#                   'substitution': False,
#                   'triples': '0'}],
#  'homeBattingNotes': {},
#  'homeBattingTotals': {'ab': '4',
#                        'avg': '',
#                        'battingOrder': '',
#                        'bb': '0',
#                        'h': '1',
#                        'hr': '0',
#                        'k': '1',
#                        'lob': '0',
#                        'name': 'Totals',
#                        'namefield': 'Totals',
#                        'note': '',
#                        'obp': '',
#                        'ops': '',
#                        'personId': 0,
#                        'position': '',
#                        'r': '0',
#                        'rbi': '0',
#                        'slg': '',
#                        'substitution': False},
#  'homePitchers': [{'bb': 'BB',
#                    'er': 'ER',
#                    'era': 'ERA',
#                    'h': 'H',
#                    'hr': 'HR',
#                    'ip': 'IP',
#                    'k': 'K',
#                    'name': 'Yankees Pitchers',
#                    'namefield': 'Padres Pitchers',
#                    'note': '',
#                    'p': 'P',
#                    'personId': 0,
#                    'r': 'R',
#                    's': 'S'},
#                   {'bb': '0',
#                    'er': '1',
#                    'era': '2.17',
#                    'h': '1',
#                    'hr': '0',
#                    'ip': '2.0',
#                    'k': '1',
#                    'name': 'Darvish',
#                    'namefield': 'Darvish',
#                    'note': '',
#                    'p': '22',
#                    'personId': 506433,
#                    'r': '1',
#                    's': '17'}],
#  'homePitchingTotals': {'bb': '0',
#                         'er': '1',
#                         'era': '',
#                         'h': '1',
#                         'hr': '0',
#                         'ip': '2.0',
#                         'k': '1',
#                         'name': 'Totals',
#                         'namefield': 'Totals',
#                         'note': '',
#                         'p': '',
#                         'personId': 0,
#                         'r': '1',
#                         's': ''},
#  'playerInfo': {'ID444482': {'boxscoreName': 'Peralta',
#                              'fullName': 'David Peralta',
#                              'id': 444482},
#                 'ID456781': {'boxscoreName': 'Solano',
#                              'fullName': 'Donovan Solano',
#                              'id': 456781},
#                 'ID506433': {'boxscoreName': 'Darvish',
#                              'fullName': 'Yu Darvish',
#                              'id': 506433},
#                 'ID519203': {'boxscoreName': 'Rizzo',
#                              'fullName': 'Anthony Rizzo',
#                              'id': 519203},
#                 'ID519317': {'boxscoreName': 'Stanton',
#                              'fullName': 'Giancarlo Stanton',
#                              'id': 519317},
#                 'ID542932': {'boxscoreName': 'Berti',
#                              'fullName': 'Jon Berti',
#                              'id': 542932},
#                 'ID543309': {'boxscoreName': 'Higashioka',
#                              'fullName': 'Kyle Higashioka',
#                              'id': 543309},
#                 'ID543859': {'boxscoreName': 'Tonkin',
#                              'fullName': 'Michael Tonkin',
#                              'id': 543859},
#                 'ID573186': {'boxscoreName': 'Stroman',
#                              'fullName': 'Marcus Stroman',
#                              'id': 573186},
#                 'ID592450': {'boxscoreName': 'Judge',
#                              'fullName': 'Aaron Judge',
#                              'id': 592450},
#                 'ID592454': {'boxscoreName': 'Kahnle',
#                              'fullName': 'Tommy Kahnle',
#                              'id': 592454},
#                 'ID592518': {'boxscoreName': 'Machado, M',
#                              'fullName': 'Manny Machado',
#                              'id': 592518},
#                 'ID593974': {'boxscoreName': 'Peralta, Wa',
#                              'fullName': 'Wandy Peralta',
#                              'id': 593974},
#                 'ID595777': {'boxscoreName': 'Profar, J',
#                              'fullName': 'Jurickson Profar',
#                              'id': 595777},
#                 'ID596133': {'boxscoreName': 'Weaver',
#                              'fullName': 'Luke Weaver',
#                              'id': 596133},
#                 'ID605280': {'boxscoreName': 'Holmes',
#                              'fullName': 'Clay Holmes',
#                              'id': 605280},
#                 'ID605397': {'boxscoreName': 'Musgrove',
#                              'fullName': 'Joe Musgrove',
#                              'id': 605397},
#                 'ID607074': {'boxscoreName': 'Rodón',
#                              'fullName': 'Carlos Rodón',
#                              'id': 607074},
#                 'ID624431': {'boxscoreName': 'Trevino',
#                              'fullName': 'Jose Trevino',
#                              'id': 624431},
#                 'ID624647': {'boxscoreName': 'González, V',
#                              'fullName': 'Victor González',
#                              'id': 624647},
#                 'ID630105': {'boxscoreName': 'Cronenworth',
#                              'fullName': 'Jake Cronenworth',
#                              'id': 630105},
#                 'ID640492': {'boxscoreName': 'Azocar',
#                              'fullName': 'José Azocar',
#                              'id': 640492},
#                 'ID641482': {'boxscoreName': 'Cortes',
#                              'fullName': 'Nestor Cortes',
#                              'id': 641482},
#                 'ID642180': {'boxscoreName': 'Wade',
#                              'fullName': 'Tyler Wade',
#                              'id': 642180},
#                 'ID642701': {'boxscoreName': 'Santana, D',
#                              'fullName': 'Dennis Santana',
#                              'id': 642701},
#                 'ID650333': {'boxscoreName': 'Arraez',
#                              'fullName': 'Luis Arraez',
#                              'id': 650333},
#                 'ID650402': {'boxscoreName': 'Torres',
#                              'fullName': 'Gleyber Torres',
#                              'id': 650402},
#                 'ID650633': {'boxscoreName': 'King',
#                              'fullName': 'Michael King',
#                              'id': 650633},
#                 'ID656302': {'boxscoreName': 'Cease',
#                              'fullName': 'Dylan Cease',
#                              'id': 656302},
#                 'ID657077': {'boxscoreName': 'Verdugo',
#                              'fullName': 'Alex Verdugo',
#                              'id': 657077},
#                 'ID657376': {'boxscoreName': 'Schmidt',
#                              'fullName': 'Clarke Schmidt',
#                              'id': 657376},
#                 'ID657571': {'boxscoreName': 'Ferguson',
#                              'fullName': 'Caleb Ferguson',
#                              'id': 657571},
#                 'ID660853': {'boxscoreName': 'De Los Santos, E',
#                              'fullName': 'Enyel De Los Santos',
#                              'id': 660853},
#                 'ID661563': {'boxscoreName': 'Gil',
#                              'fullName': 'Luis Gil',
#                              'id': 661563},
#                 'ID663158': {'boxscoreName': 'Suarez, R',
#                              'fullName': 'Robert Suarez',
#                              'id': 663158},
#                 'ID663330': {'boxscoreName': 'Jones, Jah',
#                              'fullName': 'Jahmai Jones',
#                              'id': 663330},
#                 'ID663362': {'boxscoreName': 'Waldron',
#                              'fullName': 'Matt Waldron',
#                              'id': 663362},
#                 'ID663568': {'boxscoreName': 'Kolek',
#                              'fullName': 'Stephen Kolek',
#                              'id': 663568},
#                 'ID663757': {'boxscoreName': 'Grisham',
#                              'fullName': 'Trent Grisham',
#                              'id': 663757},
#                 'ID665487': {'boxscoreName': 'Tatis Jr.',
#                              'fullName': 'Fernando Tatis Jr.',
#                              'id': 665487},
#                 'ID665742': {'boxscoreName': 'Soto, J',
#                              'fullName': 'Juan Soto',
#                              'id': 665742},
#                 'ID665828': {'boxscoreName': 'Cabrera, O',
#                              'fullName': 'Oswaldo Cabrera',
#                              'id': 665828},
#                 'ID666745': {'boxscoreName': 'Brito',
#                              'fullName': 'Jhony Brito',
#                              'id': 666745},
#                 'ID669093': {'boxscoreName': 'Estrada',
#                              'fullName': 'Jeremiah Estrada',
#                              'id': 669093},
#                 'ID669134': {'boxscoreName': 'Campusano',
#                              'fullName': 'Luis Campusano',
#                              'id': 669134},
#                 'ID669224': {'boxscoreName': 'Wells, A',
#                              'fullName': 'Austin Wells',
#                              'id': 669224},
#                 'ID670970': {'boxscoreName': 'Morejon',
#                              'fullName': 'Adrian Morejon',
#                              'id': 670970},
#                 'ID672782': {'boxscoreName': 'Gómez, Y',
#                              'fullName': 'Yoendrys Gómez',
#                              'id': 672782},
#                 'ID673490': {'boxscoreName': 'Kim, H',
#                              'fullName': 'Ha-Seong Kim',
#                              'id': 673490},
#                 'ID673513': {'boxscoreName': 'Matsui',
#                              'fullName': 'Yuki Matsui',
#                              'id': 673513},
#                 'ID683011': {'boxscoreName': 'Volpe',
#                              'fullName': 'Anthony Volpe',
#                              'id': 683011},
#                 'ID701538': {'boxscoreName': 'Merrill',
#                              'fullName': 'Jackson Merrill',
#                              'id': 701538}},
#  'teamInfo': {'away': {'abbreviation': 'NYY',
#                        'id': 147,
#                        'shortName': 'NY Yankees',
#                        'teamName': 'Yankees'},
#               'home': {'abbreviation': 'SD',
#                        'id': 135,
#                        'shortName': 'San Diego',
#                        'teamName': 'Padres'}}}

# %%
# Function to extract player details from a team
def extract_team_player_details(team_data, team_prefix, player_count):
    player_info = team_data.get('players', {})
    batting_order = team_data.get('battingOrder', [])
    batting_position_map = {player_id: position for position, player_id in enumerate(batting_order, start=1)}
    
    team_data = {}
    for player_id in player_info:
        player_data = player_info[player_id]
        player_id = player_data['person']['id']
        full_name = player_data['person']['fullName']
        batting_position = batting_position_map.get(player_id)
        
        # Skip players with no batting position
        if batting_position is None:
            continue
        
        column_name = f'{team_prefix}_Batter{player_count}_'
        team_data[f'{column_name}Name'] = full_name
        team_data[f'{column_name}ID'] = player_id
        player_count += 1
    
    return team_data, player_count

# Extract data for both teams
away_player_count = 1
home_player_count = 1
away_team_data, away_player_count = extract_team_player_details(boxscore.get('away', {}), 'Away', away_player_count)
home_team_data, home_player_count = extract_team_player_details(boxscore.get('home', {}), 'Home', home_player_count)

# Add the pitching data for both teams
away_pitchers = boxscore.get('awayPitchers', [])[1:]  # Skip the first element
home_pitchers = boxscore.get('homePitchers', [])[1:]  # Skip the first element

for i, pitcher_data in enumerate(away_pitchers, start=1):
    pitcher_name = pitcher_data['name']
    pitcher_id = pitcher_data['personId']
    column_name_name = f'Away_{("SP" if i == 1 else f"P_{i}")}_Name'
    column_name_id = f'Away_{("SP" if i == 1 else f"P_{i}")}_ID'
    away_team_data[column_name_name] = pitcher_name
    away_team_data[column_name_id] = pitcher_id

for i, pitcher_data in enumerate(home_pitchers, start=1):
    pitcher_name = pitcher_data['name']
    pitcher_id = pitcher_data['personId']
    column_name_name = f'Home_{("SP" if i == 1 else f"P_{i}")}_Name'
    column_name_id = f'Home_{("SP" if i == 1 else f"P_{i}")}_ID'
    home_team_data[column_name_name] = pitcher_name
    home_team_data[column_name_id] = pitcher_id

# Ensure all positions are filled with empty strings for missing pitchers
for i in range(len(away_pitchers) + 1, 10):
    column_name_name = f'Away_P_{i}_Name'
    column_name_id = f'Away_P_{i}_ID'
    away_team_data[column_name_name] = ''
    away_team_data[column_name_id] = ''

for i in range(len(home_pitchers) + 1, 10):
    column_name_name = f'Home_P_{i}_Name'
    column_name_id = f'Home_P_{i}_ID'
    home_team_data[column_name_name] = ''
    home_team_data[column_name_id] = ''

# Combine the extracted data into a single dictionary
combined_data = {**away_team_data, **home_team_data}

# Add the 'gamepk' column
combined_data['gamepk'] = gamepk

# Read the game_pks.csv file
game_pks_df = pd.read_csv('game_pks.csv')

# Find the gamepk in the game_pks_df and get the corresponding game_date
game_date = game_pks_df.loc[game_pks_df['game_id'] == gamepk, 'game_date'].values[0]

# Add the 'game_date' column
combined_data['game_date'] = game_date

# Adding runs columns
runs_home = int(boxscore['homeBattingTotals']['r'])
runs_away = int(boxscore['awayBattingTotals']['r'])
combined_data['runs_home'] = runs_home
combined_data['runs_away'] = runs_away
combined_data['runs_total'] = runs_home + runs_away


# Create a DataFrame from the combined data
df = pd.DataFrame([combined_data])

# Reorder columns
column_order = ['game_date', 'gamepk', 'runs_away', 'runs_home', 'runs_total']
for i in range(1, 10):
    column_order += [f'Away_Batter{i}_Name', f'Away_Batter{i}_ID']
for i in range(1, 10):
    column_order += [f'Home_Batter{i}_Name', f'Home_Batter{i}_ID']
for i in range(1, len(away_pitchers) + 1):
    column_order += [f'Away_SP_Name' if i == 1 else f'Away_P_{i}_Name', f'Away_SP_ID' if i == 1 else f'Away_P_{i}_ID']
for i in range(1, len(home_pitchers) + 1):
    column_order += [f'Home_SP_Name' if i == 1 else f'Home_P_{i}_Name', f'Home_SP_ID' if i == 1 else f'Home_P_{i}_ID']

df = df[column_order]

# Display the DataFrame
print(df)
df.to_csv(f'gamelogs/game_{gamepk}.csv')
# Out:
#     game_date  gamepk  runs_away  runs_home  runs_total Away_Batter1_Name  \
# 0  2024-05-24  745415          7          0           7     Anthony Rizzo
#
#    Away_Batter1_ID Away_Batter2_Name  Away_Batter2_ID Away_Batter3_Name  ...  \
# 0           519203      Alex Verdugo           657077       Aaron Judge  ...
#
#    Home_Batter7_Name Home_Batter7_ID  Home_Batter8_Name Home_Batter8_ID  \
# 0   Jake Cronenworth          630105       Ha-Seong Kim          673490
#
#    Home_Batter9_Name Home_Batter9_ID  Away_SP_Name Away_SP_ID  Home_SP_Name  \
# 0        Luis Arraez          650333         Rodón     607074       Darvish
#
#   Home_SP_ID
# 0     506433
#
# [1 rows x 45 columns]
