# %%
import os
import re
import pandas as pd
from pybaseball import statcast_batter, statcast_pitcher, playerid_lookup, pitching_stats_range, batting_stats_range, schedule_and_record, team_game_logs, playerid_reverse_lookup
from datetime import timedelta, datetime
import statsapi
from statsapi import boxscore_data
import pprint
import openpyxl
import mlbstatsapi

# %%
gamepk = 745333
boxscore = boxscore_data(gamePk=gamepk)

# %%
boxscore.keys()
# Out:
# dict_keys(['gameId', 'teamInfo', 'playerInfo', 'away', 'home', 'awayBatters', 'homeBatters', 'awayBattingTotals', 'homeBattingTotals', 'awayBattingNotes', 'homeBattingNotes', 'awayPitchers', 'homePitchers', 'awayPitchingTotals', 'homePitchingTotals', 'gameBoxInfo'])

# %%
pprint.pprint(boxscore)
# Out:
# {'away': {'batters': [665862,
#                       650559,
#                       605137,
#                       660821,
#                       669394,
#                       624503,
#                       672640,
#                       660644,
#                       663743,
#                       666129],
#           'battingOrder': [665862,
#                            650559,
#                            605137,
#                            660821,
#                            669394,
#                            624503,
#                            672640,
#                            660644,
#                            663743],
#           'bench': [641313, 542194, 667472, 656896],
#           'bullpen': [669622,
#                       686539,
#                       676534,
#                       666200,
#                       677053,
#                       640462,
#                       642629,
#                       669432,
#                       664350,
#                       656945,
#                       572143,
#                       677960],
#           'info': [],
#           'note': [],
#           'pitchers': [666129],
#           'players': {'ID542194': {'gameStatus': {},
#                                    'jerseyNumber': '25',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Christian '
#                                                           'Bethancourt',
#                                               'id': 542194},
#                                    'position': {'abbreviation': 'C'},
#                                    'seasonStats': {'batting': {'atBats': 65,
#                                                                'avg': '.169',
#                                                                'baseOnBalls': 2,
#                                                                'doubles': 3,
#                                                                'hits': 11,
#                                                                'homeRuns': 1,
#                                                                'leftOnBase': 33,
#                                                                'obp': '.206',
#                                                                'ops': '.468',
#                                                                'rbi': 5,
#                                                                'runs': 8,
#                                                                'slg': '.262',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 16,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID572143': {'gameStatus': {},
#                                    'jerseyNumber': '20',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Burch Smith',
#                                               'id': 572143},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 95,
#                                                                 'baseOnBalls': 8,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 4,
#                                                                 'earnedRuns': 9,
#                                                                 'era': '3.33',
#                                                                 'hits': 29,
#                                                                 'holds': 1,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '24.1',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 386,
#                                                                 'obp': '.358',
#                                                                 'pitchesThrown': 386,
#                                                                 'rbi': 0,
#                                                                 'runs': 10,
#                                                                 'stolenBases': 4,
#                                                                 'strikeOuts': 20,
#                                                                 'strikes': 258,
#                                                                 'triples': 0,
#                                                                 'wins': 2}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID605137': {'allPositions': [{'abbreviation': '1B'}],
#                                    'battingOrder': '300',
#                                    'gameStatus': {},
#                                    'jerseyNumber': '9',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Josh Bell',
#                                               'id': 605137},
#                                    'position': {'abbreviation': '1B'},
#                                    'seasonStats': {'batting': {'atBats': 210,
#                                                                'avg': '.233',
#                                                                'baseOnBalls': 19,
#                                                                'doubles': 9,
#                                                                'hits': 49,
#                                                                'homeRuns': 6,
#                                                                'leftOnBase': 92,
#                                                                'obp': '.311',
#                                                                'ops': '.673',
#                                                                'rbi': 27,
#                                                                'runs': 21,
#                                                                'slg': '.362',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 47,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {'atBats': 0,
#                                                          'baseOnBalls': 0,
#                                                          'doubles': 0,
#                                                          'hits': 0,
#                                                          'homeRuns': 0,
#                                                          'leftOnBase': 0,
#                                                          'rbi': 0,
#                                                          'runs': 0,
#                                                          'stolenBases': 0,
#                                                          'strikeOuts': 0,
#                                                          'triples': 0},
#                                              'pitching': {}},
#                                    'status': {}},
#                       'ID624503': {'allPositions': [{'abbreviation': 'LF'}],
#                                    'battingOrder': '600',
#                                    'gameStatus': {},
#                                    'jerseyNumber': '1',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Nick Gordon',
#                                               'id': 624503},
#                                    'position': {'abbreviation': 'LF'},
#                                    'seasonStats': {'batting': {'atBats': 135,
#                                                                'avg': '.222',
#                                                                'baseOnBalls': 5,
#                                                                'doubles': 5,
#                                                                'hits': 30,
#                                                                'homeRuns': 5,
#                                                                'leftOnBase': 59,
#                                                                'obp': '.248',
#                                                                'ops': '.618',
#                                                                'rbi': 18,
#                                                                'runs': 13,
#                                                                'slg': '.370',
#                                                                'stolenBases': 3,
#                                                                'strikeOuts': 32,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {'atBats': 0,
#                                                          'baseOnBalls': 0,
#                                                          'doubles': 0,
#                                                          'hits': 0,
#                                                          'homeRuns': 0,
#                                                          'leftOnBase': 0,
#                                                          'rbi': 0,
#                                                          'runs': 0,
#                                                          'stolenBases': 0,
#                                                          'strikeOuts': 0,
#                                                          'triples': 0},
#                                              'pitching': {}},
#                                    'status': {}},
#                       'ID640462': {'gameStatus': {},
#                                    'jerseyNumber': '35',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'A.J. Puk',
#                                               'id': 640462},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 75,
#                                                                 'baseOnBalls': 19,
#                                                                 'blownSaves': 1,
#                                                                 'doubles': 11,
#                                                                 'earnedRuns': 17,
#                                                                 'era': '8.66',
#                                                                 'hits': 23,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 1,
#                                                                 'inningsPitched': '17.2',
#                                                                 'losses': 6,
#                                                                 'numberOfPitches': 403,
#                                                                 'obp': '.448',
#                                                                 'pitchesThrown': 403,
#                                                                 'rbi': 0,
#                                                                 'runs': 21,
#                                                                 'stolenBases': 1,
#                                                                 'strikeOuts': 13,
#                                                                 'strikes': 238,
#                                                                 'triples': 1,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID641313': {'gameStatus': {},
#                                    'jerseyNumber': '7',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Tim Anderson',
#                                               'id': 641313},
#                                    'position': {'abbreviation': 'SS'},
#                                    'seasonStats': {'batting': {'atBats': 146,
#                                                                'avg': '.199',
#                                                                'baseOnBalls': 7,
#                                                                'doubles': 3,
#                                                                'hits': 29,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 64,
#                                                                'obp': '.235',
#                                                                'ops': '.454',
#                                                                'rbi': 6,
#                                                                'runs': 10,
#                                                                'slg': '.219',
#                                                                'stolenBases': 3,
#                                                                'strikeOuts': 43,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID642629': {'gameStatus': {},
#                                    'jerseyNumber': '67',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Emmanuel Ramirez',
#                                               'id': 642629},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 20,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 1,
#                                                                 'earnedRuns': 1,
#                                                                 'era': '1.59',
#                                                                 'hits': 3,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '5.2',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 67,
#                                                                 'obp': '.150',
#                                                                 'pitchesThrown': 67,
#                                                                 'rbi': 0,
#                                                                 'runs': 1,
#                                                                 'stolenBases': 1,
#                                                                 'strikeOuts': 5,
#                                                                 'strikes': 43,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID650559': {'allPositions': [{'abbreviation': 'DH'}],
#                                    'battingOrder': '200',
#                                    'gameStatus': {},
#                                    'jerseyNumber': '14',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Bryan De La Cruz',
#                                               'id': 650559},
#                                    'position': {'abbreviation': 'DH'},
#                                    'seasonStats': {'batting': {'atBats': 221,
#                                                                'avg': '.253',
#                                                                'baseOnBalls': 18,
#                                                                'doubles': 9,
#                                                                'hits': 56,
#                                                                'homeRuns': 9,
#                                                                'leftOnBase': 74,
#                                                                'obp': '.310',
#                                                                'ops': '.726',
#                                                                'rbi': 25,
#                                                                'runs': 27,
#                                                                'slg': '.416',
#                                                                'stolenBases': 1,
#                                                                'strikeOuts': 61,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {'atBats': 0,
#                                                          'baseOnBalls': 0,
#                                                          'doubles': 0,
#                                                          'hits': 0,
#                                                          'homeRuns': 0,
#                                                          'leftOnBase': 0,
#                                                          'rbi': 0,
#                                                          'runs': 0,
#                                                          'stolenBases': 0,
#                                                          'strikeOuts': 0,
#                                                          'triples': 0},
#                                              'pitching': {}},
#                                    'status': {}},
#                       'ID656896': {'gameStatus': {},
#                                    'jerseyNumber': '15',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Emmanuel Rivera',
#                                               'id': 656896},
#                                    'position': {'abbreviation': '3B'},
#                                    'seasonStats': {'batting': {'atBats': 93,
#                                                                'avg': '.215',
#                                                                'baseOnBalls': 9,
#                                                                'doubles': 4,
#                                                                'hits': 20,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 41,
#                                                                'obp': '.302',
#                                                                'ops': '.560',
#                                                                'rbi': 6,
#                                                                'runs': 8,
#                                                                'slg': '.258',
#                                                                'stolenBases': 1,
#                                                                'strikeOuts': 24,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 7,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 4,
#                                                                 'era': '36.00',
#                                                                 'hits': 4,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 1,
#                                                                 'inningsPitched': '1.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 20,
#                                                                 'obp': '.625',
#                                                                 'pitchesThrown': 20,
#                                                                 'rbi': 0,
#                                                                 'runs': 4,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 13,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID656945': {'gameStatus': {},
#                                    'jerseyNumber': '66',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Tanner Scott',
#                                               'id': 656945},
#                                    'position': {'abbreviation': 'P'},
#                                    'seasonStats': {'batting': {'atBats': 0,
#                                                                'avg': '.000',
#                                                                'baseOnBalls': 0,
#                                                                'doubles': 0,
#                                                                'hits': 0,
#                                                                'homeRuns': 0,
#                                                                'leftOnBase': 0,
#                                                                'obp': '.000',
#                                                                'ops': '.000',
#                                                                'rbi': 0,
#                                                                'runs': 0,
#                                                                'slg': '.000',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 0,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 76,
#                                                                 'baseOnBalls': 18,
#                                                                 'blownSaves': 1,
#                                                                 'doubles': 2,
#                                                                 'earnedRuns': 4,
#                                                                 'era': '1.64',
#                                                                 'hits': 12,
#                                                                 'holds': 1,
#                                                                 'homeRuns': 1,
#                                                                 'inningsPitched': '22.0',
#                                                                 'losses': 4,
#                                                                 'numberOfPitches': 392,
#                                                                 'obp': '.319',
#                                                                 'pitchesThrown': 392,
#                                                                 'rbi': 0,
#                                                                 'runs': 8,
#                                                                 'stolenBases': 1,
#                                                                 'strikeOuts': 23,
#                                                                 'strikes': 241,
#                                                                 'triples': 0,
#                                                                 'wins': 4}},
#                                    'stats': {'batting': {}, 'pitching': {}},
#                                    'status': {}},
#                       'ID660644': {'allPositions': [{'abbreviation': 'SS'}],
#                                    'battingOrder': '800',
#                                    'gameStatus': {},
#                                    'jerseyNumber': '17',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Vidal Bruján',
#                                               'id': 660644},
#                                    'position': {'abbreviation': 'SS'},
#                                    'seasonStats': {'batting': {'atBats': 101,
#                                                                'avg': '.257',
#                                                                'baseOnBalls': 8,
#                                                                'doubles': 6,
#                                                                'hits': 26,
#                                                                'homeRuns': 1,
#                                                                'leftOnBase': 38,
#                                                                'obp': '.330',
#                                                                'ops': '.716',
#                                                                'rbi': 6,
#                                                                'runs': 14,
#                                                                'slg': '.386',
#                                                                'stolenBases': 2,
#                                                                'strikeOuts': 15,
#                                                                'triples': 2},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {'atBats': 0,
#                                                          'baseOnBalls': 0,
#                                                          'doubles': 0,
#                                                          'hits': 0,
#                                                          'homeRuns': 0,
#                                                          'leftOnBase': 0,
#                                                          'rbi': 0,
#                                                          'runs': 0,
#                                                          'stolenBases': 0,
#                                                          'strikeOuts': 0,
#                                                          'triples': 0},
#                                              'pitching': {}},
#                                    'status': {}},
#                       'ID660821': {'allPositions': [{'abbreviation': 'RF'}],
#                                    'battingOrder': '400',
#                                    'gameStatus': {},
#                                    'jerseyNumber': '12',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Jesús Sánchez',
#                                               'id': 660821},
#                                    'position': {'abbreviation': 'RF'},
#                                    'seasonStats': {'batting': {'atBats': 147,
#                                                                'avg': '.224',
#                                                                'baseOnBalls': 9,
#                                                                'doubles': 3,
#                                                                'hits': 33,
#                                                                'homeRuns': 2,
#                                                                'leftOnBase': 73,
#                                                                'obp': '.281',
#                                                                'ops': '.567',
#                                                                'rbi': 18,
#                                                                'runs': 11,
#                                                                'slg': '.286',
#                                                                'stolenBases': 6,
#                                                                'strikeOuts': 33,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
#                                                                 'runs': 0,
#                                                                 'stolenBases': 0,
#                                                                 'strikeOuts': 0,
#                                                                 'strikes': 0,
#                                                                 'triples': 0,
#                                                                 'wins': 0}},
#                                    'stats': {'batting': {'atBats': 0,
#                                                          'baseOnBalls': 0,
#                                                          'doubles': 0,
#                                                          'hits': 0,
#                                                          'homeRuns': 0,
#                                                          'leftOnBase': 0,
#                                                          'rbi': 0,
#                                                          'runs': 0,
#                                                          'stolenBases': 0,
#                                                          'strikeOuts': 0,
#                                                          'triples': 0},
#                                              'pitching': {}},
#                                    'status': {}},
#                       'ID663743': {'allPositions': [{'abbreviation': 'C'}],
#                                    'battingOrder': '900',
#                                    'gameStatus': {},
#                                    'jerseyNumber': '4',
#                                    'parentTeamId': 146,
#                                    'person': {'fullName': 'Nick Fortes',
#                                               'id': 663743},
#                                    'position': {'abbreviation': 'C'},
#                                    'seasonStats': {'batting': {'atBats': 99,
#                                                                'avg': '.162',
#                                                                'baseOnBalls': 4,
#                                                                'doubles': 2,
#                                                                'hits': 16,
#                                                                'homeRuns': 2,
#                                                                'leftOnBase': 33,
#                                                                'obp': '.202',
#                                                                'ops': '.444',
#                                                                'rbi': 8,
#                                                                'runs': 8,
#                                                                'slg': '.242',
#                                                                'stolenBases': 0,
#                                                                'strikeOuts': 13,
#                                                                'triples': 0},
#                                                    'pitching': {'atBats': 0,
#                                                                 'baseOnBalls': 0,
#                                                                 'blownSaves': 0,
#                                                                 'doubles': 0,
#                                                                 'earnedRuns': 0,
#                                                                 'era': '-.--',
#                                                                 'hits': 0,
#                                                                 'holds': 0,
#                                                                 'homeRuns': 0,
#                                                                 'inningsPitched': '0.0',
#                                                                 'losses': 0,
#                                                                 'numberOfPitches': 0,
#                                                                 'obp': '.000',
#                                                                 'rbi': 0,
# ...
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.323',
#                   'battingOrder': '300',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Profar, J',
#                   'namefield': '3 Profar, J  LF',
#                   'note': '',
#                   'obp': '.419',
#                   'ops': '.916',
#                   'personId': 595777,
#                   'position': 'LF',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.497',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.237',
#                   'battingOrder': '400',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Machado, M',
#                   'namefield': '4 Machado, M  3B',
#                   'note': '',
#                   'obp': '.291',
#                   'ops': '.653',
#                   'personId': 592518,
#                   'position': '3B',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.362',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.266',
#                   'battingOrder': '500',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Cronenworth',
#                   'namefield': '5 Cronenworth  2B',
#                   'note': '',
#                   'obp': '.332',
#                   'ops': '.791',
#                   'personId': 630105,
#                   'position': '2B',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.459',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.375',
#                   'battingOrder': '600',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Solano',
#                   'namefield': '6 Solano  DH',
#                   'note': '',
#                   'obp': '.474',
#                   'ops': '1.005',
#                   'personId': 456781,
#                   'position': 'DH',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.531',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.241',
#                   'battingOrder': '700',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Campusano',
#                   'namefield': '7 Campusano  C',
#                   'note': '',
#                   'obp': '.293',
#                   'ops': '.670',
#                   'personId': 669134,
#                   'position': 'C',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.377',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.275',
#                   'battingOrder': '800',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Merrill',
#                   'namefield': '8 Merrill  CF',
#                   'note': '',
#                   'obp': '.316',
#                   'ops': '.676',
#                   'personId': 701538,
#                   'position': 'CF',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.360',
#                   'substitution': False,
#                   'triples': '0'},
#                  {'ab': '0',
#                   'avg': '.212',
#                   'battingOrder': '900',
#                   'bb': '0',
#                   'doubles': '0',
#                   'h': '0',
#                   'hr': '0',
#                   'k': '0',
#                   'lob': '0',
#                   'name': 'Kim, H',
#                   'namefield': '9 Kim, H  SS',
#                   'note': '',
#                   'obp': '.326',
#                   'ops': '.678',
#                   'personId': 673490,
#                   'position': 'SS',
#                   'r': '0',
#                   'rbi': '0',
#                   'sb': '0',
#                   'slg': '.352',
#                   'substitution': False,
#                   'triples': '0'}],
#  'homeBattingNotes': {},
#  'homeBattingTotals': {'ab': '0',
#                        'avg': '',
#                        'battingOrder': '',
#                        'bb': '0',
#                        'h': '0',
#                        'hr': '0',
#                        'k': '0',
#                        'lob': '0',
#                        'name': 'Totals',
#                        'namefield': 'Totals',
#                        'note': '',
#                        'obp': '',
#                        'ops': '',
#                        'personId': 0,
#                        'position': '',
#                        'r': '0',
#                        'rbi': '0',
#                        'slg': '',
#                        'substitution': False},
#  'homePitchers': [{'bb': 'BB',
#                    'er': 'ER',
#                    'era': 'ERA',
#                    'h': 'H',
#                    'hr': 'HR',
#                    'ip': 'IP',
#                    'k': 'K',
#                    'name': 'Marlins Pitchers',
#                    'namefield': 'Padres Pitchers',
#                    'note': '',
#                    'p': 'P',
#                    'personId': 0,
#                    'r': 'R',
#                    's': 'S'},
#                   {'bb': '0',
#                    'er': '0',
#                    'era': '3.04',
#                    'h': '0',
#                    'hr': '0',
#                    'ip': '0.0',
#                    'k': '0',
#                    'name': 'Darvish',
#                    'namefield': 'Darvish',
#                    'note': '',
#                    'p': '0',
#                    'personId': 506433,
#                    'r': '0',
#                    's': '0'}],
#  'homePitchingTotals': {'bb': '0',
#                         'er': '0',
#                         'era': '',
#                         'h': '0',
#                         'hr': '0',
#                         'ip': '0.0',
#                         'k': '0',
#                         'name': 'Totals',
#                         'namefield': 'Totals',
#                         'note': '',
#                         'p': '',
#                         'personId': 0,
#                         'r': '0',
#                         's': ''},
#  'playerInfo': {'ID444482': {'boxscoreName': 'Peralta',
#                              'fullName': 'David Peralta',
#                              'id': 444482},
#                 'ID456781': {'boxscoreName': 'Solano',
#                              'fullName': 'Donovan Solano',
#                              'id': 456781},
#                 'ID506433': {'boxscoreName': 'Darvish',
#                              'fullName': 'Yu Darvish',
#                              'id': 506433},
#                 'ID542194': {'boxscoreName': 'Bethancourt',
#                              'fullName': 'Christian Bethancourt',
#                              'id': 542194},
#                 'ID543309': {'boxscoreName': 'Higashioka',
#                              'fullName': 'Kyle Higashioka',
#                              'id': 543309},
#                 'ID572143': {'boxscoreName': 'Smith, B',
#                              'fullName': 'Burch Smith',
#                              'id': 572143},
#                 'ID592518': {'boxscoreName': 'Machado, M',
#                              'fullName': 'Manny Machado',
#                              'id': 592518},
#                 'ID593974': {'boxscoreName': 'Peralta, Wa',
#                              'fullName': 'Wandy Peralta',
#                              'id': 593974},
#                 'ID595777': {'boxscoreName': 'Profar, J',
#                              'fullName': 'Jurickson Profar',
#                              'id': 595777},
#                 'ID605137': {'boxscoreName': 'Bell',
#                              'fullName': 'Josh Bell',
#                              'id': 605137},
#                 'ID605397': {'boxscoreName': 'Musgrove',
#                              'fullName': 'Joe Musgrove',
#                              'id': 605397},
#                 'ID624503': {'boxscoreName': 'Gordon',
#                              'fullName': 'Nick Gordon',
#                              'id': 624503},
#                 'ID630105': {'boxscoreName': 'Cronenworth',
#                              'fullName': 'Jake Cronenworth',
#                              'id': 630105},
#                 'ID640462': {'boxscoreName': 'Puk',
#                              'fullName': 'A.J. Puk',
#                              'id': 640462},
#                 'ID640492': {'boxscoreName': 'Azocar',
#                              'fullName': 'José Azocar',
#                              'id': 640492},
#                 'ID641313': {'boxscoreName': 'Anderson, Ti',
#                              'fullName': 'Tim Anderson',
#                              'id': 641313},
#                 'ID642180': {'boxscoreName': 'Wade',
#                              'fullName': 'Tyler Wade',
#                              'id': 642180},
#                 'ID642629': {'boxscoreName': 'Ramirez, E',
#                              'fullName': 'Emmanuel Ramirez',
#                              'id': 642629},
#                 'ID650333': {'boxscoreName': 'Arraez',
#                              'fullName': 'Luis Arraez',
#                              'id': 650333},
#                 'ID650559': {'boxscoreName': 'De La Cruz, B',
#                              'fullName': 'Bryan De La Cruz',
#                              'id': 650559},
#                 'ID650633': {'boxscoreName': 'King',
#                              'fullName': 'Michael King',
#                              'id': 650633},
#                 'ID656302': {'boxscoreName': 'Cease',
#                              'fullName': 'Dylan Cease',
#                              'id': 656302},
#                 'ID656896': {'boxscoreName': 'Rivera, E',
#                              'fullName': 'Emmanuel Rivera',
#                              'id': 656896},
#                 'ID656945': {'boxscoreName': 'Scott, Tan',
#                              'fullName': 'Tanner Scott',
#                              'id': 656945},
#                 'ID660644': {'boxscoreName': 'Bruján',
#                              'fullName': 'Vidal Bruján',
#                              'id': 660644},
#                 'ID660821': {'boxscoreName': 'Sánchez, J',
#                              'fullName': 'Jesús Sánchez',
#                              'id': 660821},
#                 'ID660853': {'boxscoreName': 'De Los Santos, E',
#                              'fullName': 'Enyel De Los Santos',
#                              'id': 660853},
#                 'ID663158': {'boxscoreName': 'Suarez, R',
#                              'fullName': 'Robert Suarez',
#                              'id': 663158},
#                 'ID663362': {'boxscoreName': 'Waldron',
#                              'fullName': 'Matt Waldron',
#                              'id': 663362},
#                 'ID663568': {'boxscoreName': 'Kolek',
#                              'fullName': 'Stephen Kolek',
#                              'id': 663568},
#                 'ID663743': {'boxscoreName': 'Fortes',
#                              'fullName': 'Nick Fortes',
#                              'id': 663743},
#                 'ID664350': {'boxscoreName': 'Sánchez, S',
#                              'fullName': 'Sixto Sánchez',
#                              'id': 664350},
#                 'ID665487': {'boxscoreName': 'Tatis Jr.',
#                              'fullName': 'Fernando Tatis Jr.',
#                              'id': 665487},
#                 'ID665862': {'boxscoreName': 'Chisholm Jr.',
#                              'fullName': 'Jazz Chisholm Jr.',
#                              'id': 665862},
#                 'ID666129': {'boxscoreName': 'Garrett, B',
#                              'fullName': 'Braxton Garrett',
#                              'id': 666129},
#                 'ID666200': {'boxscoreName': 'Luzardo',
#                              'fullName': 'Jesús Luzardo',
#                              'id': 666200},
#                 'ID666745': {'boxscoreName': 'Brito',
#                              'fullName': 'Jhony Brito',
#                              'id': 666745},
#                 'ID667472': {'boxscoreName': 'Myers',
#                              'fullName': 'Dane Myers',
#                              'id': 667472},
#                 'ID669093': {'boxscoreName': 'Estrada',
#                              'fullName': 'Jeremiah Estrada',
#                              'id': 669093},
#                 'ID669134': {'boxscoreName': 'Campusano',
#                              'fullName': 'Luis Campusano',
#                              'id': 669134},
#                 'ID669394': {'boxscoreName': 'Burger',
#                              'fullName': 'Jake Burger',
#                              'id': 669394},
#                 'ID669432': {'boxscoreName': 'Rogers, Tr',
#                              'fullName': 'Trevor Rogers',
#                              'id': 669432},
#                 'ID669622': {'boxscoreName': 'Bender',
#                              'fullName': 'Anthony Bender',
#                              'id': 669622},
#                 'ID670970': {'boxscoreName': 'Morejon',
#                              'fullName': 'Adrian Morejon',
#                              'id': 670970},
#                 'ID672640': {'boxscoreName': 'Lopez, O',
#                              'fullName': 'Otto Lopez',
#                              'id': 672640},
#                 'ID673490': {'boxscoreName': 'Kim, H',
#                              'fullName': 'Ha-Seong Kim',
#                              'id': 673490},
#                 'ID673513': {'boxscoreName': 'Matsui',
#                              'fullName': 'Yuki Matsui',
#                              'id': 673513},
#                 'ID676534': {'boxscoreName': 'Faucher',
#                              'fullName': 'Calvin Faucher',
#                              'id': 676534},
#                 'ID677053': {'boxscoreName': 'Nardi',
#                              'fullName': 'Andrew Nardi',
#                              'id': 677053},
#                 'ID677960': {'boxscoreName': 'Weathers',
#                              'fullName': 'Ryan Weathers',
#                              'id': 677960},
#                 'ID686539': {'boxscoreName': 'Cronin',
#                              'fullName': 'Declan Cronin',
#                              'id': 686539},
#                 'ID701538': {'boxscoreName': 'Merrill',
#                              'fullName': 'Jackson Merrill',
#                              'id': 701538}},
#  'teamInfo': {'away': {'abbreviation': 'MIA',
#                        'id': 146,
#                        'shortName': 'Miami',
#                        'teamName': 'Marlins'},
#               'home': {'abbreviation': 'SD',
#                        'id': 135,
#                        'shortName': 'San Diego',
#                        'teamName': 'Padres'}}}

# %%
# Function to extract player details from a team and include bbref ID
def extract_team_player_details(team_data, team_prefix, player_count):
    player_info = team_data.get('players', {})
    batting_order = team_data.get('battingOrder', [])
    batting_position_map = {player_id: position for position, player_id in enumerate(batting_order, start=1)}
    
    team_data = {}
    for player_id in player_info:
        player_data = player_info[player_id]
        player_id = player_data['person']['id']
        full_name = player_data['person']['fullName']
        batting_position = batting_position_map.get(player_id)
        
        # Skip players with no batting position
        if batting_position is None:
            continue
        
        column_name = f'{team_prefix}_Batter{player_count}_'
        team_data[f'{column_name}Name'] = full_name
        team_data[f'{column_name}ID'] = player_id
        
        # Get bbref ID
        bbref_id = get_bbref_id(player_id)
        team_data[f'{column_name}bbrefID'] = bbref_id
        
        player_count += 1
    
    return team_data, player_count

def get_bbref_id(mlb_id):
    try:
        lookup_df = playerid_reverse_lookup([mlb_id], 'mlbam')
        bbref_id = lookup_df.loc[0, 'key_bbref'] if not lookup_df.empty else ''
        return bbref_id
    except Exception as e:
        print(f"Error retrieving bbref ID for MLB ID {mlb_id}: {e}")
        return ''

# Extract data for both teams
away_player_count = 1
home_player_count = 1
away_team_data, away_player_count = extract_team_player_details(boxscore.get('away', {}), 'Away', away_player_count)
home_team_data, home_player_count = extract_team_player_details(boxscore.get('home', {}), 'Home', home_player_count)

# Add the pitching data for both teams and include bbref ID
away_pitchers = boxscore.get('awayPitchers', [])[1:]  # Skip the first element
home_pitchers = boxscore.get('homePitchers', [])[1:]  # Skip the first element

for i, pitcher_data in enumerate(away_pitchers, start=1):
    pitcher_name = pitcher_data['name']
    pitcher_id = pitcher_data['personId']
    column_name_name = f'Away_{("SP" if i == 1 else f"P_{i}")}_Name'
    column_name_id = f'Away_{("SP" if i == 1 else f"P_{i}")}_ID'
    away_team_data[column_name_name] = pitcher_name
    away_team_data[column_name_id] = pitcher_id

    # Get bbref ID
    bbref_id = get_bbref_id(pitcher_id)
    column_name_bbref = f'Away_{("SP" if i == 1 else f"P_{i}")}_bbrefID'
    away_team_data[column_name_bbref] = bbref_id

for i, pitcher_data in enumerate(home_pitchers, start=1):
    pitcher_name = pitcher_data['name']
    pitcher_id = pitcher_data['personId']
    column_name_name = f'Home_{("SP" if i == 1 else f"P_{i}")}_Name'
    column_name_id = f'Home_{("SP" if i == 1 else f"P_{i}")}_ID'
    home_team_data[column_name_name] = pitcher_name
    home_team_data[column_name_id] = pitcher_id

    # Get bbref ID
    bbref_id = get_bbref_id(pitcher_id)
    column_name_bbref = f'Home_{("SP" if i == 1 else f"P_{i}")}_bbrefID'
    home_team_data[column_name_bbref] = bbref_id

# Ensure all positions are filled with empty strings for missing pitchers (up to 10)
for i in range(len(away_pitchers) + 1, 11):
    column_name_name = f'Away_P_{i}_Name'
    column_name_id = f'Away_P_{i}_ID'
    column_name_bbref = f'Away_P_{i}_bbrefID'
    away_team_data[column_name_name] = ''
    away_team_data[column_name_id] = ''
    away_team_data[column_name_bbref] = ''

for i in range(len(home_pitchers) + 1, 11):
    column_name_name = f'Home_P_{i}_Name'
    column_name_id = f'Home_P_{i}_ID'
    column_name_bbref = f'Home_P_{i}_bbrefID'
    home_team_data[column_name_name] = ''
    home_team_data[column_name_id] = ''
    home_team_data[column_name_bbref] = ''

# Combine the extracted data into a single dictionary
combined_data = {**away_team_data, **home_team_data}

# Add the 'gamepk' column
combined_data['gamepk'] = gamepk

# Read the game_pks.csv file
game_pks_df = pd.read_csv('game_pks.csv')

# Find the gamepk in the game_pks_df and get the corresponding game_date
game_date = game_pks_df.loc[game_pks_df['game_id'] == gamepk, 'game_date'].values[0]

# Add the 'game_date' column
combined_data['game_date'] = game_date

# Adding runs columns
runs_home = int(boxscore['homeBattingTotals']['r'])
runs_away = int(boxscore['awayBattingTotals']['r'])
combined_data['runs_home'] = runs_home
combined_data['runs_away'] = runs_away
combined_data['runs_total'] = runs_home + runs_away

# Ensure all batter columns are filled
for i in range(1, 10):
    for team in ['Away', 'Home']:
        combined_data.setdefault(f'{team}_Batter{i}_Name', '')
        combined_data.setdefault(f'{team}_Batter{i}_ID', '')
        combined_data.setdefault(f'{team}_Batter{i}_bbrefID', '')

# Ensure all pitcher columns are filled
for i in range(1, 11):
    for team in ['Away', 'Home']:
        role = 'SP' if i == 1 else f'P_{i}'
        combined_data.setdefault(f'{team}_{role}_Name', '')
        combined_data.setdefault(f'{team}_{role}_ID', '')
        combined_data.setdefault(f'{team}_{role}_bbrefID', '')

# Create a DataFrame from the combined data
df = pd.DataFrame([combined_data])

# Reorder columns
column_order = ['game_date', 'gamepk', 'runs_away', 'runs_home', 'runs_total']
for i in range(1, 10):
    column_order += [f'Away_Batter{i}_Name', f'Away_Batter{i}_ID', f'Away_Batter{i}_bbrefID']
for i in range(1, 10):
    column_order += [f'Home_Batter{i}_Name', f'Home_Batter{i}_ID', f'Home_Batter{i}_bbrefID']
for i in range(1, 11):
    column_order += [f'Away_SP_Name' if i == 1 else f'Away_P_{i}_Name', f'Away_SP_ID' if i == 1 else f'Away_P_{i}_ID', f'Away_SP_bbrefID' if i == 1 else f'Away_P_{i}_bbrefID']
for i in range(1, 11):
    column_order += [f'Home_SP_Name' if i == 1 else f'Home_P_{i}_Name', f'Home_SP_ID' if i == 1 else f'Home_P_{i}_ID', f'Home_SP_bbrefID' if i == 1 else f'Home_P_{i}_bbrefID']

# Filter out empty pitcher columns
df = df[column_order]
non_empty_columns = [col for col in df.columns if not df[col].isnull().all() and df[col].astype(bool).sum() > 0]
df = df[non_empty_columns]

# Display the DataFrame
print(df)
df.to_csv(f'gamelogs/game_{gamepk}.csv', index=False)
# Out:
#     game_date  gamepk  runs_away  runs_home  runs_total Away_Batter1_Name  \
# 0  2024-05-29  745333          6          1           7      Bryce Harper
#
#    Away_Batter1_ID Away_Batter1_bbrefID Away_Batter2_Name  Away_Batter2_ID  \
# 0           547180            harpebr03      Edmundo Sosa           624641
#
#    ... Home_SP_bbrefID Home_P_2_Name  Home_P_2_ID Home_P_2_bbrefID  \
# 0  ...       harriky01       Jackson       592426        jackslu01
#
#   Home_P_3_Name  Home_P_3_ID Home_P_3_bbrefID Home_P_4_Name  Home_P_4_ID  \
# 0  Rodríguez, R       678495        rodrira02    Rogers, Ty       643511
#
#   Home_P_4_bbrefID
# 0        rogerty01
#
# [1 rows x 82 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
